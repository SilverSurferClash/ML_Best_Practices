# %%
###### Basic packages
import os
from pathlib import Path
import pickle

#Data and visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#import sklearn
#assert sklearn.__version__ >= "0.20"

#Validation Strategy
from sklearn.model_selection import RepeatedStratifiedKFold, StratifiedKFold, train_test_split, KFold

#Encoding
import category_encoders as ce

#Imputation
from sklearn.impute import SimpleImputer
import missingno as msno
from sklearn.impute import KNNImputer

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler


#Metrics
from sklearn.metrics import roc_auc_score, roc_curve, log_loss, mean_squared_error

#Pipeline
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA, NMF
from sklearn.manifold import TSNE
from umap import UMAP
from scipy.cluster.hierarchy import dendrogram, ward

import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

sns.set_theme(style = 'white', palette = 'viridis')
pal = sns.color_palette('viridis')

pd.set_option('display.max_rows', 100)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Regression Models

import xgboost as xgb
import lightgbm as lgb
import xgboost as xgb
import lightgbm as lgb
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor, LassoCV
from sklearn.linear_model import PassiveAggressiveRegressor, ARDRegression, RidgeCV, ElasticNetCV
from sklearn.linear_model import TheilSenRegressor, RANSACRegressor, HuberRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor

from sklearn.cross_decomposition import PLSRegression
from catboost import CatBoost, CatBoostRegressor, CatBoostClassifier
from catboost import Pool

# %%
# File path and files

#File Path
data_dir = "/kaggle/input/playground-series-s3e15"
train_file = "data.csv"
#test_file = "test.csv"
orig_file = "/kaggle/input/predicting-heat-flux/Data_CHF_Zhao_2020_ATE.csv"
submission_file = "sample_submission.csv"
working_dir = "/kaggle/working/"

target = "target"

# %%
# test_data = Path(data_dir)/test_file
# train_data = Path(data_dir)/train_file
# submission_data = Path(data_dir)/submission_file

# %%
#train = pd.read_csv("/kaggle/input/playground-series-s3e15/data.csv")
# test = pd.read_csv(test_data)
# submission_df = pd.read_csv(submission_data)

# %%
def get_data(data_dir = data_dir,train_file = train_file,  submission_file = submission_file):
    #test_data = Path(data_dir)/test_file
    train_data = Path(data_dir)/train_file
    orig_data = Path(orig_file)
    submission_data = Path(data_dir)/submission_file
    train = pd.read_csv(train_data)
   # test = pd.read_csv(test_data)
    orig_train = pd.read_csv(orig_data)
    submission_df = pd.read_csv(submission_data)
    return train,submission_df,orig_train

# %%
train, submission_df, orig_train = get_data()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31644 entries, 0 to 31643
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   31644 non-null  int64
#  1   author               26620 non-null  object
#  2   geometry             26144 non-null  object
#  3   pressure [MPa]       27192 non-null  float64
#  4   mass_flux [kg/m2-s]  26853 non-null  float64
#  5   x_e_out [-]          21229 non-null  float64
#  6   D_e [mm]             26156 non-null  float64
#  7   D_h [mm]             27055 non-null  float64
#  8   length [mm]          26885 non-null  float64
#  9   chf_exp [MW/m2]      31644 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
def create_EDA_summary (df = None):
    train_import_table = pd.DataFrame()
    train_import_table["dtype"] = df.apply(lambda x: x.dtype)
    train_import_table["NROW"] = df.shape[0]
    train_import_table["Unique_values"] = [ len(df[col].unique()) for col in df.columns]
    train_import_table["Percent_missing"] = (df.isnull().sum()/df.shape[0])*100
    
    return train_import_table

# %%
create_EDA_summary(df = train)
# Out:
#                        dtype   NROW  Unique_values  Percent_missing
# id                     int64  31644          31644         0.000000
# author                object  31644             11        15.876627
# geometry              object  31644              4        17.380862
# pressure [MPa]       float64  31644            145        14.069018
# mass_flux [kg/m2-s]  float64  31644            734        15.140311
# x_e_out [-]          float64  31644           1683        32.913032
# D_e [mm]             float64  31644             44        17.342940
# D_h [mm]             float64  31644             50        14.501959
# length [mm]          float64  31644             71        15.039186
# chf_exp [MW/m2]      float64  31644            109         0.000000

# %%
train.head()
# Out:
#    id    author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   0  Thompson     tube            7.00               3770.0       0.1754
# 1   1  Thompson     tube             NaN               6049.0      -0.0416
# 2   2  Thompson      NaN           13.79               2034.0       0.0335
# 3   3      Beus  annulus           13.79               3679.0      -0.0279
# 4   4       NaN     tube           13.79                686.0          NaN
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       NaN      10.8        432.0              3.6
# 1      10.3      10.3        762.0              6.2
# 2       7.7       7.7        457.0              2.5
# 3       5.6      15.2       2134.0              3.0
# 4      11.1      11.1        457.0              2.8

# %%
train.rename(columns = {'x_e_out [-]':'target'}, inplace = True)

# %%
train.describe().T
# Out:
#                        count          mean          std      min        25%  \
# id                   31644.0  15821.500000  9134.980296   0.0000  7910.7500
# pressure [MPa]       27192.0     10.640747     4.333683   0.1000     6.8900
# mass_flux [kg/m2-s]  26853.0   3068.011023  1777.032080   0.0000  1519.0000
# target               21229.0     -0.000453     0.100911  -0.8667    -0.0466
# D_e [mm]             26156.0      8.629255     5.185692   1.0000     5.0000
# D_h [mm]             27055.0     14.174330    19.838489   1.0000     5.6000
# length [mm]          26885.0    832.987391   672.299239  10.0000   318.0000
# chf_exp [MW/m2]      31644.0      3.796985     1.983991   0.8000     2.4000
#
#                             50%         75%        max
# id                   15821.5000  23732.2500  31643.000
# pressure [MPa]          11.0700     13.7900     20.680
# mass_flux [kg/m2-s]   2731.0000   4069.0000   7975.000
# target                   0.0038      0.0648      0.232
# D_e [mm]                 7.8000     10.8000     37.500
# D_h [mm]                10.0000     11.5000    120.000
# length [mm]            610.0000    914.0000   3048.000
# chf_exp [MW/m2]          3.4000      4.6000     19.300

# %%
#Create the test set to be predicted - Consists of all the missing values in the target variable
train["Train/Test"] = np.where(train["target"].isnull() == True, "Test", "Train")

# %%
train["Train/Test"].value_counts(normalize=True)
# Out:
# Train    0.67087
# Test     0.32913
# Name: Train/Test, dtype: float64

# %%
test = train[train["Train/Test"] == "Test"]
train = train[train["Train/Test"] == "Train"]

# %%
train.shape
# Out:
# (21229, 11)

# %%
#Building a basic first model

#Mean of the target variable

train = train.set_index("id")
train.head(3)
# Out:
#       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  target  D_e [mm]  \
# id
# 0   Thompson     tube            7.00               3770.0  0.1754       NaN
# 1   Thompson     tube             NaN               6049.0 -0.0416      10.3
# 2   Thompson      NaN           13.79               2034.0  0.0335       7.7
#
#     D_h [mm]  length [mm]  chf_exp [MW/m2] Train/Test
# id
# 0       10.8        432.0              3.6      Train
# 1       10.3        762.0              6.2      Train
# 2        7.7        457.0              2.5      Train

# %%
#Start with defining the initial imputation strategy for each feature

# %%
train["author"].value_counts()
#use most frequent for author
# Out:
# Thompson        11621
# Janssen          1846
# Weatherhead      1377
# Beus             1087
# Peskov            729
# Williams          567
# Richenderfer      371
# Mortimore         130
# Kossolapov         70
# Inasaka            28
# Name: author, dtype: int64

# %%
train["geometry"].value_counts()
#Use most frequent for geometry
# Out:
# tube       14121
# annulus     2971
# plate        424
# Name: geometry, dtype: int64

# %%
train.columns.to_list()
# Out:
# ['author',
#  'geometry',
#  'pressure [MPa]',
#  'mass_flux [kg/m2-s]',
#  'target',
#  'D_e [mm]',
#  'D_h [mm]',
#  'length [mm]',
#  'chf_exp [MW/m2]',
#  'Train/Test']

# %%
#List for encoding

most_freq = ["author", 'geometry']

num_features = [
 'pressure [MPa]',
 'mass_flux [kg/m2-s]',
 'D_e [mm]',
 'D_h [mm]',
 'length [mm]',
 'chf_exp [MW/m2]']

# %%
# Define Encoders

encoders  = [ce.OneHotEncoder(),
                     ce.CatBoostEncoder(drop_invariant = True, return_df = True),
                     ce.OrdinalEncoder(drop_invariant = True),
                     ce.TargetEncoder(drop_invariant = True),
                     ce.WOEEncoder(verbose=0, cols=None, drop_invariant=False, return_df=True, 
                              handle_unknown='value', handle_missing='value', 
                              random_state=None, randomized=False, sigma=0.05, regularization=1.0)]

# %%
#Feature engineering steps for cross-validation
most_freq_pipe = Pipeline([('most_freq', SimpleImputer(strategy = "most_frequent")), ("one_hot",ce.OneHotEncoder() )])

num_mean_imputation =  Pipeline([('mean',SimpleImputer(strategy = "mean")),("standard_scsaler", StandardScaler())])                        
                           
                           
#Preprocessing pipeline
preprocessor = ColumnTransformer([('most_freq', most_freq_pipe, most_freq), ('mean_impute', num_mean_imputation, num_features)])

# %%
#Feature pipeline with KNN for numerical features

num_knn_imputation = Pipeline([('knn',KNNImputer(n_neighbors=8, weights='uniform', metric='nan_euclidean')),("standard_scsaler", StandardScaler())])
preprocessor_knn = ColumnTransformer([('most_freq', most_freq_pipe, most_freq), ('knn_impute', num_knn_imputation, num_features)])

# %%
#Define the model
#Define models

models = {
            "xgb": xgb.XGBRegressor(),
            #"xgb_exact": xgb.XGBRegressor(**xgb_exact_params),
            #"xgb_approx": xgb.XGBRegressor(**xgb_approx_params),
            "lgb": lgb.LGBMRegressor(),
            #"lgb2": lgb.LGBMRegressor(**lgb2_params),
            #"lgb3": lgb.LGBMRegressor(**lgb3_params),
            "cat": CatBoostRegressor(),
            #"cat2": CatBoostRegressor(**cb2_params),
           # "cat3": CatBoostRegressor(**cb3_params),
            #"cat_sym": CatBoostRegressor(**cb_sym_params),
            #"cat_loss": CatBoostRegressor(**cb_loss_params),
            #"Ridge": RidgeCV(),
            #"Lasso": LassoCV(),
            #"RandomForestRegressor": RandomForestRegressor(n_estimators=200, random_state=self.random_state, n_jobs=-1),
            #"PLSRegression": PLSRegression(n_components=10, max_iter=2000),
            #"PassiveAggressiveRegressor": PassiveAggressiveRegressor(max_iter=3000, tol=1e-3, n_iter_no_change=30, random_state=self.random_state),
            #"GradientBoostingRegressor": GradientBoostingRegressor(n_estimators=2000, learning_rate=0.05, loss="absolute_error", random_state=self.random_state),
           # "HistGradientBoostingRegressor": HistGradientBoostingRegressor(max_iter=self.n_estimators, learning_rate=0.01, loss="absolute_error", n_iter_no_change=300,random_state=self.random_state),
            #"ARDRegression": ARDRegression(n_iter=1000),
           # "HuberRegressor": HuberRegressor(max_iter=3000),
            #"KNeighborsRegressor": KNeighborsRegressor(n_neighbors=5, n_jobs=-1)
        }

# %%
#Define the cross-vlidation strategy
#Cross validation strategy
seed = 42
splits = 3
#cv = RepeatedStratifiedKFold(n_splits = splits, n_repeats = 5, random_state = seed)
cv = KFold(n_splits = splits, random_state = seed, shuffle = True)

# %%
#Create the feature matrix and the target
train_y = train[target].values
train_X = train.drop(["target", "Train/Test"], axis = 1)

# %%
train_X
# Out:
#          author geometry  pressure [MPa]  mass_flux [kg/m2-s]  D_e [mm]  \
# id
# 0      Thompson     tube            7.00               3770.0       NaN
# 1      Thompson     tube             NaN               6049.0      10.3
# 2      Thompson      NaN           13.79               2034.0       7.7
# 3          Beus  annulus           13.79               3679.0       5.6
# 5           NaN      NaN           17.24               3648.0       NaN
# ...         ...      ...             ...                  ...       ...
# 31636       NaN      NaN           12.07                  NaN       NaN
# 31638  Thompson     tube             NaN               3648.0       4.7
# 31639  Thompson      NaN             NaN               1736.0       NaN
# 31641  Thompson      NaN           18.27                658.0       3.0
# 31643       NaN     tube            6.89               7568.0      12.8
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# id
# 0          10.8        432.0              3.6
# 1          10.3        762.0              6.2
# 2           7.7        457.0              2.5
# 3          15.2       2134.0              3.0
# 5           1.9        696.0              3.6
# ...         ...          ...              ...
# 31636       1.9        152.0              5.4
# 31638       4.7        318.0              9.0
# 31639       7.8        591.0              2.3
# 31641       3.0        150.0              2.3
# 31643      12.8       1930.0              3.3
#
# [21229 rows x 8 columns]

# %%
type(train_y)
# Out:
# numpy.ndarray

# %%
train_y.shape, train_X.shape
# Out:
# ((21229,), (21229, 8))

# %%
train_X.head()
# Out:
#       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  D_e [mm]  \
# id
# 0   Thompson     tube            7.00               3770.0       NaN
# 1   Thompson     tube             NaN               6049.0      10.3
# 2   Thompson      NaN           13.79               2034.0       7.7
# 3       Beus  annulus           13.79               3679.0       5.6
# 5        NaN      NaN           17.24               3648.0       NaN
#
#     D_h [mm]  length [mm]  chf_exp [MW/m2]
# id
# 0       10.8        432.0              3.6
# 1       10.3        762.0              6.2
# 2        7.7        457.0              2.5
# 3       15.2       2134.0              3.0
# 5        1.9        696.0              3.6

# %%
#Cross-validation training loop

def cross_val_pipe(model,preprocessor = preprocessor , train_X = train_X, train_y = train_y, cv = cv, label = ''):
    
    
    #initiate prediction arrays and score lists
    train_predictions, val_predictions = np.zeros(train.shape[0]), np.zeros(train.shape[0])
   # val_predictions = np.zeros(train.shape[0]) # Validation predictions are stored in a matrix with length of the number of trainijng samples and # of preds
    train_score,val_score = [],[]
    
    
    #pipe = make_pipeline(preprocessor, model)
    
    #training model, predicting prognosis probability, and evaluating log loss
    for fold, (train_idx, val_idx) in enumerate(cv.split(train_X)):
                
        train_x= preprocessor.fit_transform(train_X.iloc[train_idx],train_y[train_idx] )
        valid_x = preprocessor.transform(train_X.iloc[val_idx])
        
        model.fit(train_x, train_y[train_idx], eval_set = [(valid_x,train_y[val_idx]),],eval_metric = "rmse" )
        
        train_pred_ = model.predict(train_x)
        val_pred_ = model.predict(valid_x)
                  
        train_predictions[train_idx] += train_pred_
        val_predictions[val_idx] += val_pred_
        
        train_score_ = mean_squared_error(train_y[train_idx], train_pred_, squared = False)
        val_score_ = mean_squared_error(train_y[val_idx], val_pred_, squared = False)
        train_score.append(train_score_)
        val_score.append(val_score_)
    
    print(f"The cross-validation score for {label} is {np.mean(val_score):.5f}")
    print(f"The standard deviation for the RMSE is {np.std(val_score):.6f}")
    return train_predictions, val_predictions, train_score, val_score

# %%
#model = xgb.XGBRegressor()
model = lgb.LGBMRegressor()

# %%
train_predictions, val_predictions, train_score, val_score = cross_val_pipe(model = model, preprocessor = preprocessor_knn, label = "LGBM")

# %%
msno.matrix(train_X)
# Out:
# <AxesSubplot: >

# %%
#Generate different feature engineering pipelines

# %%
#Fine-tune a LGBM model

num_leaf = [16,32,64,128,256, 512, 1024, 2028]
max_leaf = [4,5,6,7,8,9,10]
min_data_in_leaves_list = [20,40,60,80,100]

# %%
def manual_tune_pipe(model, train_X = train_X, train_y = train_y, params = None, cv = cv, label = ''):
    
    
    #initiate prediction arrays and score lists
    train_predictions, val_predictions = np.zeros(train.shape[0]), np.zeros(train.shape[0])
   # val_predictions = np.zeros(train.shape[0]) # Validation predictions are stored in a matrix with length of the number of trainijng samples and # of preds
    train_score,val_score = [],[]
    
    model = model.set_params(**params)
    pipe = make_pipeline(preprocessor, model)
    
    #training model, predicting prognosis probability, and evaluating log loss
    for fold, (train_idx, val_idx) in enumerate(cv.split(train_X)):
                
        pipe.fit(train_X.iloc[train_idx], train_y[train_idx])
        
        train_pred_ = pipe.predict(train_X.iloc[train_idx])
        val_pred_ = pipe.predict(train_X.iloc[val_idx])
                  
        train_predictions[train_idx] += train_pred_
        val_predictions[val_idx] += val_pred_
        
        train_score_ = mean_squared_error(train_y[train_idx], train_pred_, squared = False)
        val_score_ = mean_squared_error(train_y[val_idx], val_pred_, squared = False)
        train_score.append(train_score_)
        val_score.append(val_score_)
    
    print(f"The cross-validation score for {label} is {np.mean(val_score)}")
    print(f"The number of leaves is {params}")
    return train_predictions, val_predictions, train_score, val_score

# %%
for param in min_data_in_leaves_list:
    train_predictions, val_predictions, train_score, val_score = manual_tune_pipe(model = model, params = {"max_depth":8,"num_leaves":32,"min_data_in_leaf":60 }, label = "LGBM")

# %%
val_score

# %%
    train_predictions, val_predictions, train_score, val_score = manual_tune_pipe(model = model, params = {"max_depth":8,"num_leaves":32,"min_data_in_leaf":60 }, label = "LGBM")

# %%
np.mean(val_score)

# %%
#Optuna - Hyperparameter

#LGBM Optuna
def objective(trial):
    
    lgb_params = {
        'metric': 'rmse', 
        'random_state': 48,
        'n_estimators': 10000,
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.006,0.008,0.01,0.014,0.017,0.02]),
        'max_depth': trial.suggest_categorical('max_depth', [4,6,10,15]),
        'num_leaves' : trial.suggest_int('num_leaves', 10, 1000),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
        'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100)
}
    global train_X
    global train_y
    
    train_x, valid_x, y_train, y_valid = train_test_split(train_X, train_y, test_size=0.25, shuffle = True)
    
    #pipe.fit(train_X.iloc[train_idx], train_y[train_idx])
#     lg_train = lgb.Dataset(train_x, label = y_train)
#     lg_validation = lgb.Dataset(valid_x, label= y_valid)
#     evals_result_lgbm = {}
    
    model = lgb.LGBMRegressor(**lgb_params)
    pipe = make_pipeline(preprocessor, model)
#     model.fit(lgb_params, lg_train, 5000,
#                       valid_sets=[lg_train, lg_validation],
#                       early_stopping_rounds=100,
#                       verbose_eval=150,
#                       evals_result=evals_result_lgbm )
    pipe.fit(train_x, y_train)
    val_pred = pipe.predict(valid_x)
    val_metric = mean_squared_error(y_valid, val_pred, squared= False)
    
    return val_metric

# %%
import optuna
from optuna.integration import CatBoostPruningCallback

study = optuna.create_study( direction="minimize")
study.optimize(objective, n_trials=40 )

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %%
lgb_best_params = study.best_params

# %%
def pickle_save(object = None, file_name= "lgbm_params"):
    with open(file_name+'.pkl', 'wb') as f:  # open a text file
        pickle.dump(object, f) # serialize the list

# %%
def pickle_load(file_name= "Dummy.pkl", variable_name = "xxx"):
    with open(Path(working_dir)/file_name, 'rb') as f:  # open a text file
        variable_name = pickle.load(f) # serialize the list
        print(variable_name)

# %%
#Save the best model
pickle_save(object = lgb_best_params, file_name = "lgbm_best_params_v2")

# %%
lgb_params = {'metric': 'rmse',"random_state":42,
          'objective':'regression_l1', 
              'colsample_bytree': .4,
              "max_depth":8,
              "num_leaves":32,
          'verbosity': -1,
              'n_jobs': -1,
              "n_estimators":500,
          'learning_rate': 0.06,
              'subsample': .5,
                      'verbosity': -1}
          #             ,"early_stopping_rounds":300
         #}

# %%
final_model = lgb.LGBMRegressor(**lgb_params)

# %%
train_predictions, val_predictions, train_score, val_score = cross_val_pipe(model = final_model, label = "LGBM_tuned")
# Out:
# [1]	valid_0's rmse: 0.0994094
# [2]	valid_0's rmse: 0.0976735
# [3]	valid_0's rmse: 0.0967802
# [4]	valid_0's rmse: 0.096368
# [5]	valid_0's rmse: 0.0948485
# [6]	valid_0's rmse: 0.0938838
# [7]	valid_0's rmse: 0.0926736
# [8]	valid_0's rmse: 0.0920702
# [9]	valid_0's rmse: 0.0912894
# [10]	valid_0's rmse: 0.0910788
# [11]	valid_0's rmse: 0.0909679
# [12]	valid_0's rmse: 0.0899937
# [13]	valid_0's rmse: 0.0894188
# [14]	valid_0's rmse: 0.0889002
# [15]	valid_0's rmse: 0.0884352
# [16]	valid_0's rmse: 0.0879217
# [17]	valid_0's rmse: 0.0870795
# [18]	valid_0's rmse: 0.0863304
# [19]	valid_0's rmse: 0.0860236
# [20]	valid_0's rmse: 0.0851981
# [21]	valid_0's rmse: 0.0849259
# [22]	valid_0's rmse: 0.0845716
# [23]	valid_0's rmse: 0.084248
# [24]	valid_0's rmse: 0.0838058
# [25]	valid_0's rmse: 0.0835587
# [26]	valid_0's rmse: 0.0834068
# [27]	valid_0's rmse: 0.0829126
# [28]	valid_0's rmse: 0.0824104
# [29]	valid_0's rmse: 0.0822947
# [30]	valid_0's rmse: 0.0817085
# [31]	valid_0's rmse: 0.0814817
# [32]	valid_0's rmse: 0.0810576
# [33]	valid_0's rmse: 0.0809771
# [34]	valid_0's rmse: 0.0806575
# [35]	valid_0's rmse: 0.0805384
# [36]	valid_0's rmse: 0.0804996
# [37]	valid_0's rmse: 0.0803263
# [38]	valid_0's rmse: 0.0802201
# [39]	valid_0's rmse: 0.0799242
# [40]	valid_0's rmse: 0.0797736
# [41]	valid_0's rmse: 0.0796415
# [42]	valid_0's rmse: 0.0793375
# [43]	valid_0's rmse: 0.0792587
# [44]	valid_0's rmse: 0.0791882
# [45]	valid_0's rmse: 0.0790822
# [46]	valid_0's rmse: 0.0790213
# [47]	valid_0's rmse: 0.0789637
# [48]	valid_0's rmse: 0.0789116
# [49]	valid_0's rmse: 0.0788932
# [50]	valid_0's rmse: 0.0788647
# [51]	valid_0's rmse: 0.0788497
# [52]	valid_0's rmse: 0.078784
# [53]	valid_0's rmse: 0.0787318
# [54]	valid_0's rmse: 0.0784559
# [55]	valid_0's rmse: 0.0782048
# [56]	valid_0's rmse: 0.0781745
# [57]	valid_0's rmse: 0.078154
# [58]	valid_0's rmse: 0.0779708
# [59]	valid_0's rmse: 0.0778235
# [60]	valid_0's rmse: 0.077808
# [61]	valid_0's rmse: 0.0776643
# [62]	valid_0's rmse: 0.0776178
# [63]	valid_0's rmse: 0.0774739
# [64]	valid_0's rmse: 0.0774505
# [65]	valid_0's rmse: 0.077305
# [66]	valid_0's rmse: 0.0772057
# [67]	valid_0's rmse: 0.0771532
# [68]	valid_0's rmse: 0.0770057
# [69]	valid_0's rmse: 0.0769212
# [70]	valid_0's rmse: 0.0768749
# [71]	valid_0's rmse: 0.07684
# [72]	valid_0's rmse: 0.0767293
# [73]	valid_0's rmse: 0.0766088
# [74]	valid_0's rmse: 0.0765843
# [75]	valid_0's rmse: 0.0765734
# [76]	valid_0's rmse: 0.076572
# [77]	valid_0's rmse: 0.076565
# [78]	valid_0's rmse: 0.0765336
# [79]	valid_0's rmse: 0.0765303
# [80]	valid_0's rmse: 0.076412
# [81]	valid_0's rmse: 0.0763795
# [82]	valid_0's rmse: 0.0763804
# [83]	valid_0's rmse: 0.0763556
# [84]	valid_0's rmse: 0.0762918
# [85]	valid_0's rmse: 0.0762716
# [86]	valid_0's rmse: 0.0761811
# [87]	valid_0's rmse: 0.0761872
# [88]	valid_0's rmse: 0.0761395
# [89]	valid_0's rmse: 0.076084
# [90]	valid_0's rmse: 0.0760752
# [91]	valid_0's rmse: 0.0760583
# [92]	valid_0's rmse: 0.0760087
# [93]	valid_0's rmse: 0.0759922
# [94]	valid_0's rmse: 0.0759781
# [95]	valid_0's rmse: 0.0759535
# [96]	valid_0's rmse: 0.0759385
# [97]	valid_0's rmse: 0.0759278
# [98]	valid_0's rmse: 0.0759229
# [99]	valid_0's rmse: 0.0758692
# [100]	valid_0's rmse: 0.0758693
# [101]	valid_0's rmse: 0.0758556
# [102]	valid_0's rmse: 0.0758438
# [103]	valid_0's rmse: 0.0757767
# [104]	valid_0's rmse: 0.0757569
# [105]	valid_0's rmse: 0.0757476
# [106]	valid_0's rmse: 0.0756877
# [107]	valid_0's rmse: 0.0756657
# [108]	valid_0's rmse: 0.0756592
# [109]	valid_0's rmse: 0.0756445
# [110]	valid_0's rmse: 0.0755917
# [111]	valid_0's rmse: 0.0755932
# [112]	valid_0's rmse: 0.0755972
# [113]	valid_0's rmse: 0.0755908
# [114]	valid_0's rmse: 0.0755464
# [115]	valid_0's rmse: 0.0755394
# [116]	valid_0's rmse: 0.0755227
# [117]	valid_0's rmse: 0.075516
# [118]	valid_0's rmse: 0.0755156
# [119]	valid_0's rmse: 0.0755151
# [120]	valid_0's rmse: 0.0755061
# [121]	valid_0's rmse: 0.0754966
# [122]	valid_0's rmse: 0.0754945
# [123]	valid_0's rmse: 0.0754935
# [124]	valid_0's rmse: 0.0754945
# [125]	valid_0's rmse: 0.0754912
# [126]	valid_0's rmse: 0.0754907
# [127]	valid_0's rmse: 0.0754852
# [128]	valid_0's rmse: 0.0754537
# [129]	valid_0's rmse: 0.0754553
# [130]	valid_0's rmse: 0.0754485
# [131]	valid_0's rmse: 0.0754391
# [132]	valid_0's rmse: 0.0754349
# [133]	valid_0's rmse: 0.0753736
# [134]	valid_0's rmse: 0.0753663
# [135]	valid_0's rmse: 0.0753279
# [136]	valid_0's rmse: 0.0753302
# [137]	valid_0's rmse: 0.0753301
# [138]	valid_0's rmse: 0.0753199
# [139]	valid_0's rmse: 0.0753109
# [140]	valid_0's rmse: 0.075291
# [141]	valid_0's rmse: 0.0752859
# [142]	valid_0's rmse: 0.0752818
# [143]	valid_0's rmse: 0.0752803
# [144]	valid_0's rmse: 0.0752696
# [145]	valid_0's rmse: 0.0752598
# [146]	valid_0's rmse: 0.0752583
# [147]	valid_0's rmse: 0.0752253
# [148]	valid_0's rmse: 0.0752112
# [149]	valid_0's rmse: 0.0752106
# [150]	valid_0's rmse: 0.0751749
# [151]	valid_0's rmse: 0.0751664
# [152]	valid_0's rmse: 0.0751652
# [153]	valid_0's rmse: 0.075159
# [154]	valid_0's rmse: 0.0751578
# [155]	valid_0's rmse: 0.0751513
# [156]	valid_0's rmse: 0.0751407
# [157]	valid_0's rmse: 0.0751439
# [158]	valid_0's rmse: 0.0750957
# [159]	valid_0's rmse: 0.0750947
# [160]	valid_0's rmse: 0.0750529
# [161]	valid_0's rmse: 0.0750537
# [162]	valid_0's rmse: 0.0750335
# [163]	valid_0's rmse: 0.0750287
# [164]	valid_0's rmse: 0.0750315
# [165]	valid_0's rmse: 0.0750315
# [166]	valid_0's rmse: 0.0750183
# [167]	valid_0's rmse: 0.07502
# [168]	valid_0's rmse: 0.075012
# [169]	valid_0's rmse: 0.0749949
# [170]	valid_0's rmse: 0.0749805
# [171]	valid_0's rmse: 0.0749771
# [172]	valid_0's rmse: 0.0749628
# [173]	valid_0's rmse: 0.0749616
# [174]	valid_0's rmse: 0.074961
# [175]	valid_0's rmse: 0.0749582
# [176]	valid_0's rmse: 0.0749569
# [177]	valid_0's rmse: 0.0749592
# [178]	valid_0's rmse: 0.0749585
# [179]	valid_0's rmse: 0.0749525
# [180]	valid_0's rmse: 0.0749386
# [181]	valid_0's rmse: 0.0749398
# [182]	valid_0's rmse: 0.0749405
# [183]	valid_0's rmse: 0.0749295
# [184]	valid_0's rmse: 0.0749311
# [185]	valid_0's rmse: 0.0749314
# [186]	valid_0's rmse: 0.0749313
# [187]	valid_0's rmse: 0.0749299
# [188]	valid_0's rmse: 0.07493
# [189]	valid_0's rmse: 0.0749278
# [190]	valid_0's rmse: 0.0749246
# [191]	valid_0's rmse: 0.0748932
# [192]	valid_0's rmse: 0.0748986
# [193]	valid_0's rmse: 0.0748878
# [194]	valid_0's rmse: 0.0748838
# [195]	valid_0's rmse: 0.0748824
# [196]	valid_0's rmse: 0.0748609
# [197]	valid_0's rmse: 0.0748497
# [198]	valid_0's rmse: 0.0748501
# [199]	valid_0's rmse: 0.0748438
# [200]	valid_0's rmse: 0.0748413
# [201]	valid_0's rmse: 0.0748389
# [202]	valid_0's rmse: 0.0748347
# [203]	valid_0's rmse: 0.0748329
# [204]	valid_0's rmse: 0.0748108
# [205]	valid_0's rmse: 0.074807
# [206]	valid_0's rmse: 0.0747845
# [207]	valid_0's rmse: 0.0747827
# [208]	valid_0's rmse: 0.0747813
# [209]	valid_0's rmse: 0.0747789
# [210]	valid_0's rmse: 0.0747686
# [211]	valid_0's rmse: 0.0747435
# [212]	valid_0's rmse: 0.0747417
# [213]	valid_0's rmse: 0.0747407
# [214]	valid_0's rmse: 0.0747361
# [215]	valid_0's rmse: 0.0747339
# [216]	valid_0's rmse: 0.0747293
# [217]	valid_0's rmse: 0.0747322
# [218]	valid_0's rmse: 0.0747333
# [219]	valid_0's rmse: 0.0747304
# [220]	valid_0's rmse: 0.0747293
# [221]	valid_0's rmse: 0.0747256
# [222]	valid_0's rmse: 0.074703
# [223]	valid_0's rmse: 0.074702
# [224]	valid_0's rmse: 0.0747017
# [225]	valid_0's rmse: 0.0747008
# [226]	valid_0's rmse: 0.0747042
# [227]	valid_0's rmse: 0.074704
# [228]	valid_0's rmse: 0.0746964
# [229]	valid_0's rmse: 0.0746958
# [230]	valid_0's rmse: 0.0746922
# [231]	valid_0's rmse: 0.0746907
# [232]	valid_0's rmse: 0.0746897
# [233]	valid_0's rmse: 0.0746877
# [234]	valid_0's rmse: 0.074679
# [235]	valid_0's rmse: 0.0746773
# [236]	valid_0's rmse: 0.0746708
# [237]	valid_0's rmse: 0.0746664
# [238]	valid_0's rmse: 0.0746628
# [239]	valid_0's rmse: 0.074662
# [240]	valid_0's rmse: 0.0746625
# [241]	valid_0's rmse: 0.0746596
# [242]	valid_0's rmse: 0.074661
# [243]	valid_0's rmse: 0.0746611
# [244]	valid_0's rmse: 0.0746593
# [245]	valid_0's rmse: 0.0746544
# [246]	valid_0's rmse: 0.074652
# [247]	valid_0's rmse: 0.0746485
# [248]	valid_0's rmse: 0.0746479
# [249]	valid_0's rmse: 0.0746436
# [250]	valid_0's rmse: 0.0746441
# [251]	valid_0's rmse: 0.0746448
# [252]	valid_0's rmse: 0.0746453
# [253]	valid_0's rmse: 0.0746423
# [254]	valid_0's rmse: 0.0746445
# [255]	valid_0's rmse: 0.0746441
# [256]	valid_0's rmse: 0.0746432
# [257]	valid_0's rmse: 0.0746459
# [258]	valid_0's rmse: 0.074646
# [259]	valid_0's rmse: 0.0746446
# [260]	valid_0's rmse: 0.0746271
# [261]	valid_0's rmse: 0.0746259
# [262]	valid_0's rmse: 0.0746269
# [263]	valid_0's rmse: 0.0746277
# [264]	valid_0's rmse: 0.0746313
# [265]	valid_0's rmse: 0.0746314
# [266]	valid_0's rmse: 0.0746284
# [267]	valid_0's rmse: 0.0746263
# [268]	valid_0's rmse: 0.0746226
# [269]	valid_0's rmse: 0.0746219
# [270]	valid_0's rmse: 0.0746173
# [271]	valid_0's rmse: 0.0746164
# [272]	valid_0's rmse: 0.0746165
# [273]	valid_0's rmse: 0.0746168
# [274]	valid_0's rmse: 0.0746177
# [275]	valid_0's rmse: 0.0746158
# [276]	valid_0's rmse: 0.0746127
# [277]	valid_0's rmse: 0.074613
# [278]	valid_0's rmse: 0.0746107
# [279]	valid_0's rmse: 0.0746089
# [280]	valid_0's rmse: 0.0746092
# [281]	valid_0's rmse: 0.0746094
# [282]	valid_0's rmse: 0.0746093
# [283]	valid_0's rmse: 0.0746043
# [284]	valid_0's rmse: 0.074604
# [285]	valid_0's rmse: 0.0746069
# [286]	valid_0's rmse: 0.0746041
# [287]	valid_0's rmse: 0.0745882
# [288]	valid_0's rmse: 0.0745864
# [289]	valid_0's rmse: 0.0745723
# [290]	valid_0's rmse: 0.0745754
# [291]	valid_0's rmse: 0.0745645
# [292]	valid_0's rmse: 0.0745668
# [293]	valid_0's rmse: 0.0745679
# [294]	valid_0's rmse: 0.0745645
# [295]	valid_0's rmse: 0.0745638
# [296]	valid_0's rmse: 0.0745617
# [297]	valid_0's rmse: 0.0745562
# [298]	valid_0's rmse: 0.0745592
# [299]	valid_0's rmse: 0.0745612
# [300]	valid_0's rmse: 0.0745582
# [301]	valid_0's rmse: 0.0745597
# [302]	valid_0's rmse: 0.0745617
# [303]	valid_0's rmse: 0.0745636
# [304]	valid_0's rmse: 0.0745657
# [305]	valid_0's rmse: 0.0745666
# [306]	valid_0's rmse: 0.0745656
# [307]	valid_0's rmse: 0.0745623
# [308]	valid_0's rmse: 0.074562
# [309]	valid_0's rmse: 0.074558
# [310]	valid_0's rmse: 0.0745557
# [311]	valid_0's rmse: 0.0745567
# [312]	valid_0's rmse: 0.0745547
# [313]	valid_0's rmse: 0.0745553
# [314]	valid_0's rmse: 0.0745487
# [315]	valid_0's rmse: 0.0745479
# [316]	valid_0's rmse: 0.0745471
# [317]	valid_0's rmse: 0.0745482
# [318]	valid_0's rmse: 0.0745444
# [319]	valid_0's rmse: 0.0745423
# [320]	valid_0's rmse: 0.0745271
# [321]	valid_0's rmse: 0.0745258
# [322]	valid_0's rmse: 0.0745261
# [323]	valid_0's rmse: 0.074523
# [324]	valid_0's rmse: 0.0745237
# [325]	valid_0's rmse: 0.0745216
# [326]	valid_0's rmse: 0.0745222
# [327]	valid_0's rmse: 0.0745259
# [328]	valid_0's rmse: 0.0745259
# [329]	valid_0's rmse: 0.074527
# [330]	valid_0's rmse: 0.0745209
# [331]	valid_0's rmse: 0.07452
# [332]	valid_0's rmse: 0.0745213
# [333]	valid_0's rmse: 0.0745207
# [334]	valid_0's rmse: 0.0745205
# [335]	valid_0's rmse: 0.0745238
# [336]	valid_0's rmse: 0.0745202
# [337]	valid_0's rmse: 0.0745202
# [338]	valid_0's rmse: 0.0745176
# [339]	valid_0's rmse: 0.0745166
# [340]	valid_0's rmse: 0.0745176
# [341]	valid_0's rmse: 0.0745177
# [342]	valid_0's rmse: 0.0745179
# [343]	valid_0's rmse: 0.0745153
# [344]	valid_0's rmse: 0.0745141
# [345]	valid_0's rmse: 0.0745165
# [346]	valid_0's rmse: 0.0745167
# [347]	valid_0's rmse: 0.0745142
# [348]	valid_0's rmse: 0.0745139
# [349]	valid_0's rmse: 0.0745126
# [350]	valid_0's rmse: 0.0745114
# [351]	valid_0's rmse: 0.0745106
# [352]	valid_0's rmse: 0.0745094
# [353]	valid_0's rmse: 0.074506
# [354]	valid_0's rmse: 0.0745085
# [355]	valid_0's rmse: 0.0745102
# [356]	valid_0's rmse: 0.0745121
# [357]	valid_0's rmse: 0.0745125
# [358]	valid_0's rmse: 0.0745097
# [359]	valid_0's rmse: 0.0745106
# [360]	valid_0's rmse: 0.0745119
# [361]	valid_0's rmse: 0.0745042
# [362]	valid_0's rmse: 0.0745027
# [363]	valid_0's rmse: 0.074502
# [364]	valid_0's rmse: 0.0744915
# [365]	valid_0's rmse: 0.0744942
# [366]	valid_0's rmse: 0.0744949
# [367]	valid_0's rmse: 0.0744935
# [368]	valid_0's rmse: 0.0744941
# [369]	valid_0's rmse: 0.074488
# [370]	valid_0's rmse: 0.0744876
# [371]	valid_0's rmse: 0.0744873
# [372]	valid_0's rmse: 0.0744889
# [373]	valid_0's rmse: 0.074489
# [374]	valid_0's rmse: 0.0744902
# [375]	valid_0's rmse: 0.0744913
# [376]	valid_0's rmse: 0.0744921
# [377]	valid_0's rmse: 0.0744923
# [378]	valid_0's rmse: 0.0744926
# [379]	valid_0's rmse: 0.0744933
# [380]	valid_0's rmse: 0.0744832
# [381]	valid_0's rmse: 0.0744725
# [382]	valid_0's rmse: 0.0744751
# [383]	valid_0's rmse: 0.0744741
# [384]	valid_0's rmse: 0.0744736
# [385]	valid_0's rmse: 0.074471
# [386]	valid_0's rmse: 0.074473
# [387]	valid_0's rmse: 0.0744747
# [388]	valid_0's rmse: 0.0744782
# [389]	valid_0's rmse: 0.0744807
# [390]	valid_0's rmse: 0.0744816
# [391]	valid_0's rmse: 0.0744701
# [392]	valid_0's rmse: 0.0744678
# [393]	valid_0's rmse: 0.0744688
# [394]	valid_0's rmse: 0.0744703
# [395]	valid_0's rmse: 0.0744732
# [396]	valid_0's rmse: 0.0744729
# [397]	valid_0's rmse: 0.0744729
# [398]	valid_0's rmse: 0.0744733
# [399]	valid_0's rmse: 0.0744774
# [400]	valid_0's rmse: 0.0744753
# [401]	valid_0's rmse: 0.0744792
# [402]	valid_0's rmse: 0.0744794
# [403]	valid_0's rmse: 0.07448
# [404]	valid_0's rmse: 0.0744795
# [405]	valid_0's rmse: 0.0744766
# [406]	valid_0's rmse: 0.0744674
# [407]	valid_0's rmse: 0.0744712
# [408]	valid_0's rmse: 0.0744708
# [409]	valid_0's rmse: 0.0744717
# [410]	valid_0's rmse: 0.0744705
# [411]	valid_0's rmse: 0.0744711
# [412]	valid_0's rmse: 0.0744668
# [413]	valid_0's rmse: 0.0744674
# [414]	valid_0's rmse: 0.0744662
# [415]	valid_0's rmse: 0.0744644
# [416]	valid_0's rmse: 0.074463
# [417]	valid_0's rmse: 0.0744647
# [418]	valid_0's rmse: 0.0744613
# [419]	valid_0's rmse: 0.0744612
# [420]	valid_0's rmse: 0.0744597
# [421]	valid_0's rmse: 0.0744586
# [422]	valid_0's rmse: 0.0744576
# [423]	valid_0's rmse: 0.0744609
# [424]	valid_0's rmse: 0.0744606
# [425]	valid_0's rmse: 0.0744643
# [426]	valid_0's rmse: 0.0744638
# [427]	valid_0's rmse: 0.0744667
# [428]	valid_0's rmse: 0.0744666
# [429]	valid_0's rmse: 0.0744652
# [430]	valid_0's rmse: 0.0744636
# [431]	valid_0's rmse: 0.0744665
# [432]	valid_0's rmse: 0.0744665
# [433]	valid_0's rmse: 0.0744668
# [434]	valid_0's rmse: 0.0744618
# [435]	valid_0's rmse: 0.074459
# [436]	valid_0's rmse: 0.0744585
# [437]	valid_0's rmse: 0.0744576
# [438]	valid_0's rmse: 0.0744596
# [439]	valid_0's rmse: 0.0744582
# [440]	valid_0's rmse: 0.0744608
# [441]	valid_0's rmse: 0.074459
# [442]	valid_0's rmse: 0.0744569
# [443]	valid_0's rmse: 0.074457
# [444]	valid_0's rmse: 0.074456
# [445]	valid_0's rmse: 0.0744579
# [446]	valid_0's rmse: 0.0744567
# [447]	valid_0's rmse: 0.0744563
# [448]	valid_0's rmse: 0.0744573
# [449]	valid_0's rmse: 0.0744568
# [450]	valid_0's rmse: 0.0744572
# [451]	valid_0's rmse: 0.0744529
# [452]	valid_0's rmse: 0.0744527
# [453]	valid_0's rmse: 0.0744523
# [454]	valid_0's rmse: 0.0744547
# [455]	valid_0's rmse: 0.0744538
# [456]	valid_0's rmse: 0.0744615
# [457]	valid_0's rmse: 0.07446
# [458]	valid_0's rmse: 0.0744622
# [459]	valid_0's rmse: 0.0744547
# [460]	valid_0's rmse: 0.0744469
# [461]	valid_0's rmse: 0.0744417
# [462]	valid_0's rmse: 0.0744423
# [463]	valid_0's rmse: 0.0744452
# [464]	valid_0's rmse: 0.0744512
# [465]	valid_0's rmse: 0.0744523
# [466]	valid_0's rmse: 0.0744507
# [467]	valid_0's rmse: 0.0744535
# [468]	valid_0's rmse: 0.0744585
# [469]	valid_0's rmse: 0.0744522
# [470]	valid_0's rmse: 0.0744519
# [471]	valid_0's rmse: 0.0744519
# [472]	valid_0's rmse: 0.0744531
# [473]	valid_0's rmse: 0.0744555
# [474]	valid_0's rmse: 0.0744546
# [475]	valid_0's rmse: 0.0744554
# [476]	valid_0's rmse: 0.0744563
# [477]	valid_0's rmse: 0.0744589
# [478]	valid_0's rmse: 0.0744567
# [479]	valid_0's rmse: 0.0744545
# [480]	valid_0's rmse: 0.0744561
# [481]	valid_0's rmse: 0.0744562
# [482]	valid_0's rmse: 0.0744593
# [483]	valid_0's rmse: 0.0744578
# [484]	valid_0's rmse: 0.0744541
# [485]	valid_0's rmse: 0.0744534
# [486]	valid_0's rmse: 0.0744532
# [487]	valid_0's rmse: 0.0744544
# [488]	valid_0's rmse: 0.0744556
# [489]	valid_0's rmse: 0.0744609
# [490]	valid_0's rmse: 0.074463
# [491]	valid_0's rmse: 0.0744694
# [492]	valid_0's rmse: 0.0744698
# [493]	valid_0's rmse: 0.0744695
# [494]	valid_0's rmse: 0.0744686
# [495]	valid_0's rmse: 0.0744691
# [496]	valid_0's rmse: 0.0744679
# [497]	valid_0's rmse: 0.0744723
# [498]	valid_0's rmse: 0.0744749
# [499]	valid_0's rmse: 0.0744708
# [500]	valid_0's rmse: 0.0744708
# [1]	valid_0's rmse: 0.101133
# [2]	valid_0's rmse: 0.099486
# [3]	valid_0's rmse: 0.0985095
# [4]	valid_0's rmse: 0.097881
# [5]	valid_0's rmse: 0.0969795
# [6]	valid_0's rmse: 0.0961445
# [7]	valid_0's rmse: 0.0948253
# [8]	valid_0's rmse: 0.0941589
# [9]	valid_0's rmse: 0.0934722
# [10]	valid_0's rmse: 0.0931226
# [11]	valid_0's rmse: 0.0925643
# [12]	valid_0's rmse: 0.0914876
# [13]	valid_0's rmse: 0.0904134
# [14]	valid_0's rmse: 0.0900404
# [15]	valid_0's rmse: 0.0896209
# [16]	valid_0's rmse: 0.0886531
# [17]	valid_0's rmse: 0.0878501
# [18]	valid_0's rmse: 0.0875199
# [19]	valid_0's rmse: 0.086691
# [20]	valid_0's rmse: 0.0863969
# [21]	valid_0's rmse: 0.086001
# [22]	valid_0's rmse: 0.0858299
# [23]	valid_0's rmse: 0.0856116
# [24]	valid_0's rmse: 0.085401
# [25]	valid_0's rmse: 0.0848335
# [26]	valid_0's rmse: 0.0843081
# [27]	valid_0's rmse: 0.0841647
# [28]	valid_0's rmse: 0.0836565
# [29]	valid_0's rmse: 0.0832123
# [30]	valid_0's rmse: 0.0830636
# [31]	valid_0's rmse: 0.0826156
# [32]	valid_0's rmse: 0.0823052
# [33]	valid_0's rmse: 0.0819365
# [34]	valid_0's rmse: 0.0818387
# [35]	valid_0's rmse: 0.0817119
# [36]	valid_0's rmse: 0.0814743
# [37]	valid_0's rmse: 0.0812129
# [38]	valid_0's rmse: 0.0810801
# [39]	valid_0's rmse: 0.0807723
# [40]	valid_0's rmse: 0.0806865
# [41]	valid_0's rmse: 0.08061
# [42]	valid_0's rmse: 0.0805294
# [43]	valid_0's rmse: 0.0803859
# [44]	valid_0's rmse: 0.08031
# [45]	valid_0's rmse: 0.0802436
# [46]	valid_0's rmse: 0.0802367
# [47]	valid_0's rmse: 0.0800841
# [48]	valid_0's rmse: 0.0800252
# [49]	valid_0's rmse: 0.0799708
# [50]	valid_0's rmse: 0.0797673
# [51]	valid_0's rmse: 0.0796843
# [52]	valid_0's rmse: 0.079626
# [53]	valid_0's rmse: 0.0795865
# [54]	valid_0's rmse: 0.0794566
# [55]	valid_0's rmse: 0.0792751
# [56]	valid_0's rmse: 0.0791092
# [57]	valid_0's rmse: 0.0790096
# [58]	valid_0's rmse: 0.0789256
# [59]	valid_0's rmse: 0.0788737
# [60]	valid_0's rmse: 0.0788396
# [61]	valid_0's rmse: 0.078787
# [62]	valid_0's rmse: 0.0786922
# [63]	valid_0's rmse: 0.0785193
# [64]	valid_0's rmse: 0.0784681
# [65]	valid_0's rmse: 0.0784467
# [66]	valid_0's rmse: 0.0782912
# [67]	valid_0's rmse: 0.0782554
# [68]	valid_0's rmse: 0.0782051
# [69]	valid_0's rmse: 0.078155
# [70]	valid_0's rmse: 0.0781236
# [71]	valid_0's rmse: 0.0780977
# [72]	valid_0's rmse: 0.078063
# [73]	valid_0's rmse: 0.0780436
# [74]	valid_0's rmse: 0.078012
# [75]	valid_0's rmse: 0.0779404
# [76]	valid_0's rmse: 0.0779044
# [77]	valid_0's rmse: 0.0778766
# [78]	valid_0's rmse: 0.0778765
# [79]	valid_0's rmse: 0.077863
# [80]	valid_0's rmse: 0.0778501
# [81]	valid_0's rmse: 0.0778336
# [82]	valid_0's rmse: 0.0778123
# [83]	valid_0's rmse: 0.0777959
# [84]	valid_0's rmse: 0.0777743
# [85]	valid_0's rmse: 0.0776881
# [86]	valid_0's rmse: 0.0776252
# [87]	valid_0's rmse: 0.077552
# [88]	valid_0's rmse: 0.0775126
# [89]	valid_0's rmse: 0.077511
# [90]	valid_0's rmse: 0.0775101
# [91]	valid_0's rmse: 0.0775015
# [92]	valid_0's rmse: 0.0774948
# [93]	valid_0's rmse: 0.0774426
# [94]	valid_0's rmse: 0.0773824
# [95]	valid_0's rmse: 0.0773232
# [96]	valid_0's rmse: 0.0773125
# [97]	valid_0's rmse: 0.0773096
# [98]	valid_0's rmse: 0.077305
# [99]	valid_0's rmse: 0.0772932
# [100]	valid_0's rmse: 0.0772923
# [101]	valid_0's rmse: 0.0772834
# [102]	valid_0's rmse: 0.0772733
# [103]	valid_0's rmse: 0.0772678
# [104]	valid_0's rmse: 0.0772508
# [105]	valid_0's rmse: 0.0772369
# [106]	valid_0's rmse: 0.0772296
# [107]	valid_0's rmse: 0.0772195
# [108]	valid_0's rmse: 0.0771651
# [109]	valid_0's rmse: 0.0771595
# [110]	valid_0's rmse: 0.0771321
# [111]	valid_0's rmse: 0.0771275
# [112]	valid_0's rmse: 0.077119
# [113]	valid_0's rmse: 0.0771107
# [114]	valid_0's rmse: 0.0771104
# [115]	valid_0's rmse: 0.0770627
# [116]	valid_0's rmse: 0.0770598
# [117]	valid_0's rmse: 0.0770197
# [118]	valid_0's rmse: 0.0769961
# [119]	valid_0's rmse: 0.0769915
# [120]	valid_0's rmse: 0.0769952
# [121]	valid_0's rmse: 0.0769866
# [122]	valid_0's rmse: 0.0769722
# [123]	valid_0's rmse: 0.0769071
# [124]	valid_0's rmse: 0.0769018
# [125]	valid_0's rmse: 0.0768972
# [126]	valid_0's rmse: 0.0768795
# [127]	valid_0's rmse: 0.0768757
# [128]	valid_0's rmse: 0.0768543
# [129]	valid_0's rmse: 0.0768488
# [130]	valid_0's rmse: 0.0768394
# [131]	valid_0's rmse: 0.0768345
# [132]	valid_0's rmse: 0.0768166
# [133]	valid_0's rmse: 0.076812
# [134]	valid_0's rmse: 0.0767957
# [135]	valid_0's rmse: 0.0767919
# [136]	valid_0's rmse: 0.0767748
# [137]	valid_0's rmse: 0.0767519
# [138]	valid_0's rmse: 0.0767517
# [139]	valid_0's rmse: 0.0767449
# [140]	valid_0's rmse: 0.0767185
# [141]	valid_0's rmse: 0.0767183
# [142]	valid_0's rmse: 0.0766989
# [143]	valid_0's rmse: 0.0766913
# [144]	valid_0's rmse: 0.0766877
# [145]	valid_0's rmse: 0.0766861
# [146]	valid_0's rmse: 0.0766785
# [147]	valid_0's rmse: 0.0766765
# [148]	valid_0's rmse: 0.0766708
# [149]	valid_0's rmse: 0.0766536
# [150]	valid_0's rmse: 0.0766513
# [151]	valid_0's rmse: 0.0766428
# [152]	valid_0's rmse: 0.0766422
# [153]	valid_0's rmse: 0.0766376
# [154]	valid_0's rmse: 0.0766338
# [155]	valid_0's rmse: 0.0766283
# [156]	valid_0's rmse: 0.0766235
# [157]	valid_0's rmse: 0.0766104
# [158]	valid_0's rmse: 0.0766054
# [159]	valid_0's rmse: 0.0765984
# [160]	valid_0's rmse: 0.0765954
# [161]	valid_0's rmse: 0.0765977
# [162]	valid_0's rmse: 0.0765957
# [163]	valid_0's rmse: 0.0765757
# [164]	valid_0's rmse: 0.076574
# [165]	valid_0's rmse: 0.076572
# [166]	valid_0's rmse: 0.0765685
# [167]	valid_0's rmse: 0.0765614
# [168]	valid_0's rmse: 0.0765578
# [169]	valid_0's rmse: 0.0765401
# [170]	valid_0's rmse: 0.0765341
# [171]	valid_0's rmse: 0.0765322
# [172]	valid_0's rmse: 0.076532
# [173]	valid_0's rmse: 0.0765334
# [174]	valid_0's rmse: 0.0764981
# [175]	valid_0's rmse: 0.0765001
# [176]	valid_0's rmse: 0.0764987
# [177]	valid_0's rmse: 0.0764917
# [178]	valid_0's rmse: 0.0764755
# [179]	valid_0's rmse: 0.0764719
# [180]	valid_0's rmse: 0.0764751
# [181]	valid_0's rmse: 0.0764755
# [182]	valid_0's rmse: 0.0764672
# [183]	valid_0's rmse: 0.0764618
# [184]	valid_0's rmse: 0.0764541
# [185]	valid_0's rmse: 0.0764485
# [186]	valid_0's rmse: 0.0764459
# [187]	valid_0's rmse: 0.0764353
# [188]	valid_0's rmse: 0.0764303
# [189]	valid_0's rmse: 0.0764388
# [190]	valid_0's rmse: 0.0764153
# [191]	valid_0's rmse: 0.0764075
# [192]	valid_0's rmse: 0.0764021
# [193]	valid_0's rmse: 0.0763985
# [194]	valid_0's rmse: 0.0763975
# [195]	valid_0's rmse: 0.0763954
# [196]	valid_0's rmse: 0.0763947
# [197]	valid_0's rmse: 0.0763947
# [198]	valid_0's rmse: 0.0763923
# [199]	valid_0's rmse: 0.0763909
# [200]	valid_0's rmse: 0.0763575
# [201]	valid_0's rmse: 0.0763566
# [202]	valid_0's rmse: 0.0763539
# [203]	valid_0's rmse: 0.0763527
# [204]	valid_0's rmse: 0.07635
# [205]	valid_0's rmse: 0.0763365
# [206]	valid_0's rmse: 0.0763285
# [207]	valid_0's rmse: 0.0763271
# [208]	valid_0's rmse: 0.0763305
# [209]	valid_0's rmse: 0.0763375
# [210]	valid_0's rmse: 0.0763331
# [211]	valid_0's rmse: 0.0763175
# [212]	valid_0's rmse: 0.0763184
# [213]	valid_0's rmse: 0.0763139
# [214]	valid_0's rmse: 0.0763126
# [215]	valid_0's rmse: 0.0763036
# [216]	valid_0's rmse: 0.076304
# [217]	valid_0's rmse: 0.0763071
# [218]	valid_0's rmse: 0.0763061
# [219]	valid_0's rmse: 0.0763053
# [220]	valid_0's rmse: 0.0763024
# [221]	valid_0's rmse: 0.0762972
# [222]	valid_0's rmse: 0.0762928
# [223]	valid_0's rmse: 0.0762919
# [224]	valid_0's rmse: 0.0762907
# [225]	valid_0's rmse: 0.0762923
# [226]	valid_0's rmse: 0.0762852
# [227]	valid_0's rmse: 0.0762846
# [228]	valid_0's rmse: 0.0762834
# [229]	valid_0's rmse: 0.0762853
# [230]	valid_0's rmse: 0.0762887
# [231]	valid_0's rmse: 0.0762835
# [232]	valid_0's rmse: 0.0762835
# [233]	valid_0's rmse: 0.0762809
# [234]	valid_0's rmse: 0.0762825
# [235]	valid_0's rmse: 0.0762829
# [236]	valid_0's rmse: 0.0762818
# [237]	valid_0's rmse: 0.0762797
# [238]	valid_0's rmse: 0.0762815
# [239]	valid_0's rmse: 0.0762835
# [240]	valid_0's rmse: 0.0762823
# [241]	valid_0's rmse: 0.0762812
# [242]	valid_0's rmse: 0.0762799
# [243]	valid_0's rmse: 0.0762799
# [244]	valid_0's rmse: 0.0762793
# [245]	valid_0's rmse: 0.0762775
# [246]	valid_0's rmse: 0.076282
# [247]	valid_0's rmse: 0.0762813
# [248]	valid_0's rmse: 0.0762808
# [249]	valid_0's rmse: 0.0762744
# [250]	valid_0's rmse: 0.0762755
# [251]	valid_0's rmse: 0.0762733
# [252]	valid_0's rmse: 0.0762706
# [253]	valid_0's rmse: 0.076269
# [254]	valid_0's rmse: 0.0762699
# [255]	valid_0's rmse: 0.0762711
# [256]	valid_0's rmse: 0.0762694
# [257]	valid_0's rmse: 0.0762667
# [258]	valid_0's rmse: 0.0762674
# [259]	valid_0's rmse: 0.0762676
# [260]	valid_0's rmse: 0.0762731
# [261]	valid_0's rmse: 0.0762799
# [262]	valid_0's rmse: 0.0762803
# [263]	valid_0's rmse: 0.07628
# [264]	valid_0's rmse: 0.0762826
# [265]	valid_0's rmse: 0.0762805
# [266]	valid_0's rmse: 0.0762811
# [267]	valid_0's rmse: 0.0762812
# [268]	valid_0's rmse: 0.0762824
# [269]	valid_0's rmse: 0.0762812
# [270]	valid_0's rmse: 0.0762811
# [271]	valid_0's rmse: 0.07628
# [272]	valid_0's rmse: 0.0762765
# [273]	valid_0's rmse: 0.0762745
# [274]	valid_0's rmse: 0.0762691
# [275]	valid_0's rmse: 0.0762662
# [276]	valid_0's rmse: 0.076264
# [277]	valid_0's rmse: 0.0762634
# [278]	valid_0's rmse: 0.0762618
# [279]	valid_0's rmse: 0.076262
# [280]	valid_0's rmse: 0.0762603
# [281]	valid_0's rmse: 0.0762521
# [282]	valid_0's rmse: 0.076247
# [283]	valid_0's rmse: 0.0762429
# [284]	valid_0's rmse: 0.0762415
# [285]	valid_0's rmse: 0.0762375
# [286]	valid_0's rmse: 0.0762372
# [287]	valid_0's rmse: 0.0762357
# [288]	valid_0's rmse: 0.0762351
# [289]	valid_0's rmse: 0.0762291
# [290]	valid_0's rmse: 0.0762276
# [291]	valid_0's rmse: 0.0762276
# [292]	valid_0's rmse: 0.0762252
# [293]	valid_0's rmse: 0.0762232
# [294]	valid_0's rmse: 0.0762224
# [295]	valid_0's rmse: 0.0762219
# [296]	valid_0's rmse: 0.0762194
# [297]	valid_0's rmse: 0.0762143
# [298]	valid_0's rmse: 0.0762124
# [299]	valid_0's rmse: 0.07621
# [300]	valid_0's rmse: 0.076211
# [301]	valid_0's rmse: 0.0762083
# [302]	valid_0's rmse: 0.0762095
# [303]	valid_0's rmse: 0.0761998
# [304]	valid_0's rmse: 0.0761952
# [305]	valid_0's rmse: 0.0761939
# [306]	valid_0's rmse: 0.0761898
# [307]	valid_0's rmse: 0.0761888
# [308]	valid_0's rmse: 0.0761899
# [309]	valid_0's rmse: 0.0761912
# [310]	valid_0's rmse: 0.0761897
# [311]	valid_0's rmse: 0.0761893
# [312]	valid_0's rmse: 0.0761886
# [313]	valid_0's rmse: 0.0761823
# [314]	valid_0's rmse: 0.0761762
# [315]	valid_0's rmse: 0.0761758
# [316]	valid_0's rmse: 0.0761694
# [317]	valid_0's rmse: 0.076173
# [318]	valid_0's rmse: 0.0761695
# [319]	valid_0's rmse: 0.0761695
# [320]	valid_0's rmse: 0.0761661
# [321]	valid_0's rmse: 0.076167
# [322]	valid_0's rmse: 0.0761665
# [323]	valid_0's rmse: 0.0761636
# [324]	valid_0's rmse: 0.0761655
# [325]	valid_0's rmse: 0.0761689
# [326]	valid_0's rmse: 0.0761714
# [327]	valid_0's rmse: 0.0761708
# [328]	valid_0's rmse: 0.0761706
# [329]	valid_0's rmse: 0.0761705
# [330]	valid_0's rmse: 0.0761663
# [331]	valid_0's rmse: 0.0761635
# [332]	valid_0's rmse: 0.0761666
# [333]	valid_0's rmse: 0.0761698
# [334]	valid_0's rmse: 0.0761675
# [335]	valid_0's rmse: 0.0761675
# [336]	valid_0's rmse: 0.0761672
# [337]	valid_0's rmse: 0.076169
# [338]	valid_0's rmse: 0.0761715
# [339]	valid_0's rmse: 0.0761728
# [340]	valid_0's rmse: 0.0761746
# [341]	valid_0's rmse: 0.0761785
# [342]	valid_0's rmse: 0.0761801
# [343]	valid_0's rmse: 0.0761787
# [344]	valid_0's rmse: 0.07618
# [345]	valid_0's rmse: 0.0761804
# [346]	valid_0's rmse: 0.0761788
# [347]	valid_0's rmse: 0.0761785
# [348]	valid_0's rmse: 0.0761779
# [349]	valid_0's rmse: 0.0761775
# [350]	valid_0's rmse: 0.076179
# [351]	valid_0's rmse: 0.0761745
# [352]	valid_0's rmse: 0.0761749
# [353]	valid_0's rmse: 0.0761775
# [354]	valid_0's rmse: 0.0761801
# [355]	valid_0's rmse: 0.0761725
# [356]	valid_0's rmse: 0.0761725
# [357]	valid_0's rmse: 0.0761761
# [358]	valid_0's rmse: 0.0761772
# [359]	valid_0's rmse: 0.0761716
# [360]	valid_0's rmse: 0.0761715
# [361]	valid_0's rmse: 0.076172
# [362]	valid_0's rmse: 0.0761707
# [363]	valid_0's rmse: 0.0761703
# [364]	valid_0's rmse: 0.0761679
# [365]	valid_0's rmse: 0.0761708
# [366]	valid_0's rmse: 0.076171
# [367]	valid_0's rmse: 0.076169
# [368]	valid_0's rmse: 0.0761694
# [369]	valid_0's rmse: 0.0761684
# [370]	valid_0's rmse: 0.0761695
# [371]	valid_0's rmse: 0.0761692
# [372]	valid_0's rmse: 0.0761683
# [373]	valid_0's rmse: 0.0761662
# [374]	valid_0's rmse: 0.0761636
# [375]	valid_0's rmse: 0.0761632
# [376]	valid_0's rmse: 0.0761622
# [377]	valid_0's rmse: 0.0761631
# [378]	valid_0's rmse: 0.0761589
# [379]	valid_0's rmse: 0.0761591
# [380]	valid_0's rmse: 0.0761597
# [381]	valid_0's rmse: 0.0761588
# [382]	valid_0's rmse: 0.0761588
# [383]	valid_0's rmse: 0.0761612
# [384]	valid_0's rmse: 0.0761613
# [385]	valid_0's rmse: 0.0761601
# [386]	valid_0's rmse: 0.0761577
# [387]	valid_0's rmse: 0.0761521
# [388]	valid_0's rmse: 0.0761511
# [389]	valid_0's rmse: 0.0761508
# [390]	valid_0's rmse: 0.0761498
# [391]	valid_0's rmse: 0.0761466
# [392]	valid_0's rmse: 0.0761378
# [393]	valid_0's rmse: 0.076135
# [394]	valid_0's rmse: 0.0761361
# [395]	valid_0's rmse: 0.0761363
# [396]	valid_0's rmse: 0.0761356
# [397]	valid_0's rmse: 0.0761357
# [398]	valid_0's rmse: 0.0761336
# [399]	valid_0's rmse: 0.0761339
# [400]	valid_0's rmse: 0.0761327
# [401]	valid_0's rmse: 0.0761302
# [402]	valid_0's rmse: 0.0761272
# [403]	valid_0's rmse: 0.0761279
# [404]	valid_0's rmse: 0.0761282
# [405]	valid_0's rmse: 0.0761277
# [406]	valid_0's rmse: 0.0761294
# [407]	valid_0's rmse: 0.07613
# [408]	valid_0's rmse: 0.076128
# [409]	valid_0's rmse: 0.0761273
# [410]	valid_0's rmse: 0.0761258
# [411]	valid_0's rmse: 0.0761238
# [412]	valid_0's rmse: 0.0761247
# [413]	valid_0's rmse: 0.0761234
# [414]	valid_0's rmse: 0.0761248
# [415]	valid_0's rmse: 0.0761243
# [416]	valid_0's rmse: 0.0761251
# [417]	valid_0's rmse: 0.076126
# [418]	valid_0's rmse: 0.0761254
# [419]	valid_0's rmse: 0.0761259
# [420]	valid_0's rmse: 0.0761247
# [421]	valid_0's rmse: 0.076127
# [422]	valid_0's rmse: 0.0761259
# [423]	valid_0's rmse: 0.0761254
# [424]	valid_0's rmse: 0.0761253
# [425]	valid_0's rmse: 0.0761261
# [426]	valid_0's rmse: 0.0761263
# [427]	valid_0's rmse: 0.076123
# [428]	valid_0's rmse: 0.0761232
# [429]	valid_0's rmse: 0.0761256
# [430]	valid_0's rmse: 0.0761246
# [431]	valid_0's rmse: 0.0761243
# [432]	valid_0's rmse: 0.0761253
# [433]	valid_0's rmse: 0.0761262
# [434]	valid_0's rmse: 0.0761265
# [435]	valid_0's rmse: 0.0761262
# [436]	valid_0's rmse: 0.076127
# [437]	valid_0's rmse: 0.0761265
# [438]	valid_0's rmse: 0.0761281
# [439]	valid_0's rmse: 0.0761317
# [440]	valid_0's rmse: 0.0761337
# [441]	valid_0's rmse: 0.0761343
# [442]	valid_0's rmse: 0.0761356
# [443]	valid_0's rmse: 0.076136
# [444]	valid_0's rmse: 0.0761346
# [445]	valid_0's rmse: 0.0761327
# [446]	valid_0's rmse: 0.0761306
# [447]	valid_0's rmse: 0.0761343
# [448]	valid_0's rmse: 0.0761335
# [449]	valid_0's rmse: 0.0761331
# [450]	valid_0's rmse: 0.0761302
# [451]	valid_0's rmse: 0.0761286
# [452]	valid_0's rmse: 0.0761277
# [453]	valid_0's rmse: 0.0761294
# [454]	valid_0's rmse: 0.0761277
# [455]	valid_0's rmse: 0.0761292
# [456]	valid_0's rmse: 0.076132
# [457]	valid_0's rmse: 0.0761318
# [458]	valid_0's rmse: 0.0761322
# [459]	valid_0's rmse: 0.0761312
# [460]	valid_0's rmse: 0.0761313
# [461]	valid_0's rmse: 0.0761314
# [462]	valid_0's rmse: 0.0761315
# [463]	valid_0's rmse: 0.076135
# [464]	valid_0's rmse: 0.0761345
# [465]	valid_0's rmse: 0.0761333
# [466]	valid_0's rmse: 0.0761333
# [467]	valid_0's rmse: 0.0761334
# [468]	valid_0's rmse: 0.0761397
# [469]	valid_0's rmse: 0.0761382
# [470]	valid_0's rmse: 0.0761388
# [471]	valid_0's rmse: 0.0761369
# [472]	valid_0's rmse: 0.0761384
# [473]	valid_0's rmse: 0.0761375
# [474]	valid_0's rmse: 0.0761374
# [475]	valid_0's rmse: 0.0761376
# [476]	valid_0's rmse: 0.0761373
# [477]	valid_0's rmse: 0.0761387
# [478]	valid_0's rmse: 0.0761436
# [479]	valid_0's rmse: 0.0761437
# [480]	valid_0's rmse: 0.0761417
# [481]	valid_0's rmse: 0.0761263
# [482]	valid_0's rmse: 0.076127
# [483]	valid_0's rmse: 0.076128
# [484]	valid_0's rmse: 0.0761273
# [485]	valid_0's rmse: 0.0761253
# [486]	valid_0's rmse: 0.0761256
# [487]	valid_0's rmse: 0.0761248
# [488]	valid_0's rmse: 0.0761244
# [489]	valid_0's rmse: 0.0761228
# [490]	valid_0's rmse: 0.0761225
# [491]	valid_0's rmse: 0.076121
# [492]	valid_0's rmse: 0.0761218
# [493]	valid_0's rmse: 0.0761252
# [494]	valid_0's rmse: 0.076125
# [495]	valid_0's rmse: 0.0761274
# [496]	valid_0's rmse: 0.0761285
# [497]	valid_0's rmse: 0.076127
# [498]	valid_0's rmse: 0.0761267
# [499]	valid_0's rmse: 0.0761263
# [500]	valid_0's rmse: 0.0761283
# [1]	valid_0's rmse: 0.099794
# [2]	valid_0's rmse: 0.0980734
# [3]	valid_0's rmse: 0.0970404
# [4]	valid_0's rmse: 0.0963752
# [5]	valid_0's rmse: 0.0954721
# [6]	valid_0's rmse: 0.0946558
# [7]	valid_0's rmse: 0.0934003
# [8]	valid_0's rmse: 0.0927376
# [9]	valid_0's rmse: 0.0920659
# [10]	valid_0's rmse: 0.091548
# [11]	valid_0's rmse: 0.0909893
# [12]	valid_0's rmse: 0.0900403
# [13]	valid_0's rmse: 0.0890262
# [14]	valid_0's rmse: 0.0886101
# [15]	valid_0's rmse: 0.0881958
# [16]	valid_0's rmse: 0.0873753
# [17]	valid_0's rmse: 0.0866945
# [18]	valid_0's rmse: 0.0863383
# [19]	valid_0's rmse: 0.085612
# [20]	valid_0's rmse: 0.0853462
# [21]	valid_0's rmse: 0.084932
# [22]	valid_0's rmse: 0.0847286
# [23]	valid_0's rmse: 0.0844765
# [24]	valid_0's rmse: 0.0842307
# [25]	valid_0's rmse: 0.0836833
# [26]	valid_0's rmse: 0.0830844
# [27]	valid_0's rmse: 0.0829343
# [28]	valid_0's rmse: 0.0824754
# [29]	valid_0's rmse: 0.0820983
# [30]	valid_0's rmse: 0.0819676
# [31]	valid_0's rmse: 0.0815417
# [32]	valid_0's rmse: 0.0812181
# [33]	valid_0's rmse: 0.0809064
# [34]	valid_0's rmse: 0.0807766
# [35]	valid_0's rmse: 0.0806271
# [36]	valid_0's rmse: 0.0803584
# [37]	valid_0's rmse: 0.0801036
# [38]	valid_0's rmse: 0.0799817
# [39]	valid_0's rmse: 0.0797005
# [40]	valid_0's rmse: 0.0795903
# [41]	valid_0's rmse: 0.0794978
# [42]	valid_0's rmse: 0.0794164
# [43]	valid_0's rmse: 0.0791906
# [44]	valid_0's rmse: 0.0791176
# [45]	valid_0's rmse: 0.0790792
# [46]	valid_0's rmse: 0.0790733
# [47]	valid_0's rmse: 0.0788524
# [48]	valid_0's rmse: 0.0787866
# [49]	valid_0's rmse: 0.0787272
# [50]	valid_0's rmse: 0.0785344
# [51]	valid_0's rmse: 0.0783788
# [52]	valid_0's rmse: 0.0783098
# [53]	valid_0's rmse: 0.0782631
# [54]	valid_0's rmse: 0.0781689
# [55]	valid_0's rmse: 0.0780163
# [56]	valid_0's rmse: 0.077901
# [57]	valid_0's rmse: 0.0778196
# [58]	valid_0's rmse: 0.0777463
# [59]	valid_0's rmse: 0.0776939
# [60]	valid_0's rmse: 0.0776603
# [61]	valid_0's rmse: 0.0775845
# [62]	valid_0's rmse: 0.0774597
# [63]	valid_0's rmse: 0.0773648
# [64]	valid_0's rmse: 0.0772679
# [65]	valid_0's rmse: 0.0772529
# [66]	valid_0's rmse: 0.0771792
# [67]	valid_0's rmse: 0.0771535
# [68]	valid_0's rmse: 0.0771009
# [69]	valid_0's rmse: 0.0770712
# [70]	valid_0's rmse: 0.0770381
# [71]	valid_0's rmse: 0.0770199
# [72]	valid_0's rmse: 0.0769939
# [73]	valid_0's rmse: 0.076983
# [74]	valid_0's rmse: 0.0769613
# [75]	valid_0's rmse: 0.0768878
# [76]	valid_0's rmse: 0.0768407
# [77]	valid_0's rmse: 0.0768199
# [78]	valid_0's rmse: 0.0768212
# [79]	valid_0's rmse: 0.0767899
# [80]	valid_0's rmse: 0.0767794
# [81]	valid_0's rmse: 0.0767559
# [82]	valid_0's rmse: 0.076743
# [83]	valid_0's rmse: 0.076733
# [84]	valid_0's rmse: 0.0767267
# [85]	valid_0's rmse: 0.0766626
# [86]	valid_0's rmse: 0.0765899
# [87]	valid_0's rmse: 0.0765228
# [88]	valid_0's rmse: 0.0764684
# [89]	valid_0's rmse: 0.0764581
# [90]	valid_0's rmse: 0.0764429
# [91]	valid_0's rmse: 0.0764263
# [92]	valid_0's rmse: 0.0764103
# [93]	valid_0's rmse: 0.0763726
# [94]	valid_0's rmse: 0.0762866
# [95]	valid_0's rmse: 0.0762446
# [96]	valid_0's rmse: 0.0762331
# [97]	valid_0's rmse: 0.0762281
# [98]	valid_0's rmse: 0.0762216
# [99]	valid_0's rmse: 0.0762116
# [100]	valid_0's rmse: 0.0762028
# [101]	valid_0's rmse: 0.0761878
# [102]	valid_0's rmse: 0.076174
# [103]	valid_0's rmse: 0.0761635
# [104]	valid_0's rmse: 0.076157
# [105]	valid_0's rmse: 0.0761532
# [106]	valid_0's rmse: 0.0761461
# [107]	valid_0's rmse: 0.0761409
# [108]	valid_0's rmse: 0.0760819
# [109]	valid_0's rmse: 0.0760752
# [110]	valid_0's rmse: 0.0760337
# [111]	valid_0's rmse: 0.0760278
# [112]	valid_0's rmse: 0.0760196
# [113]	valid_0's rmse: 0.0760048
# [114]	valid_0's rmse: 0.076006
# [115]	valid_0's rmse: 0.0759794
# [116]	valid_0's rmse: 0.0759724
# [117]	valid_0's rmse: 0.0759554
# [118]	valid_0's rmse: 0.0759387
# [119]	valid_0's rmse: 0.0759353
# [120]	valid_0's rmse: 0.0759301
# [121]	valid_0's rmse: 0.0759321
# [122]	valid_0's rmse: 0.0759245
# [123]	valid_0's rmse: 0.07591
# [124]	valid_0's rmse: 0.0759043
# [125]	valid_0's rmse: 0.0759028
# [126]	valid_0's rmse: 0.0758912
# [127]	valid_0's rmse: 0.0758914
# [128]	valid_0's rmse: 0.0758788
# [129]	valid_0's rmse: 0.0758751
# [130]	valid_0's rmse: 0.0758664
# [131]	valid_0's rmse: 0.0758564
# [132]	valid_0's rmse: 0.0758338
# [133]	valid_0's rmse: 0.0758175
# [134]	valid_0's rmse: 0.0758026
# [135]	valid_0's rmse: 0.0757925
# [136]	valid_0's rmse: 0.0757822
# [137]	valid_0's rmse: 0.0757587
# [138]	valid_0's rmse: 0.0757517
# [139]	valid_0's rmse: 0.0757431
# [140]	valid_0's rmse: 0.0757257
# [141]	valid_0's rmse: 0.075715
# [142]	valid_0's rmse: 0.0757026
# [143]	valid_0's rmse: 0.0756949
# [144]	valid_0's rmse: 0.0756942
# [145]	valid_0's rmse: 0.0756821
# [146]	valid_0's rmse: 0.0756758
# [147]	valid_0's rmse: 0.075678
# [148]	valid_0's rmse: 0.0756703
# [149]	valid_0's rmse: 0.0756616
# [150]	valid_0's rmse: 0.0756564
# [151]	valid_0's rmse: 0.0756491
# [152]	valid_0's rmse: 0.0756445
# [153]	valid_0's rmse: 0.0756461
# [154]	valid_0's rmse: 0.0756401
# [155]	valid_0's rmse: 0.0756381
# [156]	valid_0's rmse: 0.0756354
# [157]	valid_0's rmse: 0.0756237
# [158]	valid_0's rmse: 0.0756197
# [159]	valid_0's rmse: 0.0756219
# [160]	valid_0's rmse: 0.0756209
# [161]	valid_0's rmse: 0.0756187
# [162]	valid_0's rmse: 0.0756106
# [163]	valid_0's rmse: 0.0756095
# [164]	valid_0's rmse: 0.075608
# [165]	valid_0's rmse: 0.0756049
# [166]	valid_0's rmse: 0.0756057
# [167]	valid_0's rmse: 0.0756092
# [168]	valid_0's rmse: 0.0756042
# [169]	valid_0's rmse: 0.0755875
# [170]	valid_0's rmse: 0.075589
# [171]	valid_0's rmse: 0.0755834
# [172]	valid_0's rmse: 0.0755835
# [173]	valid_0's rmse: 0.0755791
# [174]	valid_0's rmse: 0.07558
# [175]	valid_0's rmse: 0.0755746
# [176]	valid_0's rmse: 0.0755744
# [177]	valid_0's rmse: 0.075572
# [178]	valid_0's rmse: 0.075545
# [179]	valid_0's rmse: 0.0755389
# [180]	valid_0's rmse: 0.0755342
# [181]	valid_0's rmse: 0.0755334
# [182]	valid_0's rmse: 0.0755304
# [183]	valid_0's rmse: 0.0755332
# [184]	valid_0's rmse: 0.0755337
# [185]	valid_0's rmse: 0.0755354
# [186]	valid_0's rmse: 0.0755309
# [187]	valid_0's rmse: 0.0755255
# [188]	valid_0's rmse: 0.0755332
# [189]	valid_0's rmse: 0.0755341
# [190]	valid_0's rmse: 0.0755305
# [191]	valid_0's rmse: 0.0755308
# [192]	valid_0's rmse: 0.0755268
# [193]	valid_0's rmse: 0.0755258
# [194]	valid_0's rmse: 0.0755216
# [195]	valid_0's rmse: 0.0755154
# [196]	valid_0's rmse: 0.0755166
# [197]	valid_0's rmse: 0.0755147
# [198]	valid_0's rmse: 0.0755153
# [199]	valid_0's rmse: 0.0754974
# [200]	valid_0's rmse: 0.0754955
# [201]	valid_0's rmse: 0.0754953
# [202]	valid_0's rmse: 0.0754895
# [203]	valid_0's rmse: 0.075488
# [204]	valid_0's rmse: 0.0754877
# [205]	valid_0's rmse: 0.0754857
# [206]	valid_0's rmse: 0.075486
# [207]	valid_0's rmse: 0.0754833
# [208]	valid_0's rmse: 0.0754855
# [209]	valid_0's rmse: 0.0754875
# [210]	valid_0's rmse: 0.0754823
# [211]	valid_0's rmse: 0.0754691
# [212]	valid_0's rmse: 0.0754513
# [213]	valid_0's rmse: 0.0754448
# [214]	valid_0's rmse: 0.0754453
# [215]	valid_0's rmse: 0.0754351
# [216]	valid_0's rmse: 0.0754295
# [217]	valid_0's rmse: 0.0754338
# [218]	valid_0's rmse: 0.0754295
# [219]	valid_0's rmse: 0.0754292
# [220]	valid_0's rmse: 0.0754281
# [221]	valid_0's rmse: 0.0754245
# [222]	valid_0's rmse: 0.0754164
# [223]	valid_0's rmse: 0.0754183
# [224]	valid_0's rmse: 0.0754157
# [225]	valid_0's rmse: 0.0754185
# [226]	valid_0's rmse: 0.07542
# [227]	valid_0's rmse: 0.0754183
# [228]	valid_0's rmse: 0.0754137
# [229]	valid_0's rmse: 0.0754064
# [230]	valid_0's rmse: 0.0754058
# [231]	valid_0's rmse: 0.0754039
# [232]	valid_0's rmse: 0.0754016
# [233]	valid_0's rmse: 0.0753982
# [234]	valid_0's rmse: 0.0753959
# [235]	valid_0's rmse: 0.0753932
# [236]	valid_0's rmse: 0.0753972
# [237]	valid_0's rmse: 0.075399
# [238]	valid_0's rmse: 0.0753954
# [239]	valid_0's rmse: 0.0753944
# [240]	valid_0's rmse: 0.0753924
# [241]	valid_0's rmse: 0.0753891
# [242]	valid_0's rmse: 0.0753696
# [243]	valid_0's rmse: 0.0753673
# [244]	valid_0's rmse: 0.0753658
# [245]	valid_0's rmse: 0.0753642
# [246]	valid_0's rmse: 0.0753631
# [247]	valid_0's rmse: 0.0753618
# [248]	valid_0's rmse: 0.0753637
# [249]	valid_0's rmse: 0.075362
# [250]	valid_0's rmse: 0.0753631
# [251]	valid_0's rmse: 0.0753593
# [252]	valid_0's rmse: 0.0753611
# [253]	valid_0's rmse: 0.0753597
# [254]	valid_0's rmse: 0.0753601
# [255]	valid_0's rmse: 0.0753601
# [256]	valid_0's rmse: 0.0753572
# [257]	valid_0's rmse: 0.0753569
# [258]	valid_0's rmse: 0.0753551
# [259]	valid_0's rmse: 0.0753526
# [260]	valid_0's rmse: 0.0753464
# [261]	valid_0's rmse: 0.075342
# [262]	valid_0's rmse: 0.0753448
# [263]	valid_0's rmse: 0.0753448
# [264]	valid_0's rmse: 0.0753444
# [265]	valid_0's rmse: 0.0753401
# [266]	valid_0's rmse: 0.0753415
# [267]	valid_0's rmse: 0.0753421
# [268]	valid_0's rmse: 0.0753423
# [269]	valid_0's rmse: 0.0753426
# [270]	valid_0's rmse: 0.0753418
# [271]	valid_0's rmse: 0.0753404
# [272]	valid_0's rmse: 0.0753369
# [273]	valid_0's rmse: 0.0753325
# [274]	valid_0's rmse: 0.0753223
# [275]	valid_0's rmse: 0.0753206
# [276]	valid_0's rmse: 0.0753171
# [277]	valid_0's rmse: 0.0753161
# [278]	valid_0's rmse: 0.0753163
# [279]	valid_0's rmse: 0.0753163
# [280]	valid_0's rmse: 0.0753149
# [281]	valid_0's rmse: 0.0753148
# [282]	valid_0's rmse: 0.0753077
# [283]	valid_0's rmse: 0.0753071
# [284]	valid_0's rmse: 0.0753064
# [285]	valid_0's rmse: 0.0753073
# [286]	valid_0's rmse: 0.0753067
# [287]	valid_0's rmse: 0.075306
# [288]	valid_0's rmse: 0.0753074
# [289]	valid_0's rmse: 0.0753112
# [290]	valid_0's rmse: 0.0753155
# [291]	valid_0's rmse: 0.0753146
# [292]	valid_0's rmse: 0.0753126
# [293]	valid_0's rmse: 0.075311
# [294]	valid_0's rmse: 0.0753126
# [295]	valid_0's rmse: 0.0753093
# [296]	valid_0's rmse: 0.0753094
# [297]	valid_0's rmse: 0.0753129
# [298]	valid_0's rmse: 0.0753117
# [299]	valid_0's rmse: 0.0753135
# [300]	valid_0's rmse: 0.0753089
# [301]	valid_0's rmse: 0.0753078
# [302]	valid_0's rmse: 0.0753049
# [303]	valid_0's rmse: 0.0753041
# [304]	valid_0's rmse: 0.075305
# [305]	valid_0's rmse: 0.0753029
# [306]	valid_0's rmse: 0.075303
# [307]	valid_0's rmse: 0.0753034
# [308]	valid_0's rmse: 0.0753025
# [309]	valid_0's rmse: 0.0753037
# [310]	valid_0's rmse: 0.0753021
# [311]	valid_0's rmse: 0.0753016
# [312]	valid_0's rmse: 0.0753019
# [313]	valid_0's rmse: 0.0753028
# [314]	valid_0's rmse: 0.075304
# [315]	valid_0's rmse: 0.0753041
# [316]	valid_0's rmse: 0.0753051
# [317]	valid_0's rmse: 0.0753064
# [318]	valid_0's rmse: 0.07531
# [319]	valid_0's rmse: 0.0753093
# [320]	valid_0's rmse: 0.0753156
# [321]	valid_0's rmse: 0.0753167
# [322]	valid_0's rmse: 0.0753159
# [323]	valid_0's rmse: 0.0753139
# [324]	valid_0's rmse: 0.0753143
# [325]	valid_0's rmse: 0.0753207
# [326]	valid_0's rmse: 0.0753221
# [327]	valid_0's rmse: 0.0753199
# [328]	valid_0's rmse: 0.0753176
# [329]	valid_0's rmse: 0.0753177
# [330]	valid_0's rmse: 0.0753174
# [331]	valid_0's rmse: 0.0753164
# [332]	valid_0's rmse: 0.0753145
# [333]	valid_0's rmse: 0.0753129
# [334]	valid_0's rmse: 0.0753113
# [335]	valid_0's rmse: 0.0753156
# [336]	valid_0's rmse: 0.075316
# [337]	valid_0's rmse: 0.0753096
# [338]	valid_0's rmse: 0.0753096
# [339]	valid_0's rmse: 0.0753101
# [340]	valid_0's rmse: 0.0753125
# [341]	valid_0's rmse: 0.0753186
# [342]	valid_0's rmse: 0.0753172
# [343]	valid_0's rmse: 0.0753178
# [344]	valid_0's rmse: 0.0753152
# [345]	valid_0's rmse: 0.0753096
# [346]	valid_0's rmse: 0.0753088
# [347]	valid_0's rmse: 0.0753097
# [348]	valid_0's rmse: 0.0753081
# [349]	valid_0's rmse: 0.0753074
# [350]	valid_0's rmse: 0.0753081
# [351]	valid_0's rmse: 0.0753082
# [352]	valid_0's rmse: 0.0753088
# [353]	valid_0's rmse: 0.0753033
# [354]	valid_0's rmse: 0.0753038
# [355]	valid_0's rmse: 0.075302
# [356]	valid_0's rmse: 0.0753016
# [357]	valid_0's rmse: 0.0752973
# [358]	valid_0's rmse: 0.0752974
# [359]	valid_0's rmse: 0.0752963
# [360]	valid_0's rmse: 0.0752946
# [361]	valid_0's rmse: 0.0752924
# [362]	valid_0's rmse: 0.0752912
# [363]	valid_0's rmse: 0.0752927
# [364]	valid_0's rmse: 0.0752944
# [365]	valid_0's rmse: 0.075298
# [366]	valid_0's rmse: 0.0752969
# [367]	valid_0's rmse: 0.0752969
# [368]	valid_0's rmse: 0.0753031
# [369]	valid_0's rmse: 0.0753043
# [370]	valid_0's rmse: 0.075305
# [371]	valid_0's rmse: 0.0753032
# [372]	valid_0's rmse: 0.0753022
# [373]	valid_0's rmse: 0.0753015
# [374]	valid_0's rmse: 0.0753034
# [375]	valid_0's rmse: 0.0753038
# [376]	valid_0's rmse: 0.0753031
# [377]	valid_0's rmse: 0.0753028
# [378]	valid_0's rmse: 0.0752968
# [379]	valid_0's rmse: 0.0752954
# [380]	valid_0's rmse: 0.0752987
# [381]	valid_0's rmse: 0.0752973
# [382]	valid_0's rmse: 0.0752972
# [383]	valid_0's rmse: 0.0752978
# [384]	valid_0's rmse: 0.075296
# [385]	valid_0's rmse: 0.0752956
# [386]	valid_0's rmse: 0.0752963
# [387]	valid_0's rmse: 0.0752938
# [388]	valid_0's rmse: 0.0752938
# [389]	valid_0's rmse: 0.0752923
# [390]	valid_0's rmse: 0.0752945
# [391]	valid_0's rmse: 0.0752963
# [392]	valid_0's rmse: 0.0752983
# [393]	valid_0's rmse: 0.0752945
# [394]	valid_0's rmse: 0.0752976
# [395]	valid_0's rmse: 0.0752988
# [396]	valid_0's rmse: 0.0753023
# [397]	valid_0's rmse: 0.0753033
# [398]	valid_0's rmse: 0.0753015
# [399]	valid_0's rmse: 0.075304
# [400]	valid_0's rmse: 0.0753031
# [401]	valid_0's rmse: 0.0753034
# [402]	valid_0's rmse: 0.0753033
# [403]	valid_0's rmse: 0.0753032
# [404]	valid_0's rmse: 0.0752999
# [405]	valid_0's rmse: 0.0753036
# [406]	valid_0's rmse: 0.0753034
# [407]	valid_0's rmse: 0.0753033
# [408]	valid_0's rmse: 0.0753043
# [409]	valid_0's rmse: 0.0753046
# [410]	valid_0's rmse: 0.0753044
# [411]	valid_0's rmse: 0.0753051
# [412]	valid_0's rmse: 0.0753053
# [413]	valid_0's rmse: 0.0753047
# [414]	valid_0's rmse: 0.075306
# [415]	valid_0's rmse: 0.0753065
# [416]	valid_0's rmse: 0.0753042
# [417]	valid_0's rmse: 0.0753063
# [418]	valid_0's rmse: 0.0753072
# [419]	valid_0's rmse: 0.075307
# [420]	valid_0's rmse: 0.0753112
# [421]	valid_0's rmse: 0.0753106
# [422]	valid_0's rmse: 0.0753092
# [423]	valid_0's rmse: 0.0753073
# [424]	valid_0's rmse: 0.0753033
# [425]	valid_0's rmse: 0.0753021
# [426]	valid_0's rmse: 0.0753042
# [427]	valid_0's rmse: 0.0753046
# [428]	valid_0's rmse: 0.0753059
# [429]	valid_0's rmse: 0.0753069
# [430]	valid_0's rmse: 0.0753062
# [431]	valid_0's rmse: 0.0753071
# [432]	valid_0's rmse: 0.0753073
# [433]	valid_0's rmse: 0.0753083
# [434]	valid_0's rmse: 0.0753077
# [435]	valid_0's rmse: 0.0753076
# [436]	valid_0's rmse: 0.0753072
# [437]	valid_0's rmse: 0.075312
# [438]	valid_0's rmse: 0.0753123
# [439]	valid_0's rmse: 0.0753112
# [440]	valid_0's rmse: 0.075311
# [441]	valid_0's rmse: 0.0753108
# [442]	valid_0's rmse: 0.0753104
# [443]	valid_0's rmse: 0.0753114
# [444]	valid_0's rmse: 0.0753145
# [445]	valid_0's rmse: 0.0753141
# [446]	valid_0's rmse: 0.075315
# [447]	valid_0's rmse: 0.0753162
# [448]	valid_0's rmse: 0.0753159
# [449]	valid_0's rmse: 0.0753132
# [450]	valid_0's rmse: 0.0753192
# [451]	valid_0's rmse: 0.0753193
# [452]	valid_0's rmse: 0.0753183
# [453]	valid_0's rmse: 0.0753183
# [454]	valid_0's rmse: 0.0753178
# [455]	valid_0's rmse: 0.0753168
# [456]	valid_0's rmse: 0.0753167
# [457]	valid_0's rmse: 0.075315
# [458]	valid_0's rmse: 0.0753169
# [459]	valid_0's rmse: 0.0753188
# [460]	valid_0's rmse: 0.0753183
# [461]	valid_0's rmse: 0.0753181
# [462]	valid_0's rmse: 0.0753173
# [463]	valid_0's rmse: 0.0753183
# [464]	valid_0's rmse: 0.0753182
# [465]	valid_0's rmse: 0.0753191
# [466]	valid_0's rmse: 0.0753176
# [467]	valid_0's rmse: 0.0753175
# [468]	valid_0's rmse: 0.0753164
# [469]	valid_0's rmse: 0.0753181
# [470]	valid_0's rmse: 0.0753179
# [471]	valid_0's rmse: 0.0753134
# [472]	valid_0's rmse: 0.0753116
# [473]	valid_0's rmse: 0.0753133
# [474]	valid_0's rmse: 0.0753133
# [475]	valid_0's rmse: 0.0753113
# [476]	valid_0's rmse: 0.0753161
# [477]	valid_0's rmse: 0.0753176
# [478]	valid_0's rmse: 0.0753152
# [479]	valid_0's rmse: 0.0753142
# [480]	valid_0's rmse: 0.0753126
# [481]	valid_0's rmse: 0.0753138
# [482]	valid_0's rmse: 0.075313
# [483]	valid_0's rmse: 0.0753128
# [484]	valid_0's rmse: 0.0753107
# [485]	valid_0's rmse: 0.07531
# [486]	valid_0's rmse: 0.0753101
# [487]	valid_0's rmse: 0.0753071
# [488]	valid_0's rmse: 0.0753072
# [489]	valid_0's rmse: 0.0753062
# [490]	valid_0's rmse: 0.0753073
# [491]	valid_0's rmse: 0.0753091
# [492]	valid_0's rmse: 0.0753091
# [493]	valid_0's rmse: 0.075306
# [494]	valid_0's rmse: 0.075304
# [495]	valid_0's rmse: 0.0753042
# [496]	valid_0's rmse: 0.0753033
# [497]	valid_0's rmse: 0.0753006
# [498]	valid_0's rmse: 0.0752984
# [499]	valid_0's rmse: 0.075297
# [500]	valid_0's rmse: 0.0752982
# The cross-validation score for LGBM_tuned is 0.07530
# The standard deviation for the RMSE is 0.000677

# %%
#final_model = lgb.LGBMRegressor(**lgb_best_params)

# %%
final_model.get_params
# Out:
# <bound method LGBMModel.get_params of LGBMRegressor(colsample_bytree=0.4, learning_rate=0.06, max_depth=8,
#               metric='rmse', n_estimators=500, num_leaves=32,
#               objective='regression_l1', random_state=42, subsample=0.5,
#               verbosity=-1)>

# %%
cross_val_pipe(model = model)

# %%
#final_data = lgb.Dataset(train_X, train_y)

# %%
final_pipeline = make_pipeline(preprocessor_knn,final_model)

# %%
final_pipeline.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('most_freq',
#                                                   Pipeline(steps=[('most_freq',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('one_hot',
#                                                                    OneHotEncoder())]),
#                                                   ['author', 'geometry']),
#                                                  ('knn_impute',
#                                                   Pipeline(steps=[('knn',
#                                                                    KNNImputer(n_neighbors=8)),
#                                                                   ('standard_scsaler',
#                                                                    StandardScaler())]),
#                                                   ['pressure [MPa]',
#                                                    'mass_flux [kg/m2-s]',
#                                                    'D_e [mm]', 'D_h [mm]',
#                                                    'length [mm]',
#                                                    'chf_exp [MW/m2]'])])),
#                 ('lgbmregressor',
#                  LGBMRegressor(colsample_bytree=0.4, learning_rate=0.06,
#                                max_depth=8, metric='rmse', n_estimators=500,
#                                num_leaves=32, objective='regression_l1',
#                                random_state=42, subsample=0.5, verbosity=-1))])>

# %%
final_pipeline_fitted = final_pipeline.fit(train_X, train_y)

# %%
test_final = test.set_index("id").drop(["Train/Test", "target"], axis = 1)

# %%
predictions = pd.DataFrame(final_pipeline_fitted.predict(test_final))

# %%
index = pd.DataFrame(test_final.index)

# %%
sub = pd.concat([ index, predictions], axis="columns")
sub.columns = ["id","x_e_out [-]"]

# %%
sub.to_csv("submission_lgb_knn_9.csv", index = False)

# %%
kaggle datasets list
