# %%
###### Basic packages
import os
from pathlib import Path
import pickle

#Data and visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Validation Strategy
from sklearn.model_selection import RepeatedStratifiedKFold, StratifiedKFold, train_test_split, KFold

#Encoding
import category_encoders as ce

#Imputation
from sklearn.impute import SimpleImputer

from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler


#Metrics
from sklearn.metrics import roc_auc_score, roc_curve, log_loss, mean_squared_error

#Pipeline
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.feature_selection import SelectFromModel
from sklearn.decomposition import PCA, NMF
from sklearn.manifold import TSNE
from umap import UMAP
from scipy.cluster.hierarchy import dendrogram, ward

import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

sns.set_theme(style = 'white', palette = 'viridis')
pal = sns.color_palette('viridis')

pd.set_option('display.max_rows', 100)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Regression Models

import xgboost as xgb
import lightgbm as lgb
import xgboost as xgb
import lightgbm as lgb
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, SGDRegressor, LassoCV
from sklearn.linear_model import PassiveAggressiveRegressor, ARDRegression, RidgeCV, ElasticNetCV
from sklearn.linear_model import TheilSenRegressor, RANSACRegressor, HuberRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR, LinearSVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, ExtraTreesRegressor, HistGradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor

from sklearn.cross_decomposition import PLSRegression
from catboost import CatBoost, CatBoostRegressor, CatBoostClassifier
from catboost import Pool

# %%
# File path and files

#File Path
data_dir = "/kaggle/input/playground-series-s3e15"
train_file = "data.csv"
#test_file = "test.csv"
orig_file = "/kaggle/input/predicting-heat-flux/Data_CHF_Zhao_2020_ATE.csv"
submission_file = "sample_submission.csv"
working_dir = "/kaggle/working/"

target = "target"

# %%
# test_data = Path(data_dir)/test_file
# train_data = Path(data_dir)/train_file
# submission_data = Path(data_dir)/submission_file

# %%
#train = pd.read_csv("/kaggle/input/playground-series-s3e15/data.csv")
# test = pd.read_csv(test_data)
# submission_df = pd.read_csv(submission_data)

# %%
def get_data(data_dir = data_dir,train_file = train_file,  submission_file = submission_file):
    #test_data = Path(data_dir)/test_file
    train_data = Path(data_dir)/train_file
    orig_data = Path(orig_file)
    submission_data = Path(data_dir)/submission_file
    train = pd.read_csv(train_data)
   # test = pd.read_csv(test_data)
    orig_train = pd.read_csv(orig_data)
    submission_df = pd.read_csv(submission_data)
    return train,submission_df,orig_train

# %%
train, submission_df, orig_train = get_data()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31644 entries, 0 to 31643
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   31644 non-null  int64
#  1   author               26620 non-null  object
#  2   geometry             26144 non-null  object
#  3   pressure [MPa]       27192 non-null  float64
#  4   mass_flux [kg/m2-s]  26853 non-null  float64
#  5   x_e_out [-]          21229 non-null  float64
#  6   D_e [mm]             26156 non-null  float64
#  7   D_h [mm]             27055 non-null  float64
#  8   length [mm]          26885 non-null  float64
#  9   chf_exp [MW/m2]      31644 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.4+ MB

# %%
def create_EDA_summary (df = None):
    train_import_table = pd.DataFrame()
    train_import_table["dtype"] = df.apply(lambda x: x.dtype)
    train_import_table["NROW"] = df.shape[0]
    train_import_table["Unique_values"] = [ len(df[col].unique()) for col in df.columns]
    train_import_table["Percent_missing"] = (df.isnull().sum()/df.shape[0])*100
    
    return train_import_table

# %%
create_EDA_summary(df = train)
# Out:
#                        dtype   NROW  Unique_values  Percent_missing
# id                     int64  31644          31644         0.000000
# author                object  31644             11        15.876627
# geometry              object  31644              4        17.380862
# pressure [MPa]       float64  31644            145        14.069018
# mass_flux [kg/m2-s]  float64  31644            734        15.140311
# x_e_out [-]          float64  31644           1683        32.913032
# D_e [mm]             float64  31644             44        17.342940
# D_h [mm]             float64  31644             50        14.501959
# length [mm]          float64  31644             71        15.039186
# chf_exp [MW/m2]      float64  31644            109         0.000000

# %%
train.head()
# Out:
#    id    author geometry  pressure [MPa]  mass_flux [kg/m2-s]  x_e_out [-]  \
# 0   0  Thompson     tube            7.00               3770.0       0.1754
# 1   1  Thompson     tube             NaN               6049.0      -0.0416
# 2   2  Thompson      NaN           13.79               2034.0       0.0335
# 3   3      Beus  annulus           13.79               3679.0      -0.0279
# 4   4       NaN     tube           13.79                686.0          NaN
#
#    D_e [mm]  D_h [mm]  length [mm]  chf_exp [MW/m2]
# 0       NaN      10.8        432.0              3.6
# 1      10.3      10.3        762.0              6.2
# 2       7.7       7.7        457.0              2.5
# 3       5.6      15.2       2134.0              3.0
# 4      11.1      11.1        457.0              2.8

# %%
train.rename(columns = {'x_e_out [-]':'target'}, inplace = True)

# %%
train.describe().T
# Out:
#                        count          mean          std      min        25%  \
# id                   31644.0  15821.500000  9134.980296   0.0000  7910.7500
# pressure [MPa]       27192.0     10.640747     4.333683   0.1000     6.8900
# mass_flux [kg/m2-s]  26853.0   3068.011023  1777.032080   0.0000  1519.0000
# target               21229.0     -0.000453     0.100911  -0.8667    -0.0466
# D_e [mm]             26156.0      8.629255     5.185692   1.0000     5.0000
# D_h [mm]             27055.0     14.174330    19.838489   1.0000     5.6000
# length [mm]          26885.0    832.987391   672.299239  10.0000   318.0000
# chf_exp [MW/m2]      31644.0      3.796985     1.983991   0.8000     2.4000
#
#                             50%         75%        max
# id                   15821.5000  23732.2500  31643.000
# pressure [MPa]          11.0700     13.7900     20.680
# mass_flux [kg/m2-s]   2731.0000   4069.0000   7975.000
# target                   0.0038      0.0648      0.232
# D_e [mm]                 7.8000     10.8000     37.500
# D_h [mm]                10.0000     11.5000    120.000
# length [mm]            610.0000    914.0000   3048.000
# chf_exp [MW/m2]          3.4000      4.6000     19.300

# %%
#Create the test set to be predicted - Consists of all the missing values in the target variable
train["Train/Test"] = np.where(train["target"].isnull() == True, "Test", "Train")

# %%
train["Train/Test"].value_counts(normalize=True)
# Out:
# Train    0.67087
# Test     0.32913
# Name: Train/Test, dtype: float64

# %%
test = train[train["Train/Test"] == "Test"]
train = train[train["Train/Test"] == "Train"]

# %%
train.shape
# Out:
# (21229, 11)

# %%
#Building a basic first model

#Mean of the target variable

train = train.set_index("id")
train.head(3)
# Out:
#       author geometry  pressure [MPa]  mass_flux [kg/m2-s]  target  D_e [mm]  \
# id
# 0   Thompson     tube            7.00               3770.0  0.1754       NaN
# 1   Thompson     tube             NaN               6049.0 -0.0416      10.3
# 2   Thompson      NaN           13.79               2034.0  0.0335       7.7
#
#     D_h [mm]  length [mm]  chf_exp [MW/m2] Train/Test
# id
# 0       10.8        432.0              3.6      Train
# 1       10.3        762.0              6.2      Train
# 2        7.7        457.0              2.5      Train

# %%
#Start with defining the initial imputation strategy for each feature

# %%
train["author"].value_counts()
#use most frequent for author
# Out:
# Thompson        11621
# Janssen          1846
# Weatherhead      1377
# Beus             1087
# Peskov            729
# Williams          567
# Richenderfer      371
# Mortimore         130
# Kossolapov         70
# Inasaka            28
# Name: author, dtype: int64

# %%
train["geometry"].value_counts()
#Use most frequent for geometry
# Out:
# tube       14121
# annulus     2971
# plate        424
# Name: geometry, dtype: int64

# %%
train.columns.to_list()
# Out:
# ['author',
#  'geometry',
#  'pressure [MPa]',
#  'mass_flux [kg/m2-s]',
#  'target',
#  'D_e [mm]',
#  'D_h [mm]',
#  'length [mm]',
#  'chf_exp [MW/m2]',
#  'Train/Test']

# %%
#List for encoding

most_freq = ["author", 'geometry']

num_features = [
 'pressure [MPa]',
 'mass_flux [kg/m2-s]',
 'D_e [mm]',
 'D_h [mm]',
 'length [mm]',
 'chf_exp [MW/m2]']

# %%
# Define Encoders

encoders  = [ce.OneHotEncoder(),
                     ce.CatBoostEncoder(drop_invariant = True, return_df = True),
                     ce.OrdinalEncoder(drop_invariant = True),
                     ce.TargetEncoder(drop_invariant = True),
                     ce.WOEEncoder(verbose=0, cols=None, drop_invariant=False, return_df=True, 
                              handle_unknown='value', handle_missing='value', 
                              random_state=None, randomized=False, sigma=0.05, regularization=1.0)]

# %%
#Feature engineering steps for cross-validation
most_freq_pipe = Pipeline([('most_freq', SimpleImputer(strategy = "most_frequent")), ("one_hot",ce.OneHotEncoder() )])

num_mean_imputation =  Pipeline([('mean', SimpleImputer(strategy = "mean")),("standard_scsaler", StandardScaler())])                        
                           
                           
#Preprocessing pipeline
preprocessor = ColumnTransformer([('most_freq', most_freq_pipe, most_freq), ('mean_impute', num_mean_imputation, num_features)])

# %%
#Define the model
#Define models

models = {
            "xgb": xgb.XGBRegressor(),
            #"xgb_exact": xgb.XGBRegressor(**xgb_exact_params),
            #"xgb_approx": xgb.XGBRegressor(**xgb_approx_params),
            "lgb": lgb.LGBMRegressor(),
            #"lgb2": lgb.LGBMRegressor(**lgb2_params),
            #"lgb3": lgb.LGBMRegressor(**lgb3_params),
            "cat": CatBoostRegressor(),
            #"cat2": CatBoostRegressor(**cb2_params),
           # "cat3": CatBoostRegressor(**cb3_params),
            #"cat_sym": CatBoostRegressor(**cb_sym_params),
            #"cat_loss": CatBoostRegressor(**cb_loss_params),
            #"Ridge": RidgeCV(),
            #"Lasso": LassoCV(),
            #"RandomForestRegressor": RandomForestRegressor(n_estimators=200, random_state=self.random_state, n_jobs=-1),
            #"PLSRegression": PLSRegression(n_components=10, max_iter=2000),
            #"PassiveAggressiveRegressor": PassiveAggressiveRegressor(max_iter=3000, tol=1e-3, n_iter_no_change=30, random_state=self.random_state),
            #"GradientBoostingRegressor": GradientBoostingRegressor(n_estimators=2000, learning_rate=0.05, loss="absolute_error", random_state=self.random_state),
           # "HistGradientBoostingRegressor": HistGradientBoostingRegressor(max_iter=self.n_estimators, learning_rate=0.01, loss="absolute_error", n_iter_no_change=300,random_state=self.random_state),
            #"ARDRegression": ARDRegression(n_iter=1000),
           # "HuberRegressor": HuberRegressor(max_iter=3000),
            #"KNeighborsRegressor": KNeighborsRegressor(n_neighbors=5, n_jobs=-1)
        }

# %%
#Define the cross-vlidation strategy
#Cross validation strategy
seed = 42
splits = 3
#cv = RepeatedStratifiedKFold(n_splits = splits, n_repeats = 5, random_state = seed)
cv = KFold(n_splits = splits, random_state = seed, shuffle = True)

# %%
#Create the feature matrix and the target
train_y = train[target].values
train_X = train.drop(["target", "Train/Test"], axis = 1)

# %%
train_X
# Out:
#          author geometry  pressure [MPa]  mass_flux [kg/m2-s]  D_e [mm]  \
# id
# 0      Thompson     tube            7.00               3770.0       NaN
# 1      Thompson     tube             NaN               6049.0      10.3
# 2      Thompson      NaN           13.79               2034.0       7.7
# 3          Beus  annulus           13.79               3679.0       5.6
# 5           NaN      NaN           17.24               3648.0       NaN
# ...         ...      ...             ...                  ...       ...
# 31636       NaN      NaN           12.07                  NaN       NaN
# 31638  Thompson     tube             NaN               3648.0       4.7
# 31639  Thompson      NaN             NaN               1736.0       NaN
# 31641  Thompson      NaN           18.27                658.0       3.0
# 31643       NaN     tube            6.89               7568.0      12.8
#
#        D_h [mm]  length [mm]  chf_exp [MW/m2]
# id
# 0          10.8        432.0              3.6
# 1          10.3        762.0              6.2
# 2           7.7        457.0              2.5
# 3          15.2       2134.0              3.0
# 5           1.9        696.0              3.6
# ...         ...          ...              ...
# 31636       1.9        152.0              5.4
# 31638       4.7        318.0              9.0
# 31639       7.8        591.0              2.3
# 31641       3.0        150.0              2.3
# 31643      12.8       1930.0              3.3
#
# [21229 rows x 8 columns]

# %%
type(train_y)
# Out:
# numpy.ndarray

# %%
train_y.shape, train_X.shape
# Out:
# ((21229,), (21229, 8))

# %%
train_X.head()

# %%
#Cross-validation training loop

def cross_val_pipe(model,preprocessor = preprocessor , train_X = train_X, train_y = train_y, cv = cv, label = ''):
    
    
    #initiate prediction arrays and score lists
    train_predictions, val_predictions = np.zeros(train.shape[0]), np.zeros(train.shape[0])
   # val_predictions = np.zeros(train.shape[0]) # Validation predictions are stored in a matrix with length of the number of trainijng samples and # of preds
    train_score,val_score = [],[]
    
    
    #pipe = make_pipeline(preprocessor, model)
    
    #training model, predicting prognosis probability, and evaluating log loss
    for fold, (train_idx, val_idx) in enumerate(cv.split(train_X)):
                
        train_x= preprocessor.fit_transform(train_X.iloc[train_idx],train_y[train_idx] )
        valid_x = preprocessor.transform(train_X.iloc[val_idx])
        
        model.fit(train_x, train_y[train_idx], eval_set = [(valid_x,train_y[val_idx]),],eval_metric = "rmse" )
        
        train_pred_ = model.predict(train_x)
        val_pred_ = model.predict(valid_x)
                  
        train_predictions[train_idx] += train_pred_
        val_predictions[val_idx] += val_pred_
        
        train_score_ = mean_squared_error(train_y[train_idx], train_pred_, squared = False)
        val_score_ = mean_squared_error(train_y[val_idx], val_pred_, squared = False)
        train_score.append(train_score_)
        val_score.append(val_score_)
    
    print(f"The cross-validation score for {label} is {np.mean(val_score):.4f}")
    print(f"The standard deviation for the RMSE is {np.std(val_score):.6f}")
    return train_predictions, val_predictions, train_score, val_score

# %%
#model = xgb.XGBRegressor()
model = lgb.LGBMRegressor()

# %%
train_predictions, val_predictions, train_score, val_score = cross_val_pipe(model = model, label = "LGBM")
# Out:
# [1]	valid_0's rmse: 0.0966522	valid_0's l2: 0.00934165
# [2]	valid_0's rmse: 0.0935139	valid_0's l2: 0.00874485
# [3]	valid_0's rmse: 0.0908253	valid_0's l2: 0.00824924
# [4]	valid_0's rmse: 0.0884701	valid_0's l2: 0.00782697
# [5]	valid_0's rmse: 0.0865972	valid_0's l2: 0.00749907
# [6]	valid_0's rmse: 0.0849535	valid_0's l2: 0.0072171
# [7]	valid_0's rmse: 0.0835936	valid_0's l2: 0.0069879
# [8]	valid_0's rmse: 0.0824352	valid_0's l2: 0.00679557
# [9]	valid_0's rmse: 0.0814149	valid_0's l2: 0.00662838
# [10]	valid_0's rmse: 0.0805628	valid_0's l2: 0.00649036
# [11]	valid_0's rmse: 0.0798188	valid_0's l2: 0.00637105
# [12]	valid_0's rmse: 0.0792926	valid_0's l2: 0.00628731
# [13]	valid_0's rmse: 0.0787545	valid_0's l2: 0.00620226
# [14]	valid_0's rmse: 0.0783202	valid_0's l2: 0.00613405
# [15]	valid_0's rmse: 0.0779436	valid_0's l2: 0.0060752
# [16]	valid_0's rmse: 0.0776336	valid_0's l2: 0.00602698
# [17]	valid_0's rmse: 0.0773767	valid_0's l2: 0.00598716
# [18]	valid_0's rmse: 0.0771502	valid_0's l2: 0.00595215
# [19]	valid_0's rmse: 0.0769075	valid_0's l2: 0.00591476
# [20]	valid_0's rmse: 0.0766653	valid_0's l2: 0.00587757
# [21]	valid_0's rmse: 0.0764447	valid_0's l2: 0.0058438
# [22]	valid_0's rmse: 0.0762638	valid_0's l2: 0.00581617
# [23]	valid_0's rmse: 0.0761099	valid_0's l2: 0.00579272
# [24]	valid_0's rmse: 0.0759577	valid_0's l2: 0.00576958
# [25]	valid_0's rmse: 0.0758123	valid_0's l2: 0.0057475
# [26]	valid_0's rmse: 0.0757141	valid_0's l2: 0.00573262
# [27]	valid_0's rmse: 0.0756525	valid_0's l2: 0.00572331
# [28]	valid_0's rmse: 0.0755633	valid_0's l2: 0.00570982
# [29]	valid_0's rmse: 0.0754643	valid_0's l2: 0.00569486
# [30]	valid_0's rmse: 0.075362	valid_0's l2: 0.00567943
# [31]	valid_0's rmse: 0.0753055	valid_0's l2: 0.00567092
# [32]	valid_0's rmse: 0.075256	valid_0's l2: 0.00566347
# [33]	valid_0's rmse: 0.0752237	valid_0's l2: 0.0056586
# [34]	valid_0's rmse: 0.0751152	valid_0's l2: 0.00564229
# [35]	valid_0's rmse: 0.0750624	valid_0's l2: 0.00563437
# [36]	valid_0's rmse: 0.0750049	valid_0's l2: 0.00562573
# [37]	valid_0's rmse: 0.0749917	valid_0's l2: 0.00562376
# [38]	valid_0's rmse: 0.074926	valid_0's l2: 0.00561391
# [39]	valid_0's rmse: 0.0748849	valid_0's l2: 0.00560774
# [40]	valid_0's rmse: 0.07485	valid_0's l2: 0.00560252
# [41]	valid_0's rmse: 0.0747965	valid_0's l2: 0.00559451
# [42]	valid_0's rmse: 0.0747654	valid_0's l2: 0.00558986
# [43]	valid_0's rmse: 0.074751	valid_0's l2: 0.00558772
# [44]	valid_0's rmse: 0.0747531	valid_0's l2: 0.00558802
# [45]	valid_0's rmse: 0.0747358	valid_0's l2: 0.00558544
# [46]	valid_0's rmse: 0.0747193	valid_0's l2: 0.00558298
# [47]	valid_0's rmse: 0.0746639	valid_0's l2: 0.00557469
# [48]	valid_0's rmse: 0.0746522	valid_0's l2: 0.00557295
# [49]	valid_0's rmse: 0.0746375	valid_0's l2: 0.00557076
# [50]	valid_0's rmse: 0.0746179	valid_0's l2: 0.00556783
# [51]	valid_0's rmse: 0.0746307	valid_0's l2: 0.00556975
# [52]	valid_0's rmse: 0.0746222	valid_0's l2: 0.00556847
# [53]	valid_0's rmse: 0.0746132	valid_0's l2: 0.00556714
# [54]	valid_0's rmse: 0.0746111	valid_0's l2: 0.00556682
# [55]	valid_0's rmse: 0.0745937	valid_0's l2: 0.00556422
# [56]	valid_0's rmse: 0.0745958	valid_0's l2: 0.00556453
# [57]	valid_0's rmse: 0.0745467	valid_0's l2: 0.00555721
# [58]	valid_0's rmse: 0.0745401	valid_0's l2: 0.00555622
# [59]	valid_0's rmse: 0.0745363	valid_0's l2: 0.00555566
# [60]	valid_0's rmse: 0.0745251	valid_0's l2: 0.00555399
# [61]	valid_0's rmse: 0.0745149	valid_0's l2: 0.00555247
# [62]	valid_0's rmse: 0.074503	valid_0's l2: 0.0055507
# [63]	valid_0's rmse: 0.0744852	valid_0's l2: 0.00554804
# [64]	valid_0's rmse: 0.0744745	valid_0's l2: 0.00554645
# [65]	valid_0's rmse: 0.0744904	valid_0's l2: 0.00554883
# [66]	valid_0's rmse: 0.0744787	valid_0's l2: 0.00554707
# [67]	valid_0's rmse: 0.0744596	valid_0's l2: 0.00554423
# [68]	valid_0's rmse: 0.0744231	valid_0's l2: 0.0055388
# [69]	valid_0's rmse: 0.074409	valid_0's l2: 0.0055367
# [70]	valid_0's rmse: 0.0743914	valid_0's l2: 0.00553408
# [71]	valid_0's rmse: 0.0743835	valid_0's l2: 0.00553291
# [72]	valid_0's rmse: 0.0743848	valid_0's l2: 0.0055331
# [73]	valid_0's rmse: 0.0743798	valid_0's l2: 0.00553236
# [74]	valid_0's rmse: 0.0743694	valid_0's l2: 0.00553081
# [75]	valid_0's rmse: 0.074367	valid_0's l2: 0.00553044
# [76]	valid_0's rmse: 0.074371	valid_0's l2: 0.00553104
# [77]	valid_0's rmse: 0.0743693	valid_0's l2: 0.0055308
# [78]	valid_0's rmse: 0.0743647	valid_0's l2: 0.00553011
# [79]	valid_0's rmse: 0.0743563	valid_0's l2: 0.00552885
# [80]	valid_0's rmse: 0.0743661	valid_0's l2: 0.00553031
# [81]	valid_0's rmse: 0.0743578	valid_0's l2: 0.00552908
# [82]	valid_0's rmse: 0.0743398	valid_0's l2: 0.0055264
# [83]	valid_0's rmse: 0.0743395	valid_0's l2: 0.00552637
# [84]	valid_0's rmse: 0.0743437	valid_0's l2: 0.00552699
# [85]	valid_0's rmse: 0.0743319	valid_0's l2: 0.00552524
# [86]	valid_0's rmse: 0.0743308	valid_0's l2: 0.00552507
# [87]	valid_0's rmse: 0.0743332	valid_0's l2: 0.00552542
# [88]	valid_0's rmse: 0.0743323	valid_0's l2: 0.00552529
# [89]	valid_0's rmse: 0.0743322	valid_0's l2: 0.00552528
# [90]	valid_0's rmse: 0.074343	valid_0's l2: 0.00552688
# [91]	valid_0's rmse: 0.0743299	valid_0's l2: 0.00552493
# [92]	valid_0's rmse: 0.0743219	valid_0's l2: 0.00552374
# [93]	valid_0's rmse: 0.0743356	valid_0's l2: 0.00552578
# [94]	valid_0's rmse: 0.074325	valid_0's l2: 0.00552421
# [95]	valid_0's rmse: 0.0743199	valid_0's l2: 0.00552344
# [96]	valid_0's rmse: 0.0742977	valid_0's l2: 0.00552015
# [97]	valid_0's rmse: 0.0742983	valid_0's l2: 0.00552024
# [98]	valid_0's rmse: 0.0742933	valid_0's l2: 0.00551949
# [99]	valid_0's rmse: 0.0742942	valid_0's l2: 0.00551963
# [100]	valid_0's rmse: 0.0742817	valid_0's l2: 0.00551778
# [1]	valid_0's rmse: 0.0980576	valid_0's l2: 0.00961529
# [2]	valid_0's rmse: 0.0948507	valid_0's l2: 0.00899665
# [3]	valid_0's rmse: 0.0921373	valid_0's l2: 0.00848929
# [4]	valid_0's rmse: 0.089931	valid_0's l2: 0.00808759
# [5]	valid_0's rmse: 0.0880439	valid_0's l2: 0.00775172
# [6]	valid_0's rmse: 0.0863343	valid_0's l2: 0.0074536
# [7]	valid_0's rmse: 0.084909	valid_0's l2: 0.00720954
# [8]	valid_0's rmse: 0.0836239	valid_0's l2: 0.00699296
# [9]	valid_0's rmse: 0.0825546	valid_0's l2: 0.00681526
# [10]	valid_0's rmse: 0.0816445	valid_0's l2: 0.00666582
# [11]	valid_0's rmse: 0.0808906	valid_0's l2: 0.00654329
# [12]	valid_0's rmse: 0.0802031	valid_0's l2: 0.00643253
# [13]	valid_0's rmse: 0.0795664	valid_0's l2: 0.00633082
# [14]	valid_0's rmse: 0.0790101	valid_0's l2: 0.00624259
# [15]	valid_0's rmse: 0.0786079	valid_0's l2: 0.0061792
# [16]	valid_0's rmse: 0.0782602	valid_0's l2: 0.00612467
# [17]	valid_0's rmse: 0.077904	valid_0's l2: 0.00606903
# [18]	valid_0's rmse: 0.0776601	valid_0's l2: 0.00603109
# [19]	valid_0's rmse: 0.0774083	valid_0's l2: 0.00599205
# [20]	valid_0's rmse: 0.0771439	valid_0's l2: 0.00595119
# [21]	valid_0's rmse: 0.076942	valid_0's l2: 0.00592007
# [22]	valid_0's rmse: 0.0767025	valid_0's l2: 0.00588327
# [23]	valid_0's rmse: 0.0765292	valid_0's l2: 0.00585673
# [24]	valid_0's rmse: 0.0763417	valid_0's l2: 0.00582805
# [25]	valid_0's rmse: 0.0761904	valid_0's l2: 0.00580498
# [26]	valid_0's rmse: 0.0760796	valid_0's l2: 0.00578811
# [27]	valid_0's rmse: 0.075957	valid_0's l2: 0.00576946
# [28]	valid_0's rmse: 0.0758712	valid_0's l2: 0.00575644
# [29]	valid_0's rmse: 0.0757979	valid_0's l2: 0.00574532
# [30]	valid_0's rmse: 0.0757307	valid_0's l2: 0.00573514
# [31]	valid_0's rmse: 0.0756589	valid_0's l2: 0.00572426
# [32]	valid_0's rmse: 0.0755754	valid_0's l2: 0.00571165
# [33]	valid_0's rmse: 0.0755091	valid_0's l2: 0.00570163
# [34]	valid_0's rmse: 0.0754647	valid_0's l2: 0.00569492
# [35]	valid_0's rmse: 0.0754327	valid_0's l2: 0.00569009
# [36]	valid_0's rmse: 0.0754016	valid_0's l2: 0.0056854
# [37]	valid_0's rmse: 0.07539	valid_0's l2: 0.00568366
# [38]	valid_0's rmse: 0.0753496	valid_0's l2: 0.00567756
# [39]	valid_0's rmse: 0.075336	valid_0's l2: 0.00567551
# [40]	valid_0's rmse: 0.0752898	valid_0's l2: 0.00566855
# [41]	valid_0's rmse: 0.0752554	valid_0's l2: 0.00566337
# [42]	valid_0's rmse: 0.0752558	valid_0's l2: 0.00566344
# [43]	valid_0's rmse: 0.0752344	valid_0's l2: 0.00566022
# [44]	valid_0's rmse: 0.0752289	valid_0's l2: 0.00565939
# [45]	valid_0's rmse: 0.0752069	valid_0's l2: 0.00565608
# [46]	valid_0's rmse: 0.0751535	valid_0's l2: 0.00564805
# [47]	valid_0's rmse: 0.0751374	valid_0's l2: 0.00564562
# [48]	valid_0's rmse: 0.0751307	valid_0's l2: 0.00564463
# [49]	valid_0's rmse: 0.0751049	valid_0's l2: 0.00564074
# [50]	valid_0's rmse: 0.0751087	valid_0's l2: 0.00564132
# [51]	valid_0's rmse: 0.0751086	valid_0's l2: 0.0056413
# [52]	valid_0's rmse: 0.0750794	valid_0's l2: 0.00563691
# [53]	valid_0's rmse: 0.075069	valid_0's l2: 0.00563536
# [54]	valid_0's rmse: 0.0750628	valid_0's l2: 0.00563442
# [55]	valid_0's rmse: 0.0750514	valid_0's l2: 0.00563271
# [56]	valid_0's rmse: 0.0750339	valid_0's l2: 0.00563008
# [57]	valid_0's rmse: 0.0750344	valid_0's l2: 0.00563016
# [58]	valid_0's rmse: 0.0750092	valid_0's l2: 0.00562638
# [59]	valid_0's rmse: 0.0749905	valid_0's l2: 0.00562357
# [60]	valid_0's rmse: 0.0749798	valid_0's l2: 0.00562197
# [61]	valid_0's rmse: 0.0749691	valid_0's l2: 0.00562037
# [62]	valid_0's rmse: 0.0749563	valid_0's l2: 0.00561844
# [63]	valid_0's rmse: 0.0749581	valid_0's l2: 0.00561872
# [64]	valid_0's rmse: 0.0749426	valid_0's l2: 0.00561639
# [65]	valid_0's rmse: 0.0749193	valid_0's l2: 0.0056129
# [66]	valid_0's rmse: 0.0748951	valid_0's l2: 0.00560928
# [67]	valid_0's rmse: 0.0748971	valid_0's l2: 0.00560957
# [68]	valid_0's rmse: 0.0748972	valid_0's l2: 0.00560958
# [69]	valid_0's rmse: 0.0748738	valid_0's l2: 0.00560609
# [70]	valid_0's rmse: 0.0748835	valid_0's l2: 0.00560754
# [71]	valid_0's rmse: 0.0748776	valid_0's l2: 0.00560665
# [72]	valid_0's rmse: 0.0748634	valid_0's l2: 0.00560452
# [73]	valid_0's rmse: 0.0748348	valid_0's l2: 0.00560025
# [74]	valid_0's rmse: 0.0748429	valid_0's l2: 0.00560147
# [75]	valid_0's rmse: 0.0748303	valid_0's l2: 0.00559957
# [76]	valid_0's rmse: 0.0748376	valid_0's l2: 0.00560066
# [77]	valid_0's rmse: 0.0748292	valid_0's l2: 0.0055994
# [78]	valid_0's rmse: 0.0748338	valid_0's l2: 0.0056001
# [79]	valid_0's rmse: 0.0748375	valid_0's l2: 0.00560065
# [80]	valid_0's rmse: 0.0748401	valid_0's l2: 0.00560104
# [81]	valid_0's rmse: 0.0748219	valid_0's l2: 0.00559832
# [82]	valid_0's rmse: 0.0748338	valid_0's l2: 0.0056001
# [83]	valid_0's rmse: 0.0748208	valid_0's l2: 0.00559815
# [84]	valid_0's rmse: 0.074792	valid_0's l2: 0.00559384
# [85]	valid_0's rmse: 0.0747838	valid_0's l2: 0.00559262
# [86]	valid_0's rmse: 0.0748046	valid_0's l2: 0.00559572
# [87]	valid_0's rmse: 0.0747792	valid_0's l2: 0.00559193
# [88]	valid_0's rmse: 0.0747812	valid_0's l2: 0.00559222
# [89]	valid_0's rmse: 0.0747848	valid_0's l2: 0.00559277
# [90]	valid_0's rmse: 0.0747916	valid_0's l2: 0.00559379
# [91]	valid_0's rmse: 0.074777	valid_0's l2: 0.00559161
# [92]	valid_0's rmse: 0.0747543	valid_0's l2: 0.00558821
# [93]	valid_0's rmse: 0.0747511	valid_0's l2: 0.00558772
# [94]	valid_0's rmse: 0.0747492	valid_0's l2: 0.00558744
# [95]	valid_0's rmse: 0.0747638	valid_0's l2: 0.00558963
# [96]	valid_0's rmse: 0.0747695	valid_0's l2: 0.00559048
# [97]	valid_0's rmse: 0.0747846	valid_0's l2: 0.00559274
# [98]	valid_0's rmse: 0.0747671	valid_0's l2: 0.00559012
# [99]	valid_0's rmse: 0.0747729	valid_0's l2: 0.00559099
# [100]	valid_0's rmse: 0.0747805	valid_0's l2: 0.00559212
# [1]	valid_0's rmse: 0.0967646	valid_0's l2: 0.00936339
# [2]	valid_0's rmse: 0.0936664	valid_0's l2: 0.00877339
# [3]	valid_0's rmse: 0.0911027	valid_0's l2: 0.0082997
# [4]	valid_0's rmse: 0.0888451	valid_0's l2: 0.00789344
# [5]	valid_0's rmse: 0.0870033	valid_0's l2: 0.00756958
# [6]	valid_0's rmse: 0.0853877	valid_0's l2: 0.00729106
# [7]	valid_0's rmse: 0.0840212	valid_0's l2: 0.00705957
# [8]	valid_0's rmse: 0.082831	valid_0's l2: 0.00686098
# [9]	valid_0's rmse: 0.0818871	valid_0's l2: 0.0067055
# [10]	valid_0's rmse: 0.081026	valid_0's l2: 0.00656521
# [11]	valid_0's rmse: 0.0802699	valid_0's l2: 0.00644325
# [12]	valid_0's rmse: 0.0796587	valid_0's l2: 0.0063455
# [13]	valid_0's rmse: 0.0791327	valid_0's l2: 0.00626199
# [14]	valid_0's rmse: 0.0786585	valid_0's l2: 0.00618715
# [15]	valid_0's rmse: 0.0781739	valid_0's l2: 0.00611115
# [16]	valid_0's rmse: 0.0778038	valid_0's l2: 0.00605344
# [17]	valid_0's rmse: 0.0775864	valid_0's l2: 0.00601964
# [18]	valid_0's rmse: 0.0773264	valid_0's l2: 0.00597937
# [19]	valid_0's rmse: 0.0771346	valid_0's l2: 0.00594975
# [20]	valid_0's rmse: 0.076956	valid_0's l2: 0.00592223
# [21]	valid_0's rmse: 0.0767317	valid_0's l2: 0.00588775
# [22]	valid_0's rmse: 0.0766188	valid_0's l2: 0.00587044
# [23]	valid_0's rmse: 0.0764828	valid_0's l2: 0.00584961
# [24]	valid_0's rmse: 0.0763068	valid_0's l2: 0.00582272
# [25]	valid_0's rmse: 0.0762538	valid_0's l2: 0.00581465
# [26]	valid_0's rmse: 0.0761294	valid_0's l2: 0.00579568
# [27]	valid_0's rmse: 0.0760541	valid_0's l2: 0.00578423
# [28]	valid_0's rmse: 0.0759259	valid_0's l2: 0.00576474
# [29]	valid_0's rmse: 0.0758628	valid_0's l2: 0.00575516
# [30]	valid_0's rmse: 0.0757716	valid_0's l2: 0.00574133
# [31]	valid_0's rmse: 0.0756792	valid_0's l2: 0.00572734
# [32]	valid_0's rmse: 0.0756168	valid_0's l2: 0.00571791
# [33]	valid_0's rmse: 0.0755079	valid_0's l2: 0.00570145
# [34]	valid_0's rmse: 0.0754678	valid_0's l2: 0.00569539
# [35]	valid_0's rmse: 0.0753939	valid_0's l2: 0.00568423
# [36]	valid_0's rmse: 0.0753755	valid_0's l2: 0.00568146
# [37]	valid_0's rmse: 0.075312	valid_0's l2: 0.00567189
# [38]	valid_0's rmse: 0.0752873	valid_0's l2: 0.00566817
# [39]	valid_0's rmse: 0.0752506	valid_0's l2: 0.00566266
# [40]	valid_0's rmse: 0.0752018	valid_0's l2: 0.00565531
# [41]	valid_0's rmse: 0.0751983	valid_0's l2: 0.00565479
# [42]	valid_0's rmse: 0.0751969	valid_0's l2: 0.00565457
# [43]	valid_0's rmse: 0.0751487	valid_0's l2: 0.00564733
# [44]	valid_0's rmse: 0.0750972	valid_0's l2: 0.00563959
# [45]	valid_0's rmse: 0.0750939	valid_0's l2: 0.00563909
# [46]	valid_0's rmse: 0.0750383	valid_0's l2: 0.00563075
# [47]	valid_0's rmse: 0.075032	valid_0's l2: 0.0056298
# [48]	valid_0's rmse: 0.0750191	valid_0's l2: 0.00562786
# [49]	valid_0's rmse: 0.0750152	valid_0's l2: 0.00562727
# [50]	valid_0's rmse: 0.07501	valid_0's l2: 0.00562651
# [51]	valid_0's rmse: 0.0749995	valid_0's l2: 0.00562492
# [52]	valid_0's rmse: 0.074983	valid_0's l2: 0.00562244
# [53]	valid_0's rmse: 0.0749939	valid_0's l2: 0.00562409
# [54]	valid_0's rmse: 0.0749996	valid_0's l2: 0.00562493
# [55]	valid_0's rmse: 0.0749497	valid_0's l2: 0.00561745
# [56]	valid_0's rmse: 0.074926	valid_0's l2: 0.0056139
# [57]	valid_0's rmse: 0.074948	valid_0's l2: 0.0056172
# [58]	valid_0's rmse: 0.0749179	valid_0's l2: 0.00561269
# [59]	valid_0's rmse: 0.0748841	valid_0's l2: 0.00560762
# [60]	valid_0's rmse: 0.074875	valid_0's l2: 0.00560627
# [61]	valid_0's rmse: 0.0748721	valid_0's l2: 0.00560584
# [62]	valid_0's rmse: 0.074859	valid_0's l2: 0.00560387
# [63]	valid_0's rmse: 0.0748391	valid_0's l2: 0.00560089
# [64]	valid_0's rmse: 0.0748253	valid_0's l2: 0.00559882
# [65]	valid_0's rmse: 0.0748023	valid_0's l2: 0.00559539
# [66]	valid_0's rmse: 0.0748102	valid_0's l2: 0.00559656
# [67]	valid_0's rmse: 0.0748044	valid_0's l2: 0.00559569
# [68]	valid_0's rmse: 0.074795	valid_0's l2: 0.00559429
# [69]	valid_0's rmse: 0.0747867	valid_0's l2: 0.00559305
# [70]	valid_0's rmse: 0.0747778	valid_0's l2: 0.00559172
# [71]	valid_0's rmse: 0.0747889	valid_0's l2: 0.00559338
# [72]	valid_0's rmse: 0.0747738	valid_0's l2: 0.00559111
# [73]	valid_0's rmse: 0.0747875	valid_0's l2: 0.00559317
# [74]	valid_0's rmse: 0.0747882	valid_0's l2: 0.00559327
# [75]	valid_0's rmse: 0.0748179	valid_0's l2: 0.00559772
# [76]	valid_0's rmse: 0.0748323	valid_0's l2: 0.00559988
# [77]	valid_0's rmse: 0.0748317	valid_0's l2: 0.00559978
# [78]	valid_0's rmse: 0.0748338	valid_0's l2: 0.00560009
# [79]	valid_0's rmse: 0.0748245	valid_0's l2: 0.0055987
# [80]	valid_0's rmse: 0.0748304	valid_0's l2: 0.00559959
# [81]	valid_0's rmse: 0.0748408	valid_0's l2: 0.00560115
# [82]	valid_0's rmse: 0.0748271	valid_0's l2: 0.0055991
# [83]	valid_0's rmse: 0.0748231	valid_0's l2: 0.0055985
# [84]	valid_0's rmse: 0.0748143	valid_0's l2: 0.00559718
# [85]	valid_0's rmse: 0.0748305	valid_0's l2: 0.0055996
# [86]	valid_0's rmse: 0.0748393	valid_0's l2: 0.00560092
# [87]	valid_0's rmse: 0.0748205	valid_0's l2: 0.00559811
# [88]	valid_0's rmse: 0.0748136	valid_0's l2: 0.00559707
# [89]	valid_0's rmse: 0.0748127	valid_0's l2: 0.00559694
# [90]	valid_0's rmse: 0.0748155	valid_0's l2: 0.00559736
# [91]	valid_0's rmse: 0.0748032	valid_0's l2: 0.00559551
# [92]	valid_0's rmse: 0.0748016	valid_0's l2: 0.00559529
# [93]	valid_0's rmse: 0.0747867	valid_0's l2: 0.00559306
# [94]	valid_0's rmse: 0.0747857	valid_0's l2: 0.0055929
# [95]	valid_0's rmse: 0.0747882	valid_0's l2: 0.00559328
# [96]	valid_0's rmse: 0.0747809	valid_0's l2: 0.00559218
# [97]	valid_0's rmse: 0.0747775	valid_0's l2: 0.00559167
# [98]	valid_0's rmse: 0.0747521	valid_0's l2: 0.00558787
# [99]	valid_0's rmse: 0.0747641	valid_0's l2: 0.00558967
# [100]	valid_0's rmse: 0.0747757	valid_0's l2: 0.0055914
# The cross-validation score for LGBM is 0.0746
# The standard deviation for the RMSE is 0.000234

# %%
#Generate different feature engineering pipelines

# %%
#Fine-tune a LGBM model

num_leaf = [16,32,64,128,256, 512, 1024, 2028]
max_leaf = [4,5,6,7,8,9,10]
min_data_in_leaves_list = [20,40,60,80,100]

# %%
def manual_tune_pipe(model, train_X = train_X, train_y = train_y, params = None, cv = cv, label = ''):
    
    
    #initiate prediction arrays and score lists
    train_predictions, val_predictions = np.zeros(train.shape[0]), np.zeros(train.shape[0])
   # val_predictions = np.zeros(train.shape[0]) # Validation predictions are stored in a matrix with length of the number of trainijng samples and # of preds
    train_score,val_score = [],[]
    
    model = model.set_params(**params)
    pipe = make_pipeline(preprocessor, model)
    
    #training model, predicting prognosis probability, and evaluating log loss
    for fold, (train_idx, val_idx) in enumerate(cv.split(train_X)):
                
        pipe.fit(train_X.iloc[train_idx], train_y[train_idx])
        
        train_pred_ = pipe.predict(train_X.iloc[train_idx])
        val_pred_ = pipe.predict(train_X.iloc[val_idx])
                  
        train_predictions[train_idx] += train_pred_
        val_predictions[val_idx] += val_pred_
        
        train_score_ = mean_squared_error(train_y[train_idx], train_pred_, squared = False)
        val_score_ = mean_squared_error(train_y[val_idx], val_pred_, squared = False)
        train_score.append(train_score_)
        val_score.append(val_score_)
    
    print(f"The cross-validation score for {label} is {np.mean(val_score)}")
    print(f"The number of leaves is {params}")
    return train_predictions, val_predictions, train_score, val_score

# %%
for param in min_data_in_leaves_list:
    train_predictions, val_predictions, train_score, val_score = manual_tune_pipe(model = model, params = {"max_depth":8,"num_leaves":32,"min_data_in_leaf":60 }, label = "LGBM")

# %%
val_score

# %%
    train_predictions, val_predictions, train_score, val_score = manual_tune_pipe(model = model, params = {"max_depth":8,"num_leaves":32,"min_data_in_leaf":60 }, label = "LGBM")

# %%
np.mean(val_score)

# %%
#Optuna - Hyperparameter

#LGBM Optuna
def objective(trial):
    
    lgb_params = {
        'metric': 'rmse', 
        'random_state': 48,
        'n_estimators': 10000,
        'reg_alpha': trial.suggest_loguniform('reg_alpha', 1e-3, 10.0),
        'reg_lambda': trial.suggest_loguniform('reg_lambda', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.006,0.008,0.01,0.014,0.017,0.02]),
        'max_depth': trial.suggest_categorical('max_depth', [4,6,10,15]),
        'num_leaves' : trial.suggest_int('num_leaves', 10, 1000),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
        'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100)
}
    global train_X
    global train_y
    
    train_x, valid_x, y_train, y_valid = train_test_split(train_X, train_y, test_size=0.25, shuffle = True)
    
    #pipe.fit(train_X.iloc[train_idx], train_y[train_idx])
#     lg_train = lgb.Dataset(train_x, label = y_train)
#     lg_validation = lgb.Dataset(valid_x, label= y_valid)
#     evals_result_lgbm = {}
    
    model = lgb.LGBMRegressor(**lgb_params)
    pipe = make_pipeline(preprocessor, model)
#     model.fit(lgb_params, lg_train, 5000,
#                       valid_sets=[lg_train, lg_validation],
#                       early_stopping_rounds=100,
#                       verbose_eval=150,
#                       evals_result=evals_result_lgbm )
    pipe.fit(train_x, y_train)
    val_pred = pipe.predict(valid_x)
    val_metric = mean_squared_error(y_valid, val_pred, squared= False)
    
    return val_metric

# %%
import optuna
from optuna.integration import CatBoostPruningCallback

study = optuna.create_study( direction="minimize")
study.optimize(objective, n_trials=40 )

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))

# %%
lgb_best_params = study.best_params

# %%
def pickle_save(object = None, file_name= "lgbm_params"):
    with open(file_name+'.pkl', 'wb') as f:  # open a text file
        pickle.dump(object, f) # serialize the list

# %%
def pickle_load(file_name= "Dummy.pkl", variable_name = "xxx"):
    with open(Path(working_dir)/file_name, 'rb') as f:  # open a text file
        variable_name = pickle.load(f) # serialize the list
        print(variable_name)

# %%
#Save the best model
pickle_save(object = lgb_best_params, file_name = "lgbm_best_params_v2")

# %%
lgb_params = params = {'metric': 'rmse',"random_state":42,
          'objective':'regression_l1', 'colsample_bytree': .4, 
          'verbosity': -1,'n_jobs': -1,"n_estimators":500,
          'learning_rate': 0.06,'subsample': .5,
                      'verbosity': -1}
          #             ,"early_stopping_rounds":300
         #}

# %%
final_model = lgb.LGBMRegressor(**lgb_params)

# %%
train_predictions, val_predictions, train_score, val_score = cross_val_pipe(model = final_model, label = "LGBM_tuned")
# Out:
# [1]	valid_0's rmse: 0.0992661
# [2]	valid_0's rmse: 0.0975428
# [3]	valid_0's rmse: 0.0965484
# [4]	valid_0's rmse: 0.0960895
# [5]	valid_0's rmse: 0.0945808
# [6]	valid_0's rmse: 0.0936398
# [7]	valid_0's rmse: 0.0924438
# [8]	valid_0's rmse: 0.0917094
# [9]	valid_0's rmse: 0.0909649
# [10]	valid_0's rmse: 0.0906838
# [11]	valid_0's rmse: 0.0905765
# [12]	valid_0's rmse: 0.0896172
# [13]	valid_0's rmse: 0.0891084
# [14]	valid_0's rmse: 0.0886005
# [15]	valid_0's rmse: 0.0881448
# [16]	valid_0's rmse: 0.087628
# [17]	valid_0's rmse: 0.0867942
# [18]	valid_0's rmse: 0.0860506
# [19]	valid_0's rmse: 0.0857336
# [20]	valid_0's rmse: 0.0849321
# [21]	valid_0's rmse: 0.0846418
# [22]	valid_0's rmse: 0.0842822
# [23]	valid_0's rmse: 0.083939
# [24]	valid_0's rmse: 0.0835271
# [25]	valid_0's rmse: 0.0832848
# [26]	valid_0's rmse: 0.0831379
# [27]	valid_0's rmse: 0.0826695
# [28]	valid_0's rmse: 0.0822344
# [29]	valid_0's rmse: 0.0820911
# [30]	valid_0's rmse: 0.081512
# [31]	valid_0's rmse: 0.0812814
# [32]	valid_0's rmse: 0.0809642
# [33]	valid_0's rmse: 0.0808721
# [34]	valid_0's rmse: 0.0805426
# [35]	valid_0's rmse: 0.0804224
# [36]	valid_0's rmse: 0.0803772
# [37]	valid_0's rmse: 0.080208
# [38]	valid_0's rmse: 0.0801183
# [39]	valid_0's rmse: 0.0797966
# [40]	valid_0's rmse: 0.0796466
# [41]	valid_0's rmse: 0.0795192
# [42]	valid_0's rmse: 0.0791787
# [43]	valid_0's rmse: 0.0791218
# [44]	valid_0's rmse: 0.0790734
# [45]	valid_0's rmse: 0.0789481
# [46]	valid_0's rmse: 0.0788985
# [47]	valid_0's rmse: 0.0788491
# [48]	valid_0's rmse: 0.0788072
# [49]	valid_0's rmse: 0.0787852
# [50]	valid_0's rmse: 0.0787618
# [51]	valid_0's rmse: 0.0787417
# [52]	valid_0's rmse: 0.0786705
# [53]	valid_0's rmse: 0.0786395
# [54]	valid_0's rmse: 0.0783659
# [55]	valid_0's rmse: 0.0781115
# [56]	valid_0's rmse: 0.0780827
# [57]	valid_0's rmse: 0.0780668
# [58]	valid_0's rmse: 0.0778983
# [59]	valid_0's rmse: 0.0777464
# [60]	valid_0's rmse: 0.0777324
# [61]	valid_0's rmse: 0.0775561
# [62]	valid_0's rmse: 0.0775023
# [63]	valid_0's rmse: 0.077348
# [64]	valid_0's rmse: 0.0773259
# [65]	valid_0's rmse: 0.0771742
# [66]	valid_0's rmse: 0.0770754
# [67]	valid_0's rmse: 0.0770246
# [68]	valid_0's rmse: 0.0768559
# [69]	valid_0's rmse: 0.0767686
# [70]	valid_0's rmse: 0.0767268
# [71]	valid_0's rmse: 0.0766853
# [72]	valid_0's rmse: 0.0765893
# [73]	valid_0's rmse: 0.0764846
# [74]	valid_0's rmse: 0.076462
# [75]	valid_0's rmse: 0.0764486
# [76]	valid_0's rmse: 0.0764477
# [77]	valid_0's rmse: 0.0764387
# [78]	valid_0's rmse: 0.0764055
# [79]	valid_0's rmse: 0.0763979
# [80]	valid_0's rmse: 0.0762806
# [81]	valid_0's rmse: 0.0762116
# [82]	valid_0's rmse: 0.0762133
# [83]	valid_0's rmse: 0.0761993
# [84]	valid_0's rmse: 0.0761186
# [85]	valid_0's rmse: 0.0760927
# [86]	valid_0's rmse: 0.0760183
# [87]	valid_0's rmse: 0.076021
# [88]	valid_0's rmse: 0.0759598
# [89]	valid_0's rmse: 0.0759094
# [90]	valid_0's rmse: 0.0759106
# [91]	valid_0's rmse: 0.0758988
# [92]	valid_0's rmse: 0.0758668
# [93]	valid_0's rmse: 0.0758494
# [94]	valid_0's rmse: 0.0758375
# [95]	valid_0's rmse: 0.075819
# [96]	valid_0's rmse: 0.075805
# [97]	valid_0's rmse: 0.0757916
# [98]	valid_0's rmse: 0.0757858
# [99]	valid_0's rmse: 0.075746
# [100]	valid_0's rmse: 0.0757327
# [101]	valid_0's rmse: 0.0757245
# [102]	valid_0's rmse: 0.0757154
# [103]	valid_0's rmse: 0.0756589
# [104]	valid_0's rmse: 0.0756403
# [105]	valid_0's rmse: 0.0756377
# [106]	valid_0's rmse: 0.0756038
# [107]	valid_0's rmse: 0.0755782
# [108]	valid_0's rmse: 0.0755795
# [109]	valid_0's rmse: 0.0755653
# [110]	valid_0's rmse: 0.0754925
# [111]	valid_0's rmse: 0.0754919
# [112]	valid_0's rmse: 0.0754944
# [113]	valid_0's rmse: 0.0754878
# [114]	valid_0's rmse: 0.0754528
# [115]	valid_0's rmse: 0.0754506
# [116]	valid_0's rmse: 0.0754059
# [117]	valid_0's rmse: 0.0753987
# [118]	valid_0's rmse: 0.0753984
# [119]	valid_0's rmse: 0.0754045
# [120]	valid_0's rmse: 0.0753959
# [121]	valid_0's rmse: 0.0753905
# [122]	valid_0's rmse: 0.0753981
# [123]	valid_0's rmse: 0.0753911
# [124]	valid_0's rmse: 0.0753957
# [125]	valid_0's rmse: 0.0753939
# [126]	valid_0's rmse: 0.0753912
# [127]	valid_0's rmse: 0.0753816
# [128]	valid_0's rmse: 0.0753585
# [129]	valid_0's rmse: 0.0753563
# [130]	valid_0's rmse: 0.0753428
# [131]	valid_0's rmse: 0.0753295
# [132]	valid_0's rmse: 0.0753218
# [133]	valid_0's rmse: 0.0752609
# [134]	valid_0's rmse: 0.0752559
# [135]	valid_0's rmse: 0.075234
# [136]	valid_0's rmse: 0.0752369
# [137]	valid_0's rmse: 0.0752375
# [138]	valid_0's rmse: 0.0752349
# [139]	valid_0's rmse: 0.0752249
# [140]	valid_0's rmse: 0.0752044
# [141]	valid_0's rmse: 0.0752017
# [142]	valid_0's rmse: 0.0752027
# [143]	valid_0's rmse: 0.0751971
# [144]	valid_0's rmse: 0.0751952
# [145]	valid_0's rmse: 0.0751833
# [146]	valid_0's rmse: 0.075184
# [147]	valid_0's rmse: 0.0751631
# [148]	valid_0's rmse: 0.0751496
# [149]	valid_0's rmse: 0.0751444
# [150]	valid_0's rmse: 0.0751276
# [151]	valid_0's rmse: 0.0751216
# [152]	valid_0's rmse: 0.0751152
# [153]	valid_0's rmse: 0.0751106
# [154]	valid_0's rmse: 0.0751046
# [155]	valid_0's rmse: 0.0750962
# [156]	valid_0's rmse: 0.075084
# [157]	valid_0's rmse: 0.0750868
# [158]	valid_0's rmse: 0.0750305
# [159]	valid_0's rmse: 0.0750299
# [160]	valid_0's rmse: 0.074989
# [161]	valid_0's rmse: 0.0749859
# [162]	valid_0's rmse: 0.0749809
# [163]	valid_0's rmse: 0.0749785
# [164]	valid_0's rmse: 0.0749745
# [165]	valid_0's rmse: 0.0749714
# [166]	valid_0's rmse: 0.0749334
# [167]	valid_0's rmse: 0.0749401
# [168]	valid_0's rmse: 0.0749087
# [169]	valid_0's rmse: 0.0748987
# [170]	valid_0's rmse: 0.0748702
# [171]	valid_0's rmse: 0.0748403
# [172]	valid_0's rmse: 0.0748283
# [173]	valid_0's rmse: 0.0748277
# [174]	valid_0's rmse: 0.0748327
# [175]	valid_0's rmse: 0.0748268
# [176]	valid_0's rmse: 0.0748287
# [177]	valid_0's rmse: 0.0748304
# [178]	valid_0's rmse: 0.0748249
# [179]	valid_0's rmse: 0.074821
# [180]	valid_0's rmse: 0.0748108
# [181]	valid_0's rmse: 0.0748176
# [182]	valid_0's rmse: 0.0748203
# [183]	valid_0's rmse: 0.0748142
# [184]	valid_0's rmse: 0.0748144
# [185]	valid_0's rmse: 0.0748119
# [186]	valid_0's rmse: 0.0748118
# [187]	valid_0's rmse: 0.074808
# [188]	valid_0's rmse: 0.0748052
# [189]	valid_0's rmse: 0.0748006
# [190]	valid_0's rmse: 0.0747959
# [191]	valid_0's rmse: 0.0747975
# [192]	valid_0's rmse: 0.0747972
# [193]	valid_0's rmse: 0.0747896
# [194]	valid_0's rmse: 0.0747845
# [195]	valid_0's rmse: 0.0747933
# [196]	valid_0's rmse: 0.0747791
# [197]	valid_0's rmse: 0.0747672
# [198]	valid_0's rmse: 0.0747735
# [199]	valid_0's rmse: 0.0747722
# [200]	valid_0's rmse: 0.0747659
# [201]	valid_0's rmse: 0.0747625
# [202]	valid_0's rmse: 0.0747667
# [203]	valid_0's rmse: 0.0747664
# [204]	valid_0's rmse: 0.0747577
# [205]	valid_0's rmse: 0.0747531
# [206]	valid_0's rmse: 0.07475
# [207]	valid_0's rmse: 0.0747565
# [208]	valid_0's rmse: 0.074759
# [209]	valid_0's rmse: 0.0747605
# [210]	valid_0's rmse: 0.0747496
# [211]	valid_0's rmse: 0.074747
# [212]	valid_0's rmse: 0.0747458
# [213]	valid_0's rmse: 0.0747395
# [214]	valid_0's rmse: 0.0747383
# [215]	valid_0's rmse: 0.0747347
# [216]	valid_0's rmse: 0.0747287
# [217]	valid_0's rmse: 0.0747243
# [218]	valid_0's rmse: 0.0747247
# [219]	valid_0's rmse: 0.0747229
# [220]	valid_0's rmse: 0.0747228
# [221]	valid_0's rmse: 0.074719
# [222]	valid_0's rmse: 0.0747188
# [223]	valid_0's rmse: 0.0747191
# [224]	valid_0's rmse: 0.0747106
# [225]	valid_0's rmse: 0.074709
# [226]	valid_0's rmse: 0.0747053
# [227]	valid_0's rmse: 0.074701
# [228]	valid_0's rmse: 0.0746974
# [229]	valid_0's rmse: 0.0746965
# [230]	valid_0's rmse: 0.0746858
# [231]	valid_0's rmse: 0.0746902
# [232]	valid_0's rmse: 0.0746891
# [233]	valid_0's rmse: 0.0746757
# [234]	valid_0's rmse: 0.0746593
# [235]	valid_0's rmse: 0.0746543
# [236]	valid_0's rmse: 0.074656
# [237]	valid_0's rmse: 0.0746541
# [238]	valid_0's rmse: 0.0746522
# [239]	valid_0's rmse: 0.0746491
# [240]	valid_0's rmse: 0.0746449
# [241]	valid_0's rmse: 0.0746441
# [242]	valid_0's rmse: 0.0746405
# [243]	valid_0's rmse: 0.0746427
# [244]	valid_0's rmse: 0.0746492
# [245]	valid_0's rmse: 0.0746466
# [246]	valid_0's rmse: 0.0746418
# [247]	valid_0's rmse: 0.0746412
# [248]	valid_0's rmse: 0.0746421
# [249]	valid_0's rmse: 0.0746328
# [250]	valid_0's rmse: 0.0746338
# [251]	valid_0's rmse: 0.0746335
# [252]	valid_0's rmse: 0.0746398
# [253]	valid_0's rmse: 0.0746349
# [254]	valid_0's rmse: 0.074633
# [255]	valid_0's rmse: 0.0746352
# [256]	valid_0's rmse: 0.0746337
# [257]	valid_0's rmse: 0.0746312
# [258]	valid_0's rmse: 0.0746289
# [259]	valid_0's rmse: 0.0746304
# [260]	valid_0's rmse: 0.0746278
# [261]	valid_0's rmse: 0.0746363
# [262]	valid_0's rmse: 0.0746211
# [263]	valid_0's rmse: 0.074618
# [264]	valid_0's rmse: 0.0746187
# [265]	valid_0's rmse: 0.0746156
# [266]	valid_0's rmse: 0.0746203
# [267]	valid_0's rmse: 0.0746174
# [268]	valid_0's rmse: 0.0746127
# [269]	valid_0's rmse: 0.0746099
# [270]	valid_0's rmse: 0.0746069
# [271]	valid_0's rmse: 0.0746067
# [272]	valid_0's rmse: 0.0746048
# [273]	valid_0's rmse: 0.0746021
# [274]	valid_0's rmse: 0.0746018
# [275]	valid_0's rmse: 0.0746034
# [276]	valid_0's rmse: 0.0746009
# [277]	valid_0's rmse: 0.0746044
# [278]	valid_0's rmse: 0.0746007
# [279]	valid_0's rmse: 0.0745967
# [280]	valid_0's rmse: 0.074601
# [281]	valid_0's rmse: 0.0746001
# [282]	valid_0's rmse: 0.0745972
# [283]	valid_0's rmse: 0.0745929
# [284]	valid_0's rmse: 0.0745949
# [285]	valid_0's rmse: 0.0745951
# [286]	valid_0's rmse: 0.0746007
# [287]	valid_0's rmse: 0.0746021
# [288]	valid_0's rmse: 0.0745995
# [289]	valid_0's rmse: 0.0745983
# [290]	valid_0's rmse: 0.0745966
# [291]	valid_0's rmse: 0.0745976
# [292]	valid_0's rmse: 0.0745955
# [293]	valid_0's rmse: 0.0745955
# [294]	valid_0's rmse: 0.0745927
# [295]	valid_0's rmse: 0.0745928
# [296]	valid_0's rmse: 0.0745876
# [297]	valid_0's rmse: 0.0745881
# [298]	valid_0's rmse: 0.0745864
# [299]	valid_0's rmse: 0.0745916
# [300]	valid_0's rmse: 0.0745877
# [301]	valid_0's rmse: 0.0745877
# [302]	valid_0's rmse: 0.0745868
# [303]	valid_0's rmse: 0.0745849
# [304]	valid_0's rmse: 0.0745872
# [305]	valid_0's rmse: 0.074589
# [306]	valid_0's rmse: 0.0745831
# [307]	valid_0's rmse: 0.0745742
# [308]	valid_0's rmse: 0.0745761
# [309]	valid_0's rmse: 0.0745685
# [310]	valid_0's rmse: 0.0745667
# [311]	valid_0's rmse: 0.0745618
# [312]	valid_0's rmse: 0.0745587
# [313]	valid_0's rmse: 0.074558
# [314]	valid_0's rmse: 0.0745474
# [315]	valid_0's rmse: 0.0745471
# [316]	valid_0's rmse: 0.0745467
# [317]	valid_0's rmse: 0.0745448
# [318]	valid_0's rmse: 0.0745439
# [319]	valid_0's rmse: 0.0745388
# [320]	valid_0's rmse: 0.0745408
# [321]	valid_0's rmse: 0.0745381
# [322]	valid_0's rmse: 0.0745379
# [323]	valid_0's rmse: 0.074537
# [324]	valid_0's rmse: 0.0745374
# [325]	valid_0's rmse: 0.0745349
# [326]	valid_0's rmse: 0.0745249
# [327]	valid_0's rmse: 0.0745227
# [328]	valid_0's rmse: 0.0745257
# [329]	valid_0's rmse: 0.0745255
# [330]	valid_0's rmse: 0.0745263
# [331]	valid_0's rmse: 0.0745295
# [332]	valid_0's rmse: 0.0745306
# [333]	valid_0's rmse: 0.0745296
# [334]	valid_0's rmse: 0.0745249
# [335]	valid_0's rmse: 0.0745232
# [336]	valid_0's rmse: 0.0745248
# [337]	valid_0's rmse: 0.0745247
# [338]	valid_0's rmse: 0.0745234
# [339]	valid_0's rmse: 0.0745204
# [340]	valid_0's rmse: 0.0745196
# [341]	valid_0's rmse: 0.0745194
# [342]	valid_0's rmse: 0.074521
# [343]	valid_0's rmse: 0.0745237
# [344]	valid_0's rmse: 0.0745225
# [345]	valid_0's rmse: 0.0745261
# [346]	valid_0's rmse: 0.0745257
# [347]	valid_0's rmse: 0.0745261
# [348]	valid_0's rmse: 0.0745259
# [349]	valid_0's rmse: 0.0745216
# [350]	valid_0's rmse: 0.0745206
# [351]	valid_0's rmse: 0.0745206
# [352]	valid_0's rmse: 0.0745176
# [353]	valid_0's rmse: 0.0745169
# [354]	valid_0's rmse: 0.0745274
# [355]	valid_0's rmse: 0.0745245
# [356]	valid_0's rmse: 0.0745249
# [357]	valid_0's rmse: 0.0745225
# [358]	valid_0's rmse: 0.0745253
# [359]	valid_0's rmse: 0.0745233
# [360]	valid_0's rmse: 0.0745251
# [361]	valid_0's rmse: 0.0745244
# [362]	valid_0's rmse: 0.0745108
# [363]	valid_0's rmse: 0.0745109
# [364]	valid_0's rmse: 0.0745034
# [365]	valid_0's rmse: 0.0745032
# [366]	valid_0's rmse: 0.0745015
# [367]	valid_0's rmse: 0.0744969
# [368]	valid_0's rmse: 0.0744958
# [369]	valid_0's rmse: 0.0744928
# [370]	valid_0's rmse: 0.0744933
# [371]	valid_0's rmse: 0.0744924
# [372]	valid_0's rmse: 0.0744925
# [373]	valid_0's rmse: 0.0744904
# [374]	valid_0's rmse: 0.0744956
# [375]	valid_0's rmse: 0.0744968
# [376]	valid_0's rmse: 0.0744967
# [377]	valid_0's rmse: 0.0744963
# [378]	valid_0's rmse: 0.0744961
# [379]	valid_0's rmse: 0.0744937
# [380]	valid_0's rmse: 0.074488
# [381]	valid_0's rmse: 0.0744884
# [382]	valid_0's rmse: 0.0744874
# [383]	valid_0's rmse: 0.0744841
# [384]	valid_0's rmse: 0.0744855
# [385]	valid_0's rmse: 0.0744838
# [386]	valid_0's rmse: 0.0744844
# [387]	valid_0's rmse: 0.0744825
# [388]	valid_0's rmse: 0.0744828
# [389]	valid_0's rmse: 0.0744833
# [390]	valid_0's rmse: 0.074481
# [391]	valid_0's rmse: 0.0744764
# [392]	valid_0's rmse: 0.0744736
# [393]	valid_0's rmse: 0.0744716
# [394]	valid_0's rmse: 0.0744732
# [395]	valid_0's rmse: 0.0744728
# [396]	valid_0's rmse: 0.0744731
# [397]	valid_0's rmse: 0.0744725
# [398]	valid_0's rmse: 0.0744708
# [399]	valid_0's rmse: 0.0744714
# [400]	valid_0's rmse: 0.0744699
# [401]	valid_0's rmse: 0.0744738
# [402]	valid_0's rmse: 0.0744711
# [403]	valid_0's rmse: 0.0744703
# [404]	valid_0's rmse: 0.0744758
# [405]	valid_0's rmse: 0.0744722
# [406]	valid_0's rmse: 0.0744717
# [407]	valid_0's rmse: 0.0744686
# [408]	valid_0's rmse: 0.0744682
# [409]	valid_0's rmse: 0.0744708
# [410]	valid_0's rmse: 0.0744715
# [411]	valid_0's rmse: 0.0744716
# [412]	valid_0's rmse: 0.074474
# [413]	valid_0's rmse: 0.0744742
# [414]	valid_0's rmse: 0.074476
# [415]	valid_0's rmse: 0.0744805
# [416]	valid_0's rmse: 0.0744796
# [417]	valid_0's rmse: 0.0744793
# [418]	valid_0's rmse: 0.0744794
# [419]	valid_0's rmse: 0.0744792
# [420]	valid_0's rmse: 0.0744791
# [421]	valid_0's rmse: 0.0744751
# [422]	valid_0's rmse: 0.0744734
# [423]	valid_0's rmse: 0.0744751
# [424]	valid_0's rmse: 0.074475
# [425]	valid_0's rmse: 0.074475
# [426]	valid_0's rmse: 0.0744754
# [427]	valid_0's rmse: 0.0744799
# [428]	valid_0's rmse: 0.0744829
# [429]	valid_0's rmse: 0.0744846
# [430]	valid_0's rmse: 0.0744813
# [431]	valid_0's rmse: 0.0744831
# [432]	valid_0's rmse: 0.0744848
# [433]	valid_0's rmse: 0.0744871
# [434]	valid_0's rmse: 0.0744885
# [435]	valid_0's rmse: 0.0744892
# [436]	valid_0's rmse: 0.0744889
# [437]	valid_0's rmse: 0.0744896
# [438]	valid_0's rmse: 0.0744911
# [439]	valid_0's rmse: 0.0744911
# [440]	valid_0's rmse: 0.0744886
# [441]	valid_0's rmse: 0.0744872
# [442]	valid_0's rmse: 0.0744846
# [443]	valid_0's rmse: 0.074486
# [444]	valid_0's rmse: 0.0744851
# [445]	valid_0's rmse: 0.0744839
# [446]	valid_0's rmse: 0.0744817
# [447]	valid_0's rmse: 0.074472
# [448]	valid_0's rmse: 0.0744738
# [449]	valid_0's rmse: 0.0744729
# [450]	valid_0's rmse: 0.0744738
# [451]	valid_0's rmse: 0.0744695
# [452]	valid_0's rmse: 0.0744694
# [453]	valid_0's rmse: 0.0744693
# [454]	valid_0's rmse: 0.0744688
# [455]	valid_0's rmse: 0.0744591
# [456]	valid_0's rmse: 0.07446
# [457]	valid_0's rmse: 0.0744604
# [458]	valid_0's rmse: 0.0744616
# [459]	valid_0's rmse: 0.0744597
# [460]	valid_0's rmse: 0.0744653
# [461]	valid_0's rmse: 0.0744636
# [462]	valid_0's rmse: 0.0744611
# [463]	valid_0's rmse: 0.0744575
# [464]	valid_0's rmse: 0.074461
# [465]	valid_0's rmse: 0.0744623
# [466]	valid_0's rmse: 0.0744615
# [467]	valid_0's rmse: 0.0744623
# [468]	valid_0's rmse: 0.0744646
# [469]	valid_0's rmse: 0.0744679
# [470]	valid_0's rmse: 0.0744681
# [471]	valid_0's rmse: 0.074469
# [472]	valid_0's rmse: 0.074469
# [473]	valid_0's rmse: 0.0744702
# [474]	valid_0's rmse: 0.0744697
# [475]	valid_0's rmse: 0.0744699
# [476]	valid_0's rmse: 0.0744686
# [477]	valid_0's rmse: 0.0744677
# [478]	valid_0's rmse: 0.0744646
# [479]	valid_0's rmse: 0.0744645
# [480]	valid_0's rmse: 0.0744654
# [481]	valid_0's rmse: 0.0744682
# [482]	valid_0's rmse: 0.0744716
# [483]	valid_0's rmse: 0.0744746
# [484]	valid_0's rmse: 0.0744751
# [485]	valid_0's rmse: 0.0744773
# [486]	valid_0's rmse: 0.0744772
# [487]	valid_0's rmse: 0.0744762
# [488]	valid_0's rmse: 0.0744759
# [489]	valid_0's rmse: 0.0744796
# [490]	valid_0's rmse: 0.0744807
# [491]	valid_0's rmse: 0.0744803
# [492]	valid_0's rmse: 0.0744817
# [493]	valid_0's rmse: 0.0744817
# [494]	valid_0's rmse: 0.0744778
# [495]	valid_0's rmse: 0.0744773
# [496]	valid_0's rmse: 0.0744812
# [497]	valid_0's rmse: 0.0744844
# [498]	valid_0's rmse: 0.0744849
# [499]	valid_0's rmse: 0.0744848
# [500]	valid_0's rmse: 0.0744867
# [1]	valid_0's rmse: 0.100896
# [2]	valid_0's rmse: 0.0991844
# [3]	valid_0's rmse: 0.0982064
# [4]	valid_0's rmse: 0.0975328
# [5]	valid_0's rmse: 0.0966962
# [6]	valid_0's rmse: 0.0959074
# [7]	valid_0's rmse: 0.0946074
# [8]	valid_0's rmse: 0.0939662
# [9]	valid_0's rmse: 0.0932585
# [10]	valid_0's rmse: 0.0926369
# [11]	valid_0's rmse: 0.0920882
# [12]	valid_0's rmse: 0.091052
# [13]	valid_0's rmse: 0.089972
# [14]	valid_0's rmse: 0.0896063
# [15]	valid_0's rmse: 0.089241
# [16]	valid_0's rmse: 0.0882782
# [17]	valid_0's rmse: 0.087451
# [18]	valid_0's rmse: 0.0870955
# [19]	valid_0's rmse: 0.0863017
# [20]	valid_0's rmse: 0.0859751
# [21]	valid_0's rmse: 0.0855767
# [22]	valid_0's rmse: 0.0853536
# [23]	valid_0's rmse: 0.0851429
# [24]	valid_0's rmse: 0.0849304
# [25]	valid_0's rmse: 0.0843751
# [26]	valid_0's rmse: 0.0838635
# [27]	valid_0's rmse: 0.0837134
# [28]	valid_0's rmse: 0.0832385
# [29]	valid_0's rmse: 0.0828082
# [30]	valid_0's rmse: 0.0826965
# [31]	valid_0's rmse: 0.0822496
# [32]	valid_0's rmse: 0.0818588
# [33]	valid_0's rmse: 0.081608
# [34]	valid_0's rmse: 0.0815045
# [35]	valid_0's rmse: 0.0813708
# [36]	valid_0's rmse: 0.0810937
# [37]	valid_0's rmse: 0.0808391
# [38]	valid_0's rmse: 0.0807255
# [39]	valid_0's rmse: 0.0804407
# [40]	valid_0's rmse: 0.0803535
# [41]	valid_0's rmse: 0.0802781
# [42]	valid_0's rmse: 0.0801848
# [43]	valid_0's rmse: 0.0800376
# [44]	valid_0's rmse: 0.0799932
# [45]	valid_0's rmse: 0.0799536
# [46]	valid_0's rmse: 0.079949
# [47]	valid_0's rmse: 0.0798159
# [48]	valid_0's rmse: 0.0797686
# [49]	valid_0's rmse: 0.079736
# [50]	valid_0's rmse: 0.0795324
# [51]	valid_0's rmse: 0.0794321
# [52]	valid_0's rmse: 0.0793652
# [53]	valid_0's rmse: 0.0793301
# [54]	valid_0's rmse: 0.0792268
# [55]	valid_0's rmse: 0.0790331
# [56]	valid_0's rmse: 0.0788678
# [57]	valid_0's rmse: 0.0787484
# [58]	valid_0's rmse: 0.0786646
# [59]	valid_0's rmse: 0.0786337
# [60]	valid_0's rmse: 0.0786093
# [61]	valid_0's rmse: 0.0785104
# [62]	valid_0's rmse: 0.0783925
# [63]	valid_0's rmse: 0.078292
# [64]	valid_0's rmse: 0.0782107
# [65]	valid_0's rmse: 0.0782007
# [66]	valid_0's rmse: 0.0780926
# [67]	valid_0's rmse: 0.0780597
# [68]	valid_0's rmse: 0.0779985
# [69]	valid_0's rmse: 0.0779404
# [70]	valid_0's rmse: 0.0779116
# [71]	valid_0's rmse: 0.0778938
# [72]	valid_0's rmse: 0.0778636
# [73]	valid_0's rmse: 0.0778491
# [74]	valid_0's rmse: 0.0778286
# [75]	valid_0's rmse: 0.0777503
# [76]	valid_0's rmse: 0.0776976
# [77]	valid_0's rmse: 0.0776793
# [78]	valid_0's rmse: 0.0776796
# [79]	valid_0's rmse: 0.0776743
# [80]	valid_0's rmse: 0.0776601
# [81]	valid_0's rmse: 0.0776419
# [82]	valid_0's rmse: 0.0776376
# [83]	valid_0's rmse: 0.077625
# [84]	valid_0's rmse: 0.0776072
# [85]	valid_0's rmse: 0.077529
# [86]	valid_0's rmse: 0.077488
# [87]	valid_0's rmse: 0.0774533
# [88]	valid_0's rmse: 0.0773864
# [89]	valid_0's rmse: 0.0773831
# [90]	valid_0's rmse: 0.0773814
# [91]	valid_0's rmse: 0.0773665
# [92]	valid_0's rmse: 0.0773615
# [93]	valid_0's rmse: 0.0772922
# [94]	valid_0's rmse: 0.0772788
# [95]	valid_0's rmse: 0.0772399
# [96]	valid_0's rmse: 0.0772272
# [97]	valid_0's rmse: 0.0772278
# [98]	valid_0's rmse: 0.0772252
# [99]	valid_0's rmse: 0.0772134
# [100]	valid_0's rmse: 0.0772092
# [101]	valid_0's rmse: 0.0772012
# [102]	valid_0's rmse: 0.0771835
# [103]	valid_0's rmse: 0.077173
# [104]	valid_0's rmse: 0.0771617
# [105]	valid_0's rmse: 0.0771588
# [106]	valid_0's rmse: 0.0771391
# [107]	valid_0's rmse: 0.0771303
# [108]	valid_0's rmse: 0.0770999
# [109]	valid_0's rmse: 0.0770926
# [110]	valid_0's rmse: 0.0770776
# [111]	valid_0's rmse: 0.0770724
# [112]	valid_0's rmse: 0.077071
# [113]	valid_0's rmse: 0.0770599
# [114]	valid_0's rmse: 0.07706
# [115]	valid_0's rmse: 0.077017
# [116]	valid_0's rmse: 0.0770101
# [117]	valid_0's rmse: 0.0769342
# [118]	valid_0's rmse: 0.0769149
# [119]	valid_0's rmse: 0.0769134
# [120]	valid_0's rmse: 0.0769111
# [121]	valid_0's rmse: 0.0769052
# [122]	valid_0's rmse: 0.0769001
# [123]	valid_0's rmse: 0.0768936
# [124]	valid_0's rmse: 0.0768852
# [125]	valid_0's rmse: 0.0768841
# [126]	valid_0's rmse: 0.0768751
# [127]	valid_0's rmse: 0.0768735
# [128]	valid_0's rmse: 0.0768475
# [129]	valid_0's rmse: 0.0768428
# [130]	valid_0's rmse: 0.0768299
# [131]	valid_0's rmse: 0.0768257
# [132]	valid_0's rmse: 0.0768102
# [133]	valid_0's rmse: 0.0767892
# [134]	valid_0's rmse: 0.0767724
# [135]	valid_0's rmse: 0.0767625
# [136]	valid_0's rmse: 0.0767581
# [137]	valid_0's rmse: 0.0767518
# [138]	valid_0's rmse: 0.0767462
# [139]	valid_0's rmse: 0.0767436
# [140]	valid_0's rmse: 0.0767118
# [141]	valid_0's rmse: 0.0767011
# [142]	valid_0's rmse: 0.0766901
# [143]	valid_0's rmse: 0.0766871
# [144]	valid_0's rmse: 0.0766844
# [145]	valid_0's rmse: 0.0766839
# [146]	valid_0's rmse: 0.0766761
# [147]	valid_0's rmse: 0.0766779
# [148]	valid_0's rmse: 0.0766694
# [149]	valid_0's rmse: 0.0766354
# [150]	valid_0's rmse: 0.076634
# [151]	valid_0's rmse: 0.0766296
# [152]	valid_0's rmse: 0.0766243
# [153]	valid_0's rmse: 0.0766119
# [154]	valid_0's rmse: 0.0766115
# [155]	valid_0's rmse: 0.0766093
# [156]	valid_0's rmse: 0.0766042
# [157]	valid_0's rmse: 0.0765996
# [158]	valid_0's rmse: 0.0765956
# [159]	valid_0's rmse: 0.0765917
# [160]	valid_0's rmse: 0.0765942
# [161]	valid_0's rmse: 0.076561
# [162]	valid_0's rmse: 0.0765588
# [163]	valid_0's rmse: 0.0765471
# [164]	valid_0's rmse: 0.0765443
# [165]	valid_0's rmse: 0.0765434
# [166]	valid_0's rmse: 0.0765427
# [167]	valid_0's rmse: 0.0765402
# [168]	valid_0's rmse: 0.0765389
# [169]	valid_0's rmse: 0.0765377
# [170]	valid_0's rmse: 0.0765424
# [171]	valid_0's rmse: 0.0765399
# [172]	valid_0's rmse: 0.0765388
# [173]	valid_0's rmse: 0.0765378
# [174]	valid_0's rmse: 0.0765281
# [175]	valid_0's rmse: 0.0765257
# [176]	valid_0's rmse: 0.0765245
# [177]	valid_0's rmse: 0.0765187
# [178]	valid_0's rmse: 0.0765201
# [179]	valid_0's rmse: 0.0765126
# [180]	valid_0's rmse: 0.0765104
# [181]	valid_0's rmse: 0.0765079
# [182]	valid_0's rmse: 0.076505
# [183]	valid_0's rmse: 0.0765007
# [184]	valid_0's rmse: 0.0765002
# [185]	valid_0's rmse: 0.0764995
# [186]	valid_0's rmse: 0.0764885
# [187]	valid_0's rmse: 0.0764767
# [188]	valid_0's rmse: 0.0764593
# [189]	valid_0's rmse: 0.0764555
# [190]	valid_0's rmse: 0.076421
# [191]	valid_0's rmse: 0.0764094
# [192]	valid_0's rmse: 0.0764029
# [193]	valid_0's rmse: 0.0764039
# [194]	valid_0's rmse: 0.0764028
# [195]	valid_0's rmse: 0.0763972
# [196]	valid_0's rmse: 0.0763934
# [197]	valid_0's rmse: 0.0763966
# [198]	valid_0's rmse: 0.0763939
# [199]	valid_0's rmse: 0.0763889
# [200]	valid_0's rmse: 0.0763767
# [201]	valid_0's rmse: 0.0763762
# [202]	valid_0's rmse: 0.0763767
# [203]	valid_0's rmse: 0.0763746
# [204]	valid_0's rmse: 0.0763765
# [205]	valid_0's rmse: 0.0763725
# [206]	valid_0's rmse: 0.0763493
# [207]	valid_0's rmse: 0.0763486
# [208]	valid_0's rmse: 0.0763468
# [209]	valid_0's rmse: 0.0763398
# [210]	valid_0's rmse: 0.0763279
# [211]	valid_0's rmse: 0.0763324
# [212]	valid_0's rmse: 0.0763331
# [213]	valid_0's rmse: 0.0763365
# [214]	valid_0's rmse: 0.0763346
# [215]	valid_0's rmse: 0.0763226
# [216]	valid_0's rmse: 0.0763191
# [217]	valid_0's rmse: 0.0763203
# [218]	valid_0's rmse: 0.0763184
# [219]	valid_0's rmse: 0.0763181
# [220]	valid_0's rmse: 0.0762892
# [221]	valid_0's rmse: 0.0762898
# [222]	valid_0's rmse: 0.0762845
# [223]	valid_0's rmse: 0.0762799
# [224]	valid_0's rmse: 0.0762643
# [225]	valid_0's rmse: 0.076262
# [226]	valid_0's rmse: 0.0762533
# [227]	valid_0's rmse: 0.0762538
# [228]	valid_0's rmse: 0.076252
# [229]	valid_0's rmse: 0.0762542
# [230]	valid_0's rmse: 0.0762518
# [231]	valid_0's rmse: 0.0762551
# [232]	valid_0's rmse: 0.0762562
# [233]	valid_0's rmse: 0.0762571
# [234]	valid_0's rmse: 0.0762542
# [235]	valid_0's rmse: 0.076253
# [236]	valid_0's rmse: 0.0762511
# [237]	valid_0's rmse: 0.0762529
# [238]	valid_0's rmse: 0.076251
# [239]	valid_0's rmse: 0.0762518
# [240]	valid_0's rmse: 0.0762475
# [241]	valid_0's rmse: 0.0762465
# [242]	valid_0's rmse: 0.0762468
# [243]	valid_0's rmse: 0.0762448
# [244]	valid_0's rmse: 0.0762428
# [245]	valid_0's rmse: 0.0762399
# [246]	valid_0's rmse: 0.0762389
# [247]	valid_0's rmse: 0.076236
# [248]	valid_0's rmse: 0.0762334
# [249]	valid_0's rmse: 0.0762254
# [250]	valid_0's rmse: 0.0762227
# [251]	valid_0's rmse: 0.0762204
# [252]	valid_0's rmse: 0.0762179
# [253]	valid_0's rmse: 0.076216
# [254]	valid_0's rmse: 0.0762172
# [255]	valid_0's rmse: 0.0762168
# [256]	valid_0's rmse: 0.0762158
# [257]	valid_0's rmse: 0.0762157
# [258]	valid_0's rmse: 0.0762136
# [259]	valid_0's rmse: 0.0762116
# [260]	valid_0's rmse: 0.0762077
# [261]	valid_0's rmse: 0.0762112
# [262]	valid_0's rmse: 0.0762131
# [263]	valid_0's rmse: 0.0762136
# [264]	valid_0's rmse: 0.0762152
# [265]	valid_0's rmse: 0.0761945
# [266]	valid_0's rmse: 0.0761926
# [267]	valid_0's rmse: 0.0761929
# [268]	valid_0's rmse: 0.0761948
# [269]	valid_0's rmse: 0.0761958
# [270]	valid_0's rmse: 0.0761933
# [271]	valid_0's rmse: 0.0761942
# [272]	valid_0's rmse: 0.0761828
# [273]	valid_0's rmse: 0.0761833
# [274]	valid_0's rmse: 0.0761758
# [275]	valid_0's rmse: 0.0761754
# [276]	valid_0's rmse: 0.0761776
# [277]	valid_0's rmse: 0.0761746
# [278]	valid_0's rmse: 0.0761746
# [279]	valid_0's rmse: 0.0761742
# [280]	valid_0's rmse: 0.0761732
# [281]	valid_0's rmse: 0.0761761
# [282]	valid_0's rmse: 0.0761696
# [283]	valid_0's rmse: 0.0761691
# [284]	valid_0's rmse: 0.0761714
# [285]	valid_0's rmse: 0.0761701
# [286]	valid_0's rmse: 0.0761701
# [287]	valid_0's rmse: 0.0761753
# [288]	valid_0's rmse: 0.0761757
# [289]	valid_0's rmse: 0.0761826
# [290]	valid_0's rmse: 0.076185
# [291]	valid_0's rmse: 0.0761837
# [292]	valid_0's rmse: 0.0761807
# [293]	valid_0's rmse: 0.0761785
# [294]	valid_0's rmse: 0.0761788
# [295]	valid_0's rmse: 0.0761821
# [296]	valid_0's rmse: 0.0761722
# [297]	valid_0's rmse: 0.0761606
# [298]	valid_0's rmse: 0.0761634
# [299]	valid_0's rmse: 0.0761635
# [300]	valid_0's rmse: 0.0761609
# [301]	valid_0's rmse: 0.076166
# [302]	valid_0's rmse: 0.0761636
# [303]	valid_0's rmse: 0.0761621
# [304]	valid_0's rmse: 0.0761611
# [305]	valid_0's rmse: 0.0761603
# [306]	valid_0's rmse: 0.0761605
# [307]	valid_0's rmse: 0.0761575
# [308]	valid_0's rmse: 0.0761575
# [309]	valid_0's rmse: 0.0761627
# [310]	valid_0's rmse: 0.076165
# [311]	valid_0's rmse: 0.0761617
# [312]	valid_0's rmse: 0.0761567
# [313]	valid_0's rmse: 0.0761552
# [314]	valid_0's rmse: 0.0761522
# [315]	valid_0's rmse: 0.0761536
# [316]	valid_0's rmse: 0.0761502
# [317]	valid_0's rmse: 0.0761523
# [318]	valid_0's rmse: 0.0761539
# [319]	valid_0's rmse: 0.0761549
# [320]	valid_0's rmse: 0.0761547
# [321]	valid_0's rmse: 0.0761532
# [322]	valid_0's rmse: 0.0761523
# [323]	valid_0's rmse: 0.0761324
# [324]	valid_0's rmse: 0.0761375
# [325]	valid_0's rmse: 0.0761381
# [326]	valid_0's rmse: 0.0761378
# [327]	valid_0's rmse: 0.0761384
# [328]	valid_0's rmse: 0.0761371
# [329]	valid_0's rmse: 0.076136
# [330]	valid_0's rmse: 0.0761352
# [331]	valid_0's rmse: 0.0761341
# [332]	valid_0's rmse: 0.0761335
# [333]	valid_0's rmse: 0.0761305
# [334]	valid_0's rmse: 0.0761282
# [335]	valid_0's rmse: 0.076128
# [336]	valid_0's rmse: 0.0761253
# [337]	valid_0's rmse: 0.0761234
# [338]	valid_0's rmse: 0.0761191
# [339]	valid_0's rmse: 0.0761203
# [340]	valid_0's rmse: 0.0761198
# [341]	valid_0's rmse: 0.0761195
# [342]	valid_0's rmse: 0.0761207
# [343]	valid_0's rmse: 0.076121
# [344]	valid_0's rmse: 0.0761206
# [345]	valid_0's rmse: 0.0761205
# [346]	valid_0's rmse: 0.0761209
# [347]	valid_0's rmse: 0.0761198
# [348]	valid_0's rmse: 0.0761223
# [349]	valid_0's rmse: 0.0761221
# [350]	valid_0's rmse: 0.076123
# [351]	valid_0's rmse: 0.0761223
# [352]	valid_0's rmse: 0.0761227
# [353]	valid_0's rmse: 0.0761239
# [354]	valid_0's rmse: 0.0761248
# [355]	valid_0's rmse: 0.0761239
# [356]	valid_0's rmse: 0.0761235
# [357]	valid_0's rmse: 0.0761238
# [358]	valid_0's rmse: 0.0761225
# [359]	valid_0's rmse: 0.0761223
# [360]	valid_0's rmse: 0.076121
# [361]	valid_0's rmse: 0.0761232
# [362]	valid_0's rmse: 0.0761172
# [363]	valid_0's rmse: 0.0761177
# [364]	valid_0's rmse: 0.0761157
# [365]	valid_0's rmse: 0.0761135
# [366]	valid_0's rmse: 0.0761124
# [367]	valid_0's rmse: 0.0761105
# [368]	valid_0's rmse: 0.0761096
# [369]	valid_0's rmse: 0.076112
# [370]	valid_0's rmse: 0.0761109
# [371]	valid_0's rmse: 0.0761081
# [372]	valid_0's rmse: 0.0761092
# [373]	valid_0's rmse: 0.0761091
# [374]	valid_0's rmse: 0.0761098
# [375]	valid_0's rmse: 0.0761085
# [376]	valid_0's rmse: 0.0761081
# [377]	valid_0's rmse: 0.076109
# [378]	valid_0's rmse: 0.0761038
# [379]	valid_0's rmse: 0.0760995
# [380]	valid_0's rmse: 0.0761008
# [381]	valid_0's rmse: 0.0761005
# [382]	valid_0's rmse: 0.0760992
# [383]	valid_0's rmse: 0.0760993
# [384]	valid_0's rmse: 0.0761007
# [385]	valid_0's rmse: 0.0761004
# [386]	valid_0's rmse: 0.0760963
# [387]	valid_0's rmse: 0.0760862
# [388]	valid_0's rmse: 0.0760837
# [389]	valid_0's rmse: 0.0760839
# [390]	valid_0's rmse: 0.0760853
# [391]	valid_0's rmse: 0.0760771
# [392]	valid_0's rmse: 0.07607
# [393]	valid_0's rmse: 0.0760713
# [394]	valid_0's rmse: 0.0760692
# [395]	valid_0's rmse: 0.0760692
# [396]	valid_0's rmse: 0.0760704
# [397]	valid_0's rmse: 0.0760713
# [398]	valid_0's rmse: 0.0760696
# [399]	valid_0's rmse: 0.0760688
# [400]	valid_0's rmse: 0.0760682
# [401]	valid_0's rmse: 0.076069
# [402]	valid_0's rmse: 0.0760688
# [403]	valid_0's rmse: 0.0760685
# [404]	valid_0's rmse: 0.0760571
# [405]	valid_0's rmse: 0.0760591
# [406]	valid_0's rmse: 0.0760579
# [407]	valid_0's rmse: 0.0760563
# [408]	valid_0's rmse: 0.0760588
# [409]	valid_0's rmse: 0.0760601
# [410]	valid_0's rmse: 0.0760606
# [411]	valid_0's rmse: 0.0760597
# [412]	valid_0's rmse: 0.0760572
# [413]	valid_0's rmse: 0.0760571
# [414]	valid_0's rmse: 0.0760543
# [415]	valid_0's rmse: 0.0760527
# [416]	valid_0's rmse: 0.0760535
# [417]	valid_0's rmse: 0.076055
# [418]	valid_0's rmse: 0.0760524
# [419]	valid_0's rmse: 0.0760516
# [420]	valid_0's rmse: 0.0760521
# [421]	valid_0's rmse: 0.0760524
# [422]	valid_0's rmse: 0.0760518
# [423]	valid_0's rmse: 0.0760512
# [424]	valid_0's rmse: 0.0760549
# [425]	valid_0's rmse: 0.0760551
# [426]	valid_0's rmse: 0.0760546
# [427]	valid_0's rmse: 0.0760545
# [428]	valid_0's rmse: 0.0760555
# [429]	valid_0's rmse: 0.0760547
# [430]	valid_0's rmse: 0.0760534
# [431]	valid_0's rmse: 0.0760488
# [432]	valid_0's rmse: 0.0760483
# [433]	valid_0's rmse: 0.076044
# [434]	valid_0's rmse: 0.0760437
# [435]	valid_0's rmse: 0.0760438
# [436]	valid_0's rmse: 0.0760451
# [437]	valid_0's rmse: 0.0760412
# [438]	valid_0's rmse: 0.0760353
# [439]	valid_0's rmse: 0.076037
# [440]	valid_0's rmse: 0.0760356
# [441]	valid_0's rmse: 0.0760362
# [442]	valid_0's rmse: 0.0760341
# [443]	valid_0's rmse: 0.0760356
# [444]	valid_0's rmse: 0.0760224
# [445]	valid_0's rmse: 0.0760219
# [446]	valid_0's rmse: 0.0760227
# [447]	valid_0's rmse: 0.0760232
# [448]	valid_0's rmse: 0.0760226
# [449]	valid_0's rmse: 0.0760219
# [450]	valid_0's rmse: 0.0760166
# [451]	valid_0's rmse: 0.0760175
# [452]	valid_0's rmse: 0.076018
# [453]	valid_0's rmse: 0.0760197
# [454]	valid_0's rmse: 0.0760206
# [455]	valid_0's rmse: 0.0760186
# [456]	valid_0's rmse: 0.0760122
# [457]	valid_0's rmse: 0.0760107
# [458]	valid_0's rmse: 0.0760118
# [459]	valid_0's rmse: 0.0760126
# [460]	valid_0's rmse: 0.0760116
# [461]	valid_0's rmse: 0.0760123
# [462]	valid_0's rmse: 0.0760107
# [463]	valid_0's rmse: 0.0760104
# [464]	valid_0's rmse: 0.0760095
# [465]	valid_0's rmse: 0.0760095
# [466]	valid_0's rmse: 0.0760101
# [467]	valid_0's rmse: 0.07601
# [468]	valid_0's rmse: 0.076008
# [469]	valid_0's rmse: 0.076002
# [470]	valid_0's rmse: 0.0760031
# [471]	valid_0's rmse: 0.0760037
# [472]	valid_0's rmse: 0.076003
# [473]	valid_0's rmse: 0.0760036
# [474]	valid_0's rmse: 0.0760024
# [475]	valid_0's rmse: 0.0760038
# [476]	valid_0's rmse: 0.0760048
# [477]	valid_0's rmse: 0.0760039
# [478]	valid_0's rmse: 0.0760046
# [479]	valid_0's rmse: 0.0760058
# [480]	valid_0's rmse: 0.0760033
# [481]	valid_0's rmse: 0.0760036
# [482]	valid_0's rmse: 0.0760021
# [483]	valid_0's rmse: 0.0760019
# [484]	valid_0's rmse: 0.0760041
# [485]	valid_0's rmse: 0.0760004
# [486]	valid_0's rmse: 0.0760024
# [487]	valid_0's rmse: 0.0760004
# [488]	valid_0's rmse: 0.0760004
# [489]	valid_0's rmse: 0.0759979
# [490]	valid_0's rmse: 0.0759993
# [491]	valid_0's rmse: 0.075994
# [492]	valid_0's rmse: 0.0759931
# [493]	valid_0's rmse: 0.0759932
# [494]	valid_0's rmse: 0.0759936
# [495]	valid_0's rmse: 0.0759936
# [496]	valid_0's rmse: 0.0759932
# [497]	valid_0's rmse: 0.0759941
# [498]	valid_0's rmse: 0.0759927
# [499]	valid_0's rmse: 0.0759933
# [500]	valid_0's rmse: 0.075991
# [1]	valid_0's rmse: 0.0993932
# [2]	valid_0's rmse: 0.0976978
# [3]	valid_0's rmse: 0.096706
# [4]	valid_0's rmse: 0.0960034
# [5]	valid_0's rmse: 0.0951555
# [6]	valid_0's rmse: 0.0943158
# [7]	valid_0's rmse: 0.0930891
# [8]	valid_0's rmse: 0.0924511
# [9]	valid_0's rmse: 0.0918214
# [10]	valid_0's rmse: 0.0912526
# [11]	valid_0's rmse: 0.0907436
# [12]	valid_0's rmse: 0.089804
# [13]	valid_0's rmse: 0.0888067
# [14]	valid_0's rmse: 0.0883933
# [15]	valid_0's rmse: 0.0880102
# [16]	valid_0's rmse: 0.0872089
# [17]	valid_0's rmse: 0.0865343
# [18]	valid_0's rmse: 0.0861237
# [19]	valid_0's rmse: 0.0853627
# [20]	valid_0's rmse: 0.0849909
# [21]	valid_0's rmse: 0.0845881
# [22]	valid_0's rmse: 0.0843523
# [23]	valid_0's rmse: 0.0841151
# [24]	valid_0's rmse: 0.0838599
# [25]	valid_0's rmse: 0.0833796
# [26]	valid_0's rmse: 0.0828408
# [27]	valid_0's rmse: 0.0826902
# [28]	valid_0's rmse: 0.0822279
# [29]	valid_0's rmse: 0.0818699
# [30]	valid_0's rmse: 0.0817543
# [31]	valid_0's rmse: 0.0813186
# [32]	valid_0's rmse: 0.0810133
# [33]	valid_0's rmse: 0.0807223
# [34]	valid_0's rmse: 0.080588
# [35]	valid_0's rmse: 0.0804259
# [36]	valid_0's rmse: 0.0801654
# [37]	valid_0's rmse: 0.0798624
# [38]	valid_0's rmse: 0.0797465
# [39]	valid_0's rmse: 0.0794611
# [40]	valid_0's rmse: 0.0793518
# [41]	valid_0's rmse: 0.0792523
# [42]	valid_0's rmse: 0.0791424
# [43]	valid_0's rmse: 0.0789685
# [44]	valid_0's rmse: 0.0788965
# [45]	valid_0's rmse: 0.0788543
# [46]	valid_0's rmse: 0.0788512
# [47]	valid_0's rmse: 0.0786737
# [48]	valid_0's rmse: 0.0786101
# [49]	valid_0's rmse: 0.0785609
# [50]	valid_0's rmse: 0.0783946
# [51]	valid_0's rmse: 0.078271
# [52]	valid_0's rmse: 0.0782
# [53]	valid_0's rmse: 0.0781633
# [54]	valid_0's rmse: 0.0780906
# [55]	valid_0's rmse: 0.0779262
# [56]	valid_0's rmse: 0.077763
# [57]	valid_0's rmse: 0.0776956
# [58]	valid_0's rmse: 0.0775764
# [59]	valid_0's rmse: 0.077524
# [60]	valid_0's rmse: 0.0775064
# [61]	valid_0's rmse: 0.0774039
# [62]	valid_0's rmse: 0.0772788
# [63]	valid_0's rmse: 0.0771823
# [64]	valid_0's rmse: 0.0771297
# [65]	valid_0's rmse: 0.0771104
# [66]	valid_0's rmse: 0.0770146
# [67]	valid_0's rmse: 0.0769859
# [68]	valid_0's rmse: 0.0769549
# [69]	valid_0's rmse: 0.0769184
# [70]	valid_0's rmse: 0.076884
# [71]	valid_0's rmse: 0.076864
# [72]	valid_0's rmse: 0.0768303
# [73]	valid_0's rmse: 0.0768273
# [74]	valid_0's rmse: 0.0768034
# [75]	valid_0's rmse: 0.0767319
# [76]	valid_0's rmse: 0.0766896
# [77]	valid_0's rmse: 0.0766648
# [78]	valid_0's rmse: 0.0766655
# [79]	valid_0's rmse: 0.076639
# [80]	valid_0's rmse: 0.0766217
# [81]	valid_0's rmse: 0.0765913
# [82]	valid_0's rmse: 0.0765709
# [83]	valid_0's rmse: 0.0765526
# [84]	valid_0's rmse: 0.0765351
# [85]	valid_0's rmse: 0.0764765
# [86]	valid_0's rmse: 0.0764233
# [87]	valid_0's rmse: 0.076389
# [88]	valid_0's rmse: 0.0763571
# [89]	valid_0's rmse: 0.0763427
# [90]	valid_0's rmse: 0.0763259
# [91]	valid_0's rmse: 0.0763133
# [92]	valid_0's rmse: 0.0763018
# [93]	valid_0's rmse: 0.076237
# [94]	valid_0's rmse: 0.0762087
# [95]	valid_0's rmse: 0.0761572
# [96]	valid_0's rmse: 0.0761508
# [97]	valid_0's rmse: 0.0761504
# [98]	valid_0's rmse: 0.0761421
# [99]	valid_0's rmse: 0.0761308
# [100]	valid_0's rmse: 0.0761242
# [101]	valid_0's rmse: 0.0761265
# [102]	valid_0's rmse: 0.0761172
# [103]	valid_0's rmse: 0.076112
# [104]	valid_0's rmse: 0.0761097
# [105]	valid_0's rmse: 0.0761068
# [106]	valid_0's rmse: 0.0760958
# [107]	valid_0's rmse: 0.0760897
# [108]	valid_0's rmse: 0.076051
# [109]	valid_0's rmse: 0.0760382
# [110]	valid_0's rmse: 0.0759916
# [111]	valid_0's rmse: 0.075982
# [112]	valid_0's rmse: 0.0759691
# [113]	valid_0's rmse: 0.0759585
# [114]	valid_0's rmse: 0.0759549
# [115]	valid_0's rmse: 0.0759423
# [116]	valid_0's rmse: 0.0759331
# [117]	valid_0's rmse: 0.0758847
# [118]	valid_0's rmse: 0.0758612
# [119]	valid_0's rmse: 0.0758561
# [120]	valid_0's rmse: 0.0758484
# [121]	valid_0's rmse: 0.0758437
# [122]	valid_0's rmse: 0.0758408
# [123]	valid_0's rmse: 0.0757752
# [124]	valid_0's rmse: 0.0757732
# [125]	valid_0's rmse: 0.0757642
# [126]	valid_0's rmse: 0.0757551
# [127]	valid_0's rmse: 0.0757577
# [128]	valid_0's rmse: 0.075751
# [129]	valid_0's rmse: 0.0757482
# [130]	valid_0's rmse: 0.0757409
# [131]	valid_0's rmse: 0.0757362
# [132]	valid_0's rmse: 0.0757198
# [133]	valid_0's rmse: 0.075707
# [134]	valid_0's rmse: 0.0756886
# [135]	valid_0's rmse: 0.0756795
# [136]	valid_0's rmse: 0.0756734
# [137]	valid_0's rmse: 0.0756436
# [138]	valid_0's rmse: 0.0756399
# [139]	valid_0's rmse: 0.075635
# [140]	valid_0's rmse: 0.0755957
# [141]	valid_0's rmse: 0.0755728
# [142]	valid_0's rmse: 0.0755668
# [143]	valid_0's rmse: 0.0755656
# [144]	valid_0's rmse: 0.075562
# [145]	valid_0's rmse: 0.0755527
# [146]	valid_0's rmse: 0.0755536
# [147]	valid_0's rmse: 0.0755539
# [148]	valid_0's rmse: 0.0755548
# [149]	valid_0's rmse: 0.0755408
# [150]	valid_0's rmse: 0.0755369
# [151]	valid_0's rmse: 0.0755342
# [152]	valid_0's rmse: 0.0755354
# [153]	valid_0's rmse: 0.075537
# [154]	valid_0's rmse: 0.0755372
# [155]	valid_0's rmse: 0.0755227
# [156]	valid_0's rmse: 0.0755214
# [157]	valid_0's rmse: 0.0755226
# [158]	valid_0's rmse: 0.0755181
# [159]	valid_0's rmse: 0.0755243
# [160]	valid_0's rmse: 0.0755263
# [161]	valid_0's rmse: 0.0755028
# [162]	valid_0's rmse: 0.0755
# [163]	valid_0's rmse: 0.0754944
# [164]	valid_0's rmse: 0.0754933
# [165]	valid_0's rmse: 0.0754854
# [166]	valid_0's rmse: 0.0754849
# [167]	valid_0's rmse: 0.075478
# [168]	valid_0's rmse: 0.075473
# [169]	valid_0's rmse: 0.075464
# [170]	valid_0's rmse: 0.0754528
# [171]	valid_0's rmse: 0.0754533
# [172]	valid_0's rmse: 0.0754473
# [173]	valid_0's rmse: 0.0754457
# [174]	valid_0's rmse: 0.0754345
# [175]	valid_0's rmse: 0.0754353
# [176]	valid_0's rmse: 0.0754358
# [177]	valid_0's rmse: 0.0754348
# [178]	valid_0's rmse: 0.075421
# [179]	valid_0's rmse: 0.0754183
# [180]	valid_0's rmse: 0.0754196
# [181]	valid_0's rmse: 0.0754178
# [182]	valid_0's rmse: 0.0754178
# [183]	valid_0's rmse: 0.0754193
# [184]	valid_0's rmse: 0.0754194
# [185]	valid_0's rmse: 0.075419
# [186]	valid_0's rmse: 0.0754179
# [187]	valid_0's rmse: 0.0754167
# [188]	valid_0's rmse: 0.075421
# [189]	valid_0's rmse: 0.0754219
# [190]	valid_0's rmse: 0.075422
# [191]	valid_0's rmse: 0.0754186
# [192]	valid_0's rmse: 0.075413
# [193]	valid_0's rmse: 0.0754141
# [194]	valid_0's rmse: 0.0754106
# [195]	valid_0's rmse: 0.0754088
# [196]	valid_0's rmse: 0.0753946
# [197]	valid_0's rmse: 0.0753976
# [198]	valid_0's rmse: 0.0753918
# [199]	valid_0's rmse: 0.0753832
# [200]	valid_0's rmse: 0.0753851
# [201]	valid_0's rmse: 0.0753845
# [202]	valid_0's rmse: 0.0753853
# [203]	valid_0's rmse: 0.0753912
# [204]	valid_0's rmse: 0.0753909
# [205]	valid_0's rmse: 0.0753834
# [206]	valid_0's rmse: 0.0753852
# [207]	valid_0's rmse: 0.0753861
# [208]	valid_0's rmse: 0.0753858
# [209]	valid_0's rmse: 0.0753812
# [210]	valid_0's rmse: 0.0753826
# [211]	valid_0's rmse: 0.0753808
# [212]	valid_0's rmse: 0.075371
# [213]	valid_0's rmse: 0.0753655
# [214]	valid_0's rmse: 0.0753663
# [215]	valid_0's rmse: 0.0753643
# [216]	valid_0's rmse: 0.0753634
# [217]	valid_0's rmse: 0.0753629
# [218]	valid_0's rmse: 0.0753591
# [219]	valid_0's rmse: 0.0753588
# [220]	valid_0's rmse: 0.0753538
# [221]	valid_0's rmse: 0.0753531
# [222]	valid_0's rmse: 0.0753555
# [223]	valid_0's rmse: 0.0753524
# [224]	valid_0's rmse: 0.0753453
# [225]	valid_0's rmse: 0.0753404
# [226]	valid_0's rmse: 0.0753384
# [227]	valid_0's rmse: 0.0753388
# [228]	valid_0's rmse: 0.0753357
# [229]	valid_0's rmse: 0.0753346
# [230]	valid_0's rmse: 0.0753366
# [231]	valid_0's rmse: 0.075336
# [232]	valid_0's rmse: 0.0753323
# [233]	valid_0's rmse: 0.0753342
# [234]	valid_0's rmse: 0.0753284
# [235]	valid_0's rmse: 0.0753261
# [236]	valid_0's rmse: 0.0753258
# [237]	valid_0's rmse: 0.0753284
# [238]	valid_0's rmse: 0.0753237
# [239]	valid_0's rmse: 0.075321
# [240]	valid_0's rmse: 0.0753194
# [241]	valid_0's rmse: 0.0753229
# [242]	valid_0's rmse: 0.0753062
# [243]	valid_0's rmse: 0.075301
# [244]	valid_0's rmse: 0.0753011
# [245]	valid_0's rmse: 0.0753011
# [246]	valid_0's rmse: 0.0752971
# [247]	valid_0's rmse: 0.0752962
# [248]	valid_0's rmse: 0.0752957
# [249]	valid_0's rmse: 0.0752966
# [250]	valid_0's rmse: 0.0752946
# [251]	valid_0's rmse: 0.075295
# [252]	valid_0's rmse: 0.075297
# [253]	valid_0's rmse: 0.0752951
# [254]	valid_0's rmse: 0.0752906
# [255]	valid_0's rmse: 0.0752895
# [256]	valid_0's rmse: 0.0752905
# [257]	valid_0's rmse: 0.0752896
# [258]	valid_0's rmse: 0.0752905
# [259]	valid_0's rmse: 0.0752952
# [260]	valid_0's rmse: 0.0752963
# [261]	valid_0's rmse: 0.0752981
# [262]	valid_0's rmse: 0.0752927
# [263]	valid_0's rmse: 0.0752922
# [264]	valid_0's rmse: 0.0752862
# [265]	valid_0's rmse: 0.0752872
# [266]	valid_0's rmse: 0.0752835
# [267]	valid_0's rmse: 0.0752854
# [268]	valid_0's rmse: 0.0752912
# [269]	valid_0's rmse: 0.0752859
# [270]	valid_0's rmse: 0.0752825
# [271]	valid_0's rmse: 0.0752814
# [272]	valid_0's rmse: 0.0752703
# [273]	valid_0's rmse: 0.0752672
# [274]	valid_0's rmse: 0.0752638
# [275]	valid_0's rmse: 0.0752626
# [276]	valid_0's rmse: 0.0752595
# [277]	valid_0's rmse: 0.0752594
# [278]	valid_0's rmse: 0.0752572
# [279]	valid_0's rmse: 0.0752563
# [280]	valid_0's rmse: 0.0752554
# [281]	valid_0's rmse: 0.0752555
# [282]	valid_0's rmse: 0.0752528
# [283]	valid_0's rmse: 0.0752574
# [284]	valid_0's rmse: 0.0752566
# [285]	valid_0's rmse: 0.075253
# [286]	valid_0's rmse: 0.0752507
# [287]	valid_0's rmse: 0.0752481
# [288]	valid_0's rmse: 0.0752501
# [289]	valid_0's rmse: 0.075251
# [290]	valid_0's rmse: 0.0752539
# [291]	valid_0's rmse: 0.0752539
# [292]	valid_0's rmse: 0.0752507
# [293]	valid_0's rmse: 0.0752533
# [294]	valid_0's rmse: 0.0752529
# [295]	valid_0's rmse: 0.0752483
# [296]	valid_0's rmse: 0.0752426
# [297]	valid_0's rmse: 0.0752412
# [298]	valid_0's rmse: 0.0752462
# [299]	valid_0's rmse: 0.0752482
# [300]	valid_0's rmse: 0.0752451
# [301]	valid_0's rmse: 0.0752425
# [302]	valid_0's rmse: 0.0752414
# [303]	valid_0's rmse: 0.075241
# [304]	valid_0's rmse: 0.0752426
# [305]	valid_0's rmse: 0.0752414
# [306]	valid_0's rmse: 0.0752417
# [307]	valid_0's rmse: 0.075241
# [308]	valid_0's rmse: 0.0752413
# [309]	valid_0's rmse: 0.075242
# [310]	valid_0's rmse: 0.0752406
# [311]	valid_0's rmse: 0.07524
# [312]	valid_0's rmse: 0.0752383
# [313]	valid_0's rmse: 0.07524
# [314]	valid_0's rmse: 0.0752412
# [315]	valid_0's rmse: 0.0752416
# [316]	valid_0's rmse: 0.0752421
# [317]	valid_0's rmse: 0.0752421
# [318]	valid_0's rmse: 0.0752474
# [319]	valid_0's rmse: 0.075247
# [320]	valid_0's rmse: 0.0752514
# [321]	valid_0's rmse: 0.0752494
# [322]	valid_0's rmse: 0.0752482
# [323]	valid_0's rmse: 0.075255
# [324]	valid_0's rmse: 0.0752478
# [325]	valid_0's rmse: 0.0752544
# [326]	valid_0's rmse: 0.0752523
# [327]	valid_0's rmse: 0.0752506
# [328]	valid_0's rmse: 0.0752497
# [329]	valid_0's rmse: 0.0752487
# [330]	valid_0's rmse: 0.0752507
# [331]	valid_0's rmse: 0.0752474
# [332]	valid_0's rmse: 0.0752491
# [333]	valid_0's rmse: 0.0752499
# [334]	valid_0's rmse: 0.0752504
# [335]	valid_0's rmse: 0.0752511
# [336]	valid_0's rmse: 0.0752505
# [337]	valid_0's rmse: 0.0752487
# [338]	valid_0's rmse: 0.0752383
# [339]	valid_0's rmse: 0.075236
# [340]	valid_0's rmse: 0.0752333
# [341]	valid_0's rmse: 0.07524
# [342]	valid_0's rmse: 0.0752378
# [343]	valid_0's rmse: 0.0752431
# [344]	valid_0's rmse: 0.0752462
# [345]	valid_0's rmse: 0.0752449
# [346]	valid_0's rmse: 0.0752426
# [347]	valid_0's rmse: 0.0752447
# [348]	valid_0's rmse: 0.0752461
# [349]	valid_0's rmse: 0.0752427
# [350]	valid_0's rmse: 0.0752403
# [351]	valid_0's rmse: 0.0752418
# [352]	valid_0's rmse: 0.0752422
# [353]	valid_0's rmse: 0.0752397
# [354]	valid_0's rmse: 0.0752413
# [355]	valid_0's rmse: 0.0752454
# [356]	valid_0's rmse: 0.0752446
# [357]	valid_0's rmse: 0.0752425
# [358]	valid_0's rmse: 0.075243
# [359]	valid_0's rmse: 0.0752431
# [360]	valid_0's rmse: 0.0752391
# [361]	valid_0's rmse: 0.0752335
# [362]	valid_0's rmse: 0.0752356
# [363]	valid_0's rmse: 0.0752348
# [364]	valid_0's rmse: 0.0752313
# [365]	valid_0's rmse: 0.0752331
# [366]	valid_0's rmse: 0.0752334
# [367]	valid_0's rmse: 0.0752341
# [368]	valid_0's rmse: 0.0752354
# [369]	valid_0's rmse: 0.0752391
# [370]	valid_0's rmse: 0.0752406
# [371]	valid_0's rmse: 0.0752332
# [372]	valid_0's rmse: 0.0752328
# [373]	valid_0's rmse: 0.0752328
# [374]	valid_0's rmse: 0.0752328
# [375]	valid_0's rmse: 0.0752322
# [376]	valid_0's rmse: 0.0752321
# [377]	valid_0's rmse: 0.0752336
# [378]	valid_0's rmse: 0.075231
# [379]	valid_0's rmse: 0.0752304
# [380]	valid_0's rmse: 0.0752351
# [381]	valid_0's rmse: 0.0752358
# [382]	valid_0's rmse: 0.0752346
# [383]	valid_0's rmse: 0.0752363
# [384]	valid_0's rmse: 0.0752371
# [385]	valid_0's rmse: 0.0752346
# [386]	valid_0's rmse: 0.0752318
# [387]	valid_0's rmse: 0.0752317
# [388]	valid_0's rmse: 0.0752338
# [389]	valid_0's rmse: 0.0752327
# [390]	valid_0's rmse: 0.0752299
# [391]	valid_0's rmse: 0.0752298
# [392]	valid_0's rmse: 0.07523
# [393]	valid_0's rmse: 0.075232
# [394]	valid_0's rmse: 0.0752354
# [395]	valid_0's rmse: 0.0752362
# [396]	valid_0's rmse: 0.0752357
# [397]	valid_0's rmse: 0.075232
# [398]	valid_0's rmse: 0.0752325
# [399]	valid_0's rmse: 0.075231
# [400]	valid_0's rmse: 0.075232
# [401]	valid_0's rmse: 0.0752309
# [402]	valid_0's rmse: 0.0752341
# [403]	valid_0's rmse: 0.0752344
# [404]	valid_0's rmse: 0.0752371
# [405]	valid_0's rmse: 0.0752362
# [406]	valid_0's rmse: 0.0752416
# [407]	valid_0's rmse: 0.0752399
# [408]	valid_0's rmse: 0.0752402
# [409]	valid_0's rmse: 0.0752435
# [410]	valid_0's rmse: 0.0752405
# [411]	valid_0's rmse: 0.0752413
# [412]	valid_0's rmse: 0.0752398
# [413]	valid_0's rmse: 0.0752402
# [414]	valid_0's rmse: 0.0752364
# [415]	valid_0's rmse: 0.0752365
# [416]	valid_0's rmse: 0.0752354
# [417]	valid_0's rmse: 0.0752361
# [418]	valid_0's rmse: 0.0752372
# [419]	valid_0's rmse: 0.0752406
# [420]	valid_0's rmse: 0.0752394
# [421]	valid_0's rmse: 0.0752404
# [422]	valid_0's rmse: 0.0752391
# [423]	valid_0's rmse: 0.0752441
# [424]	valid_0's rmse: 0.075241
# [425]	valid_0's rmse: 0.0752378
# [426]	valid_0's rmse: 0.075237
# [427]	valid_0's rmse: 0.0752374
# [428]	valid_0's rmse: 0.0752374
# [429]	valid_0's rmse: 0.0752391
# [430]	valid_0's rmse: 0.0752414
# [431]	valid_0's rmse: 0.0752386
# [432]	valid_0's rmse: 0.0752393
# [433]	valid_0's rmse: 0.0752387
# [434]	valid_0's rmse: 0.0752375
# [435]	valid_0's rmse: 0.075239
# [436]	valid_0's rmse: 0.0752401
# [437]	valid_0's rmse: 0.0752405
# [438]	valid_0's rmse: 0.0752433
# [439]	valid_0's rmse: 0.0752408
# [440]	valid_0's rmse: 0.0752419
# [441]	valid_0's rmse: 0.0752435
# [442]	valid_0's rmse: 0.0752464
# [443]	valid_0's rmse: 0.0752478
# [444]	valid_0's rmse: 0.0752471
# [445]	valid_0's rmse: 0.0752474
# [446]	valid_0's rmse: 0.0752468
# [447]	valid_0's rmse: 0.0752466
# [448]	valid_0's rmse: 0.075246
# [449]	valid_0's rmse: 0.0752476
# [450]	valid_0's rmse: 0.0752475
# [451]	valid_0's rmse: 0.0752485
# [452]	valid_0's rmse: 0.0752492
# [453]	valid_0's rmse: 0.0752468
# [454]	valid_0's rmse: 0.0752472
# [455]	valid_0's rmse: 0.0752466
# [456]	valid_0's rmse: 0.0752434
# [457]	valid_0's rmse: 0.0752478
# [458]	valid_0's rmse: 0.0752511
# [459]	valid_0's rmse: 0.0752539
# [460]	valid_0's rmse: 0.075253
# [461]	valid_0's rmse: 0.0752508
# [462]	valid_0's rmse: 0.0752515
# [463]	valid_0's rmse: 0.075251
# [464]	valid_0's rmse: 0.0752499
# [465]	valid_0's rmse: 0.0752501
# [466]	valid_0's rmse: 0.0752545
# [467]	valid_0's rmse: 0.0752541
# [468]	valid_0's rmse: 0.075252
# [469]	valid_0's rmse: 0.0752521
# [470]	valid_0's rmse: 0.0752515
# [471]	valid_0's rmse: 0.0752486
# [472]	valid_0's rmse: 0.0752482
# [473]	valid_0's rmse: 0.0752528
# [474]	valid_0's rmse: 0.0752546
# [475]	valid_0's rmse: 0.0752584
# [476]	valid_0's rmse: 0.0752604
# [477]	valid_0's rmse: 0.0752597
# [478]	valid_0's rmse: 0.0752591
# [479]	valid_0's rmse: 0.0752597
# [480]	valid_0's rmse: 0.0752601
# [481]	valid_0's rmse: 0.075262
# [482]	valid_0's rmse: 0.0752617
# [483]	valid_0's rmse: 0.0752608
# [484]	valid_0's rmse: 0.0752586
# [485]	valid_0's rmse: 0.0752585
# [486]	valid_0's rmse: 0.0752574
# [487]	valid_0's rmse: 0.0752568
# [488]	valid_0's rmse: 0.0752574
# [489]	valid_0's rmse: 0.0752606
# [490]	valid_0's rmse: 0.0752602
# [491]	valid_0's rmse: 0.0752606
# [492]	valid_0's rmse: 0.075263
# [493]	valid_0's rmse: 0.0752632
# [494]	valid_0's rmse: 0.0752618
# [495]	valid_0's rmse: 0.0752593
# [496]	valid_0's rmse: 0.0752586
# [497]	valid_0's rmse: 0.0752581
# [498]	valid_0's rmse: 0.0752574
# [499]	valid_0's rmse: 0.0752577
# [500]	valid_0's rmse: 0.0752584
# The cross-validation score for LGBM_tuned is 0.0752
# The standard deviation for the RMSE is 0.000614

# %%
final_model = lgb.LGBMRegressor(**lgb_best_params)

# %%
final_model.get_params

# %%
cross_val_pipe(model = model)

# %%
#final_data = lgb.Dataset(train_X, train_y)

# %%
final_pipeline = make_pipeline(preprocessor,final_model)

# %%
final_pipeline

# %%
final_pipeline_fitted = final_pipeline.fit(train_X, train_y)

# %%
test_final = test.set_index("id").drop(["Train/Test", "target"], axis = 1)

# %%
predictions = pd.DataFrame(final_pipeline_fitted.predict(test_final))

# %%
index = pd.DataFrame(test_final.index)

# %%
sub = pd.concat([ index, predictions], axis="columns")
sub.columns = ["id","x_e_out [-]"]

# %%
sub.to_csv("submission_lgb_opt_25.csv", index = False)
